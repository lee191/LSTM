# %% [markdown]
# <a href="https://colab.research.google.com/github/lee191/LSTM/blob/main/DNN_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 특징추출

# %% [markdown]
# # 새 섹션

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 필요한 라이브러리를 임포트합니다.
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.cluster import KMeans
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import sklearn
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE

# 데이터셋의 열 이름을 정의합니다.
column_names = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes',
    'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins',
    'logged_in', 'num_compromised', 'root_shell', 'su_attempted',
    'num_root', 'num_file_creations', 'num_shells', 'num_access_files',
    'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate',
    'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
    'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
    'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
    'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate',
    'label'
]

# 학습 및 테스트 데이터를 읽어옵니다.
df1 = pd.read_csv("/content/drive/MyDrive/attack_name_data/KDDTrain+.csv", names=column_names)
df2 = pd.read_csv("/content/drive/MyDrive/attack_name_data/KDDTest+.csv", names=column_names)

# 두 데이터프레임을 합쳐 새로운 데이터프레임을 만듭니다.
newdf = pd.concat([df1, df2], ignore_index=True)

# 공격 레이블을 숫자 값으로 대체합니다.
dfdos = newdf.replace(['apache2', 'back', 'land', 'mailbomb', 'neptune', 'pod', 'processtable', 'smurf', 'teardrop', 'udpstorm'], 2)
dfr2l = dfdos.replace(['ftp_write', 'guess_passwd', 'imap', 'multihop', 'named', 'phf', 'sendmail', 'snmpgetattack', 'snmpguess', 'warezmaster', 'worm', 'xlock' ,'xsnoop', 'httptunnel', 'warezclient', 'spy'], 3)
dfu2r = dfr2l.replace(['buffer_overflow', 'loadmodule', 'perl', 'rootkit', 'ps', 'sqlattack', 'xterm'], 4)
dfprobe = dfu2r.replace(['ipsweep', 'mscan', 'nmap', 'portsweep', 'saint', 'satan'], 1)
dfnormal = dfprobe.replace(['normal'], 0)
df_type = dfnormal

# 레이블이 0 또는 1인 행만 선택합니다 (normal 또는 dos).
condition = (df_type.label == 0) | (df_type.label == 1)
df_dos = df_type[condition]
df_dos = df_dos.reset_index(drop=True)

# 각 레이블의 개수를 표시합니다.
print(df_dos.value_counts('label'))

# object 타입의 열에 대해 고유 값 및 개수를 표시합니다.
for columns in df1.columns:
    if df_dos[columns].dtypes == 'object':
        print(columns, '\n종류:', df_dos[columns].unique(), '\n개수:', df_dos[columns].nunique(), '\n')

# 'protocol_type', 'service', 'flag' 열을 추출합니다.
df_dos_obj = df_dos[['protocol_type', 'service', 'flag']]

# 'label' 열을 제외한 새로운 데이터프레임을 생성합니다.
newdos = df_dos.drop(columns=['label'])
newlabel = df_dos['label']

# LabelEncoder를 사용하여 범주형 열을 인코딩합니다.
le = LabelEncoder()
le.fit(newdos['protocol_type'])
protocol = le.transform(newdos['protocol_type'])
le.fit(newdos['service'])
service = le.transform(newdos['service'])
le.fit(newdos['flag'])
flag = le.transform(newdos['flag'])
newdos['protocol_type'] = protocol
newdos['service'] = service
newdos['flag'] = flag

# 전처리된 데이터를 dosle 및 yle에 저장합니다.
dosle = newdos
yle = newlabel

# MinMaxScaler를 사용하여 특성을 스케일링합니다.
pd.options.display.float_format = '{:.9f}'.format
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(dosle)
xle = pd.DataFrame(np_scaled, columns=dosle.columns)

# 데이터를 훈련 및 테스트 세트로 나눕니다.
xle, xle_test, yle, yle_test = train_test_split(xle, yle, test_size=0.2, random_state=2022)

# 데이터셋의 모양을 표시합니다.
print(xle.shape, yle.shape)
print(xle_test.shape, yle_test.shape)

# 훈련 및 테스트용으로 데이터의 일부를 선택합니다.
x = xle.head(1000)
x_test = xle_test.head(200)
y = yle.head(1000)
y_test = yle_test.head(200)

# XGBoost 분류기를 훈련합니다.
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
xgb.fit(xle, yle)

# 테스트 세트에서 예측을 수행합니다.
yle_preds = xgb.predict(xle_test)
yle_test = yle_test.astype(int)
yle_preds = yle_preds.astype(int)

# 정확도를 표시합니다.
print('Accuracy: %.2f' % accuracy_score(yle_test, yle_preds))

# 혼동 행렬을 표시합니다.
cm = confusion_matrix(yle_test, yle_preds)
plt.figure(figsize=(16, 9))
sns.heatmap(
    cm,
    annot=True,
    fmt='g',
    xticklabels=['dos', 'normal'],
    yticklabels=['dos', 'normal']
)
plt.show()

# Permutation Importance 분석을 수행합니다.
perm = PermutationImportance(xgb, random_state=1).fit(xle_test, yle_test)

# 중요도가 높은 순서대로 22개의 특성 선택
selected_features = xle_test.columns[perm.feature_importances_.argsort()[::-1][:22]]
print(selected_features)

# 선택된 특성을 데이터프레임으로 추출
xle_test_selected = xle_test[selected_features]

# newlabel과 합치기
final_df = pd.concat([xle_test_selected, pd.DataFrame(yle_test, columns=['label'])], axis=1)

print(final_df)
# CSV 파일로 저장
final_df.to_csv("/content/drive/MyDrive/attack_name_data/df_probe.csv", index=False)

eli5.show_weights(perm, feature_names=xle_test.columns.tolist())
# Out:
# label
# 0    77054
# 1    14077
# dtype: int64
# protocol_type
# 종류: ['tcp' 'udp' 'icmp']
# 개수: 3
#
# service
# 종류: ['ftp_data' 'other' 'http' 'eco_i' 'telnet' 'private' 'domain_u' 'smtp'
#  'netbios_dgm' 'urp_i' 'finger' 'ftp' 'gopher' 'ecr_i' 'sql_net' 'time'
#  'ntp_u' 'remote_job' 'csnet_ns' 'ssh' 'auth' 'shell' 'pop_3' 'Z39_50'
#  'IRC' 'pm_dump' 'link' 'systat' 'exec' 'iso_tsap' 'red_i' 'domain'
#  'netbios_ns' 'echo' 'uucp_path' 'bgp' 'whois' 'nntp' 'kshell' 'X11'
#  'klogin' 'ldap' 'name' 'discard' 'imap4' 'rje' 'http_443' 'pop_2'
#  'netbios_ssn' 'mtp' 'netstat' 'daytime' 'sunrpc' 'urh_i' 'http_8001'
#  'efs' 'supdup' 'ctf' 'nnsp' 'hostnames' 'courier' 'uucp' 'aol' 'vmnet'
#  'tim_i' 'login' 'http_2784' 'printer' 'tftp_u' 'harvest']
# 개수: 70
#
# flag
# 종류: ['SF' 'REJ' 'RSTR' 'SH' 'RSTO' 'S0' 'S1' 'RSTOS0' 'S3' 'S2' 'OTH']
# 개수: 11
#
# label
# 종류: [0 1]
# 개수: 2
#
# (72904, 41) (72904,)
# (18227, 41) (18227,)
# Accuracy: 1.00
# Index(['src_bytes', 'protocol_type', 'service', 'dst_host_same_srv_rate',
#        'dst_bytes', 'dst_host_same_src_port_rate', 'dst_host_rerror_rate',
#        'dst_host_diff_srv_rate', 'dst_host_count', 'count', 'diff_srv_rate',
#        'srv_count', 'dst_host_serror_rate', 'dst_host_srv_count',
#        'same_srv_rate', 'flag', 'rerror_rate', 'duration', 'logged_in',
#        'wrong_fragment', 'dst_host_srv_rerror_rate', 'num_outbound_cmds'],
#       dtype='object')
#         src_bytes  protocol_type     service  dst_host_same_srv_rate  \
# 40692 0.000000542    0.500000000 0.289855072             0.360000000
# 30744 0.000000231    0.500000000 0.347826087             1.000000000
# 23296 0.000000134    0.500000000 0.347826087             1.000000000
# 7668  0.000000161    0.500000000 0.347826087             1.000000000
# 61792 0.000000252    0.500000000 0.347826087             1.000000000
# ...           ...            ...         ...                     ...
# 44242 0.000000022    0.000000000 0.202898551             1.000000000
# 57888 0.000000175    0.500000000 0.347826087             1.000000000
# 71839 0.000000032    1.000000000 0.173913043             0.990000000
# 7551  0.000000235    0.500000000 0.347826087             1.000000000
# 23159 0.000000033    1.000000000 0.173913043             0.770000000
#
#         dst_bytes  dst_host_same_src_port_rate  dst_host_rerror_rate  \
# 40692 0.000000000                  0.360000000           0.000000000
# 30744 0.000002331                  0.000000000           0.000000000
# 23296 0.000004197                  0.010000000           0.000000000
# 7668  0.000000604                  0.010000000           0.330000000
# 61792 0.000004771                  0.000000000           0.000000000
# ...           ...                          ...                   ...
# 44242 0.000000000                  1.000000000           0.000000000
# 57888 0.000000366                  0.000000000           0.000000000
# 71839 0.000000084                  0.000000000           0.000000000
# 7551  0.000043825                  0.050000000           0.000000000
# 23159 0.000000098                  0.010000000           0.000000000
#
#        dst_host_diff_srv_rate  dst_host_count       count  ...  \
# 40692             0.020000000     0.721568627 0.001956947  ...
# 30744             0.000000000     1.000000000 0.035225049  ...
# 23296             0.000000000     0.533333333 0.001956947  ...
# 7668              0.000000000     0.427450980 0.052837573  ...
# 61792             0.000000000     1.000000000 0.015655577  ...
# ...                       ...             ...         ...  ...
# 44242             0.000000000     0.286274510 0.000000000  ...
# 57888             0.000000000     1.000000000 0.015655577  ...
# 71839             0.010000000     0.882352941 0.001956947  ...
# 7551              0.000000000     0.082352941 0.041095890  ...
# 23159             0.020000000     0.654901961 0.322896282  ...
#
#        dst_host_srv_count  same_srv_rate        flag  rerror_rate    duration  \
# 40692         0.301960784    1.000000000 0.900000000  0.000000000 0.000000000
# 30744         1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# 23296         0.533333333    1.000000000 0.900000000  0.000000000 0.000000000
# 7668          1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# 61792         1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# ...                   ...            ...         ...          ...         ...
# 44242         0.286274510    0.000000000 0.900000000  0.000000000 0.000000000
# 57888         1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# 71839         0.870588235    1.000000000 0.900000000  0.000000000 0.000000000
# 7551          1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# 23159         0.501960784    0.990000000 0.900000000  0.000000000 0.000000000
#
#         logged_in  wrong_fragment  dst_host_srv_rerror_rate  \
# 40692 1.000000000     0.000000000               0.000000000
# 30744 1.000000000     0.000000000               0.000000000
# 23296 1.000000000     0.000000000               0.000000000
# 7668  1.000000000     0.000000000               0.550000000
# 61792 1.000000000     0.000000000               0.000000000
# ...           ...             ...                       ...
# 44242 0.000000000     0.000000000               0.000000000
# 57888 1.000000000     0.000000000               0.000000000
# 71839 0.000000000     0.000000000               0.000000000
# 7551  1.000000000     0.000000000               0.000000000
# 23159 0.000000000     0.000000000               0.000000000
#
#        num_outbound_cmds  label
# 40692        0.000000000      0
# 30744        0.000000000      0
# 23296        0.000000000      0
# 7668         0.000000000      0
# 61792        0.000000000      0
# ...                  ...    ...
# 44242        0.000000000      0
# 57888        0.000000000      0
# 71839        0.000000000      0
# 7551         0.000000000      0
# 23159        0.000000000      0
#
# [18227 rows x 23 columns]
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0800
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 src_bytes
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0123
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 protocol_type
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0083
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 service
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0047
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_same_srv_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_bytes
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_same_src_port_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_rerror_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_diff_srv_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_count
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 count
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 diff_srv_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.31%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 srv_count
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_serror_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_srv_count
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 same_srv_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 flag
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 rerror_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.00

# %% [markdown]
# # DNN(DOS)

# %%
import pandas as pd
import numpy as np
import sklearn
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.preprocessing import MinMaxScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 소수점 9자리까지 표시
pd.options.display.float_format = '{:.9f}'.format

# df_dos2.csv 파일을 읽어옵니다.
df_dos = pd.read_csv("/content/drive/MyDrive/attack_name_data/df_dos.csv")

# 'label' 열을 제외한 데이터를 dos_loX로 지정합니다.
dos_loX = df_dos.drop(['label'], axis=1)

# 'label' 열을 dosY로 지정합니다.
dosY = df_dos['label']

# MinMaxScaler를 사용하여 데이터를 스케일링합니다.
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(dos_loX)
dosX = pd.DataFrame(np_scaled, columns=dos_loX.columns)

# RandomUnderSampler를 사용하여 언더샘플링을 수행합니다.
rus = RandomUnderSampler()
dfrus_X, dfrus_Y = rus.fit_resample(dosX, dosY)
dfrus_X = pd.DataFrame(dfrus_X, columns=dosX.columns)

# 훈련 및 테스트 데이터로 분할합니다.
X_train, X_test, y_train, y_test = train_test_split(dfrus_X, dfrus_Y, test_size=0.2, random_state=2022)

# 데이터 차원 확인
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# Random Forest 모델 생성
rand_clf = RandomForestClassifier(criterion='entropy', bootstrap=True, random_state=42, max_depth=5)
rand_clf.fit(X_train, y_train)

# 훈련 및 테스트 정확도 출력
print('훈련세트 정확도: {:.3f}'.format(rand_clf.score(X_train, y_train)))
print('테스트세트 정확도: {:.3f}'.format(rand_clf.score(X_test, y_test)))

# DNN 모델 생성
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=22))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 구조 확인
model.summary()

# 모델 훈련
history = model.fit(X_train, y_train, epochs=270, batch_size=64)

# 테스트셋 평가
scores = model.evaluate(X_test, y_test)
print(scores)

# 모델 저장
model.save('/content/drive/MyDrive/DNN_Model/DNN_dos.h5')

# 손실 및 정확도 그래프
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 데이터에 대한 예측 확률
y_pred_prob = model.predict(X_test)

# 확률을 클래스로 변환 (임계값은 예시로 0.5)
threshold = 0.6
y_pred = np.where(y_pred_prob > threshold, 1, 0)

# 혼동 행렬을 시각화
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# (17097, 22) (17097,)
# (4275, 22) (4275,)
# 훈련세트 정확도: 0.995
# 테스트세트 정확도: 0.994
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_72 (Dense)            (None, 64)                1472
#
#  dense_73 (Dense)            (None, 32)                2080
#
#  dense_74 (Dense)            (None, 16)                528
#
#  dense_75 (Dense)            (None, 8)                 136
#
#  dense_76 (Dense)            (None, 4)                 36
#
#  dense_77 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 4257 (16.63 KB)
# Trainable params: 4257 (16.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/270
# 268/268 [==============================] - 2s 2ms/step - loss: 0.3842 - accuracy: 0.9254
# Epoch 2/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.2780 - accuracy: 0.9802
# Epoch 3/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.2330 - accuracy: 0.9826
# Epoch 4/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1988 - accuracy: 0.9830
# Epoch 5/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1710 - accuracy: 0.9846
# Epoch 6/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1497 - accuracy: 0.9848
# Epoch 7/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1324 - accuracy: 0.9859
# Epoch 8/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1171 - accuracy: 0.9861
# Epoch 9/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1063 - accuracy: 0.9861
# Epoch 10/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0978 - accuracy: 0.9861
# Epoch 11/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0885 - accuracy: 0.9874
# Epoch 12/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0831 - accuracy: 0.9866
# Epoch 13/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0768 - accuracy: 0.9878
# Epoch 14/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0719 - accuracy: 0.9879
# Epoch 15/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0707 - accuracy: 0.9870
# Epoch 16/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0657 - accuracy: 0.9880
# Epoch 17/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0631 - accuracy: 0.9881
# Epoch 18/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0607 - accuracy: 0.9884
# Epoch 19/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0598 - accuracy: 0.9881
# Epoch 20/270
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0564 - accuracy: 0.9882
# Epoch 21/270
# 106/268 [==========>...................] - ETA: 0s - loss: 0.0568 - accuracy: 0.9870
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-16d0ae257e33> in <cell line: 67>()
#      65
#      66 # 모델 훈련
# ---> 67 history = model.fit(X_train, y_train, epochs=270, batch_size=64)
#      68
#      69 # 테스트셋 평가
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1781                         ):
#    1782                             callbacks.on_train_batch_begin(step)
# -> 1783                             tmp_logs = self.train_function(iterator)
#    1784                             if data_handler.should_sync:
#    1785                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     829
#     830       with OptionalXlaContext(self._jit_compile):
# --> 831         result = self._call(*args, **kwds)
#     832
#     833       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     851     """Calls the graph function."""
#     852     self._lock.acquire()
# --> 853     bound_args = function_type_utils.canonicalize_function_inputs(
#     854         args,
#     855         kwds,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/function_type_utils.py in canonicalize_function_inputs(args, kwargs, function_type, default_values, is_pure)
#     415   if is_pure:
#     416     args, kwargs = _convert_variables_to_tensors(args, kwargs)
# --> 417   bound_arguments = bind_function_inputs(
#     418       args, kwargs, function_type, default_values
#     419   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/function_type_utils.py in bind_function_inputs(args, kwargs, function_type, default_values)
#     435
#     436   try:
# --> 437     bound_arguments = function_type.bind_with_defaults(
#     438         args, sanitized_kwargs, default_values
#     439     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in bind_with_defaults(self, args, kwargs, default_values)
#     256     """Returns BoundArguments with default values filled in."""
#     257     bound_arguments = self.bind(*args, **kwargs)
# --> 258     bound_arguments.apply_defaults()
#     259
#     260     with_default_args = collections.OrderedDict()
#
# /usr/lib/python3.10/inspect.py in apply_defaults(self)
#    2849         arguments = self.arguments
#    2850         new_arguments = []
# -> 2851         for name, param in self._signature.parameters.items():
#    2852             try:
#    2853                 new_arguments.append((name, arguments[name]))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in parameters(self)
#     186     self._captures = captures if captures else collections.OrderedDict()
#     187
# --> 188   @property
#     189   def parameters(self) -> Mapping[str, Any]:
#     190     """Returns an ordered mapping of parameter name to specification."""
#
# KeyboardInterrupt:

# %% [markdown]
# # DNN(U2R)

# %%
import pandas as pd
import numpy as np
import sklearn
import sys
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.preprocessing import MinMaxScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers import Dropout
from keras.optimizers import Adam
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 소수점 9자리까지 표시
pd.options.display.float_format = '{:.9f}'.format

# df_u2r.csv 파일을 읽어옵니다.
df_u2r = pd.read_csv("/content/drive/MyDrive/attack_name_data/df_u2r.csv")

# 'label' 열을 제외한 데이터를 u2r_loX로 지정합니다.
u2r_loX = df_u2r.drop(['label'], axis=1)

# 'label' 열을 u2rY로 지정합니다.
u2rY = df_u2r['label']

# MinMaxScaler를 사용하여 데이터를 스케일링합니다.
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(u2r_loX)
u2rX = pd.DataFrame(np_scaled, columns=u2r_loX.columns)

# RandomUnderSampler를 사용하여 언더샘플링을 수행합니다.
rus = RandomUnderSampler()
dfrus_X, dfrus_Y = rus.fit_resample(u2rX, u2rY)
dfrus_X = pd.DataFrame(dfrus_X, columns=u2rX.columns)

# 훈련 및 테스트 데이터로 분할합니다.
X_train, X_test, y_train, y_test = train_test_split(dfrus_X, dfrus_Y, test_size=0.2, random_state=2022)

# 데이터 차원 확인
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# 배열로 변환
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# DNN 모델 생성
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=22))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

# 모델 구조 확인
model.summary()

# 모델 훈련
mod = model.fit(X_train, y_train, epochs=300, batch_size=6, validation_data=(X_test, y_test))


# 테스트셋 평가
scores = model.evaluate(X_test, y_test)
print(scores)

# 분류 보고서 출력
# print("Classification Report:")
# print(classification_report(y_test, y_pred))
# 모델 저장
model.save('/content/drive/MyDrive/DNN_u2r.h5')

# 손실 그래프
plt.plot(mod.history['loss'], label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 정확도 그래프
plt.plot(mod.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 데이터에 대한 예측 확률
y_pred_prob = model.predict(X_test)

# 확률을 클래스로 변환 (임계값은 예시로 0.5)
threshold = 0.5
y_pred = np.where(y_pred_prob > threshold, 1, 0)

# 혼동 행렬을 시각화
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# (44, 22) (44,)
# (12, 22) (12,)
# Model: "sequential_186"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1099 (Dense)          (None, 64)                1472
#
#  dropout_699 (Dropout)       (None, 64)                0
#
#  dense_1100 (Dense)          (None, 32)                2080
#
#  dropout_700 (Dropout)       (None, 32)                0
#
#  dense_1101 (Dense)          (None, 16)                528
#
#  dropout_701 (Dropout)       (None, 16)                0
#
#  dense_1102 (Dense)          (None, 8)                 136
#
#  dropout_702 (Dropout)       (None, 8)                 0
#
#  dense_1103 (Dense)          (None, 4)                 36
#
#  dense_1104 (Dense)          (None, 1)                 5
#
# =================================================================
# Total params: 4257 (16.63 KB)
# Trainable params: 4257 (16.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/300
# 8/8 [==============================] - 2s 30ms/step - loss: 0.6999 - accuracy: 0.5000 - val_loss: 0.7078 - val_accuracy: 0.5000
# Epoch 2/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7029 - accuracy: 0.5227 - val_loss: 0.7064 - val_accuracy: 0.5000
# Epoch 3/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6980 - accuracy: 0.5455 - val_loss: 0.7053 - val_accuracy: 0.5000
# Epoch 4/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6955 - accuracy: 0.4545 - val_loss: 0.7042 - val_accuracy: 0.5000
# Epoch 5/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7034 - accuracy: 0.4773 - val_loss: 0.7031 - val_accuracy: 0.5000
# Epoch 6/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7160 - accuracy: 0.3864 - val_loss: 0.7021 - val_accuracy: 0.5000
# Epoch 7/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6926 - accuracy: 0.6591 - val_loss: 0.7012 - val_accuracy: 0.5000
# Epoch 8/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6906 - accuracy: 0.6136 - val_loss: 0.7008 - val_accuracy: 0.5000
# Epoch 9/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7066 - accuracy: 0.5227 - val_loss: 0.7000 - val_accuracy: 0.5000
# Epoch 10/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7073 - accuracy: 0.5227 - val_loss: 0.6994 - val_accuracy: 0.5000
# Epoch 11/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6989 - accuracy: 0.5000 - val_loss: 0.6982 - val_accuracy: 0.5000
# Epoch 12/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7061 - accuracy: 0.4773 - val_loss: 0.6971 - val_accuracy: 0.5000
# Epoch 13/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6958 - accuracy: 0.5227 - val_loss: 0.6964 - val_accuracy: 0.5000
# Epoch 14/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6937 - accuracy: 0.5227 - val_loss: 0.6958 - val_accuracy: 0.5000
# Epoch 15/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7060 - accuracy: 0.4545 - val_loss: 0.6952 - val_accuracy: 0.5000
# Epoch 16/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6990 - accuracy: 0.4545 - val_loss: 0.6947 - val_accuracy: 0.5000
# Epoch 17/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7021 - accuracy: 0.5227 - val_loss: 0.6940 - val_accuracy: 0.5000
# Epoch 18/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6980 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 19/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6916 - accuracy: 0.4545 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 20/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6928 - accuracy: 0.5000 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 21/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6943 - accuracy: 0.5227 - val_loss: 0.6908 - val_accuracy: 0.5000
# Epoch 22/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6916 - accuracy: 0.5682 - val_loss: 0.6899 - val_accuracy: 0.5000
# Epoch 23/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6895 - accuracy: 0.5455 - val_loss: 0.6889 - val_accuracy: 0.5000
# Epoch 24/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6934 - accuracy: 0.5682 - val_loss: 0.6882 - val_accuracy: 0.5000
# Epoch 25/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6867 - accuracy: 0.5000 - val_loss: 0.6874 - val_accuracy: 0.5000
# Epoch 26/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7004 - accuracy: 0.5227 - val_loss: 0.6866 - val_accuracy: 0.5000
# Epoch 27/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6858 - accuracy: 0.6364 - val_loss: 0.6857 - val_accuracy: 0.5000
# Epoch 28/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6817 - accuracy: 0.5682 - val_loss: 0.6848 - val_accuracy: 0.5833
# Epoch 29/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.5227 - val_loss: 0.6844 - val_accuracy: 0.5833
# Epoch 30/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6848 - accuracy: 0.5227 - val_loss: 0.6837 - val_accuracy: 0.5833
# Epoch 31/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6892 - accuracy: 0.5227 - val_loss: 0.6828 - val_accuracy: 0.5833
# Epoch 32/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6821 - accuracy: 0.5682 - val_loss: 0.6820 - val_accuracy: 0.5833
# Epoch 33/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6835 - accuracy: 0.5227 - val_loss: 0.6815 - val_accuracy: 0.5833
# Epoch 34/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6875 - accuracy: 0.5682 - val_loss: 0.6808 - val_accuracy: 0.8333
# Epoch 35/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6900 - accuracy: 0.5455 - val_loss: 0.6797 - val_accuracy: 0.9167
# Epoch 36/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6885 - accuracy: 0.5909 - val_loss: 0.6789 - val_accuracy: 0.9167
# Epoch 37/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6848 - accuracy: 0.6364 - val_loss: 0.6784 - val_accuracy: 0.9167
# Epoch 38/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6921 - accuracy: 0.5682 - val_loss: 0.6780 - val_accuracy: 0.9167
# Epoch 39/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6800 - accuracy: 0.5909 - val_loss: 0.6774 - val_accuracy: 0.9167
# Epoch 40/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6856 - accuracy: 0.5909 - val_loss: 0.6769 - val_accuracy: 0.9167
# Epoch 41/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6841 - accuracy: 0.6136 - val_loss: 0.6763 - val_accuracy: 0.9167
# Epoch 42/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6710 - accuracy: 0.6818 - val_loss: 0.6757 - val_accuracy: 0.9167
# Epoch 43/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6716 - accuracy: 0.6136 - val_loss: 0.6748 - val_accuracy: 0.9167
# Epoch 44/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6838 - accuracy: 0.5682 - val_loss: 0.6739 - val_accuracy: 0.9167
# Epoch 45/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6805 - accuracy: 0.5682 - val_loss: 0.6728 - val_accuracy: 0.9167
# Epoch 46/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6735 - accuracy: 0.7273 - val_loss: 0.6718 - val_accuracy: 0.9167
# Epoch 47/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6846 - accuracy: 0.6364 - val_loss: 0.6709 - val_accuracy: 0.9167
# Epoch 48/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6814 - accuracy: 0.6591 - val_loss: 0.6696 - val_accuracy: 0.9167
# Epoch 49/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6717 - accuracy: 0.6364 - val_loss: 0.6683 - val_accuracy: 0.9167
# Epoch 50/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6811 - accuracy: 0.6364 - val_loss: 0.6675 - val_accuracy: 0.9167
# Epoch 51/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6721 - accuracy: 0.6591 - val_loss: 0.6667 - val_accuracy: 0.9167
# Epoch 52/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6732 - accuracy: 0.5227 - val_loss: 0.6659 - val_accuracy: 0.9167
# Epoch 53/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6810 - accuracy: 0.5227 - val_loss: 0.6648 - val_accuracy: 0.9167
# Epoch 54/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6685 - accuracy: 0.6136 - val_loss: 0.6637 - val_accuracy: 0.9167
# Epoch 55/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6602 - accuracy: 0.6591 - val_loss: 0.6625 - val_accuracy: 0.9167
# Epoch 56/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6609 - accuracy: 0.6364 - val_loss: 0.6612 - val_accuracy: 0.9167
# Epoch 57/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6684 - accuracy: 0.6364 - val_loss: 0.6600 - val_accuracy: 0.9167
# Epoch 58/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6701 - accuracy: 0.6136 - val_loss: 0.6589 - val_accuracy: 0.9167
# Epoch 59/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6569 - accuracy: 0.5909 - val_loss: 0.6579 - val_accuracy: 0.9167
# Epoch 60/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6565 - accuracy: 0.6818 - val_loss: 0.6566 - val_accuracy: 0.9167
# Epoch 61/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6551 - accuracy: 0.6818 - val_loss: 0.6548 - val_accuracy: 0.9167
# Epoch 62/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6502 - accuracy: 0.6591 - val_loss: 0.6529 - val_accuracy: 0.9167
# Epoch 63/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6557 - accuracy: 0.6364 - val_loss: 0.6508 - val_accuracy: 0.9167
# Epoch 64/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6568 - accuracy: 0.7045 - val_loss: 0.6491 - val_accuracy: 0.9167
# Epoch 65/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6589 - accuracy: 0.6591 - val_loss: 0.6479 - val_accuracy: 0.9167
# Epoch 66/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6443 - accuracy: 0.6818 - val_loss: 0.6470 - val_accuracy: 0.9167
# Epoch 67/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6557 - accuracy: 0.6364 - val_loss: 0.6460 - val_accuracy: 0.9167
# Epoch 68/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6560 - accuracy: 0.6364 - val_loss: 0.6442 - val_accuracy: 0.9167
# Epoch 69/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6538 - accuracy: 0.6364 - val_loss: 0.6425 - val_accuracy: 0.9167
# Epoch 70/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6474 - accuracy: 0.6364 - val_loss: 0.6403 - val_accuracy: 0.9167
# Epoch 71/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6390 - accuracy: 0.6818 - val_loss: 0.6380 - val_accuracy: 0.9167
# Epoch 72/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6524 - accuracy: 0.6818 - val_loss: 0.6359 - val_accuracy: 0.9167
# Epoch 73/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6564 - accuracy: 0.5909 - val_loss: 0.6344 - val_accuracy: 0.9167
# Epoch 74/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6514 - accuracy: 0.5909 - val_loss: 0.6328 - val_accuracy: 0.9167
# Epoch 75/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6386 - accuracy: 0.6818 - val_loss: 0.6306 - val_accuracy: 0.9167
# Epoch 76/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6227 - accuracy: 0.7727 - val_loss: 0.6281 - val_accuracy: 0.9167
# Epoch 77/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6578 - accuracy: 0.7500 - val_loss: 0.6262 - val_accuracy: 0.9167
# Epoch 78/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6283 - accuracy: 0.5909 - val_loss: 0.6244 - val_accuracy: 0.9167
# Epoch 79/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6404 - accuracy: 0.7955 - val_loss: 0.6220 - val_accuracy: 0.9167
# Epoch 80/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6220 - accuracy: 0.8182 - val_loss: 0.6199 - val_accuracy: 0.9167
# Epoch 81/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6376 - accuracy: 0.7500 - val_loss: 0.6176 - val_accuracy: 0.9167
# Epoch 82/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6279 - accuracy: 0.6591 - val_loss: 0.6154 - val_accuracy: 0.9167
# Epoch 83/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6263 - accuracy: 0.6591 - val_loss: 0.6137 - val_accuracy: 0.9167
# Epoch 84/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6167 - accuracy: 0.7727 - val_loss: 0.6122 - val_accuracy: 0.9167
# Epoch 85/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6276 - accuracy: 0.6818 - val_loss: 0.6102 - val_accuracy: 0.9167
# Epoch 86/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5973 - accuracy: 0.6818 - val_loss: 0.6080 - val_accuracy: 0.9167
# Epoch 87/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6025 - accuracy: 0.8182 - val_loss: 0.6054 - val_accuracy: 0.9167
# Epoch 88/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6052 - accuracy: 0.7273 - val_loss: 0.6021 - val_accuracy: 0.9167
# Epoch 89/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6188 - accuracy: 0.6818 - val_loss: 0.5993 - val_accuracy: 0.9167
# Epoch 90/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6029 - accuracy: 0.7500 - val_loss: 0.5960 - val_accuracy: 0.9167
# Epoch 91/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5978 - accuracy: 0.7727 - val_loss: 0.5934 - val_accuracy: 0.9167
# Epoch 92/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6122 - accuracy: 0.7045 - val_loss: 0.5910 - val_accuracy: 0.9167
# Epoch 93/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5735 - accuracy: 0.7727 - val_loss: 0.5882 - val_accuracy: 0.9167
# Epoch 94/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6046 - accuracy: 0.6818 - val_loss: 0.5857 - val_accuracy: 0.9167
# Epoch 95/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5779 - accuracy: 0.7727 - val_loss: 0.5834 - val_accuracy: 0.9167
# Epoch 96/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5923 - accuracy: 0.7727 - val_loss: 0.5808 - val_accuracy: 0.9167
# Epoch 97/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5987 - accuracy: 0.7273 - val_loss: 0.5781 - val_accuracy: 0.9167
# Epoch 98/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5949 - accuracy: 0.7955 - val_loss: 0.5749 - val_accuracy: 0.9167
# Epoch 99/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5643 - accuracy: 0.8409 - val_loss: 0.5724 - val_accuracy: 0.9167
# Epoch 100/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5841 - accuracy: 0.7500 - val_loss: 0.5697 - val_accuracy: 0.9167
# Epoch 101/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5676 - accuracy: 0.7045 - val_loss: 0.5672 - val_accuracy: 0.9167
# Epoch 102/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5607 - accuracy: 0.7955 - val_loss: 0.5646 - val_accuracy: 0.9167
# Epoch 103/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5678 - accuracy: 0.8182 - val_loss: 0.5617 - val_accuracy: 0.9167
# Epoch 104/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5722 - accuracy: 0.7500 - val_loss: 0.5591 - val_accuracy: 0.9167
# Epoch 105/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5816 - accuracy: 0.8409 - val_loss: 0.5569 - val_accuracy: 0.9167
# Epoch 106/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5865 - accuracy: 0.7955 - val_loss: 0.5547 - val_accuracy: 0.9167
# Epoch 107/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5738 - accuracy: 0.9091 - val_loss: 0.5525 - val_accuracy: 0.9167
# Epoch 108/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5688 - accuracy: 0.7273 - val_loss: 0.5493 - val_accuracy: 0.9167
# Epoch 109/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6124 - accuracy: 0.7273 - val_loss: 0.5467 - val_accuracy: 0.9167
# Epoch 110/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6065 - accuracy: 0.7500 - val_loss: 0.5449 - val_accuracy: 0.9167
# Epoch 111/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5686 - accuracy: 0.7727 - val_loss: 0.5433 - val_accuracy: 0.9167
# Epoch 112/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5906 - accuracy: 0.7500 - val_loss: 0.5415 - val_accuracy: 0.9167
# Epoch 113/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5661 - accuracy: 0.8182 - val_loss: 0.5393 - val_accuracy: 0.9167
# Epoch 114/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5636 - accuracy: 0.8182 - val_loss: 0.5371 - val_accuracy: 0.9167
# Epoch 115/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5404 - accuracy: 0.7955 - val_loss: 0.5349 - val_accuracy: 0.9167
# Epoch 116/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5564 - accuracy: 0.8409 - val_loss: 0.5328 - val_accuracy: 1.0000
# Epoch 117/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5803 - accuracy: 0.7727 - val_loss: 0.5308 - val_accuracy: 1.0000
# Epoch 118/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5776 - accuracy: 0.7955 - val_loss: 0.5294 - val_accuracy: 1.0000
# Epoch 119/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5690 - accuracy: 0.7955 - val_loss: 0.5285 - val_accuracy: 1.0000
# Epoch 120/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5612 - accuracy: 0.8409 - val_loss: 0.5274 - val_accuracy: 1.0000
# Epoch 121/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5481 - accuracy: 0.8864 - val_loss: 0.5242 - val_accuracy: 1.0000
# Epoch 122/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5436 - accuracy: 0.7955 - val_loss: 0.5212 - val_accuracy: 1.0000
# Epoch 123/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5402 - accuracy: 0.8409 - val_loss: 0.5184 - val_accuracy: 1.0000
# Epoch 124/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5228 - accuracy: 0.9091 - val_loss: 0.5147 - val_accuracy: 1.0000
# Epoch 125/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5087 - accuracy: 0.9545 - val_loss: 0.5109 - val_accuracy: 1.0000
# Epoch 126/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5234 - accuracy: 0.7727 - val_loss: 0.5080 - val_accuracy: 1.0000
# Epoch 127/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5534 - accuracy: 0.7955 - val_loss: 0.5052 - val_accuracy: 1.0000
# Epoch 128/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5712 - accuracy: 0.8636 - val_loss: 0.5034 - val_accuracy: 1.0000
# Epoch 129/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5331 - accuracy: 0.8409 - val_loss: 0.5024 - val_accuracy: 1.0000
# Epoch 130/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5398 - accuracy: 0.8636 - val_loss: 0.5004 - val_accuracy: 1.0000
# Epoch 131/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5207 - accuracy: 0.7500 - val_loss: 0.4995 - val_accuracy: 1.0000
# Epoch 132/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5304 - accuracy: 0.8409 - val_loss: 0.4979 - val_accuracy: 1.0000
# Epoch 133/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5224 - accuracy: 0.8636 - val_loss: 0.4968 - val_accuracy: 1.0000
# Epoch 134/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5347 - accuracy: 0.8409 - val_loss: 0.4973 - val_accuracy: 0.9167
# Epoch 135/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5090 - accuracy: 0.8409 - val_loss: 0.4962 - val_accuracy: 0.9167
# Epoch 136/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5145 - accuracy: 0.8636 - val_loss: 0.4938 - val_accuracy: 0.9167
# Epoch 137/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5354 - accuracy: 0.8636 - val_loss: 0.4912 - val_accuracy: 0.9167
# Epoch 138/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5125 - accuracy: 0.8636 - val_loss: 0.4883 - val_accuracy: 0.9167
# Epoch 139/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5146 - accuracy: 0.9318 - val_loss: 0.4852 - val_accuracy: 0.9167
# Epoch 140/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5111 - accuracy: 0.8636 - val_loss: 0.4822 - val_accuracy: 0.9167
# Epoch 141/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5086 - accuracy: 0.9318 - val_loss: 0.4798 - val_accuracy: 0.9167
# Epoch 142/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4927 - accuracy: 0.8636 - val_loss: 0.4766 - val_accuracy: 0.9167
# Epoch 143/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4966 - accuracy: 0.8636 - val_loss: 0.4743 - val_accuracy: 0.9167
# Epoch 144/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5042 - accuracy: 0.8409 - val_loss: 0.4714 - val_accuracy: 0.9167
# Epoch 145/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5235 - accuracy: 0.8409 - val_loss: 0.4698 - val_accuracy: 0.9167
# Epoch 146/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5058 - accuracy: 0.8636 - val_loss: 0.4680 - val_accuracy: 0.9167
# Epoch 147/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4790 - accuracy: 0.8864 - val_loss: 0.4664 - val_accuracy: 0.9167
# Epoch 148/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5026 - accuracy: 0.8409 - val_loss: 0.4647 - val_accuracy: 0.9167
# Epoch 149/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4800 - accuracy: 0.9318 - val_loss: 0.4626 - val_accuracy: 0.9167
# Epoch 150/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4704 - accuracy: 0.8409 - val_loss: 0.4609 - val_accuracy: 0.9167
# Epoch 151/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5382 - accuracy: 0.8182 - val_loss: 0.4594 - val_accuracy: 0.9167
# Epoch 152/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4769 - accuracy: 0.8409 - val_loss: 0.4583 - val_accuracy: 0.9167
# Epoch 153/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4837 - accuracy: 0.8636 - val_loss: 0.4561 - val_accuracy: 0.9167
# Epoch 154/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4740 - accuracy: 0.8864 - val_loss: 0.4539 - val_accuracy: 0.9167
# Epoch 155/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4570 - accuracy: 0.9318 - val_loss: 0.4513 - val_accuracy: 0.9167
# Epoch 156/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4645 - accuracy: 0.8864 - val_loss: 0.4483 - val_accuracy: 0.9167
# Epoch 157/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5202 - accuracy: 0.8409 - val_loss: 0.4459 - val_accuracy: 0.9167
# Epoch 158/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4673 - accuracy: 0.9318 - val_loss: 0.4440 - val_accuracy: 0.9167
# Epoch 159/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4657 - accuracy: 0.8864 - val_loss: 0.4424 - val_accuracy: 0.9167
# Epoch 160/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4536 - accuracy: 0.9091 - val_loss: 0.4400 - val_accuracy: 0.9167
# Epoch 161/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4662 - accuracy: 0.9318 - val_loss: 0.4378 - val_accuracy: 0.9167
# Epoch 162/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4572 - accuracy: 0.9091 - val_loss: 0.4349 - val_accuracy: 0.9167
# Epoch 163/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4733 - accuracy: 0.8864 - val_loss: 0.4329 - val_accuracy: 0.9167
# Epoch 164/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4636 - accuracy: 0.9091 - val_loss: 0.4307 - val_accuracy: 0.9167
# Epoch 165/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4901 - accuracy: 0.9091 - val_loss: 0.4282 - val_accuracy: 0.9167
# Epoch 166/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4570 - accuracy: 0.9318 - val_loss: 0.4248 - val_accuracy: 0.9167
# Epoch 167/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4816 - accuracy: 0.8864 - val_loss: 0.4219 - val_accuracy: 0.9167
# Epoch 168/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4405 - accuracy: 0.8864 - val_loss: 0.4201 - val_accuracy: 0.9167
# Epoch 169/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4380 - accuracy: 0.9091 - val_loss: 0.4187 - val_accuracy: 0.9167
# Epoch 170/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4816 - accuracy: 0.8636 - val_loss: 0.4175 - val_accuracy: 0.9167
# Epoch 171/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4710 - accuracy: 0.8864 - val_loss: 0.4154 - val_accuracy: 0.9167
# Epoch 172/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4127 - accuracy: 0.9318 - val_loss: 0.4117 - val_accuracy: 0.9167
# Epoch 173/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3994 - accuracy: 0.9318 - val_loss: 0.4087 - val_accuracy: 0.9167
# Epoch 174/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4509 - accuracy: 0.9091 - val_loss: 0.4066 - val_accuracy: 0.9167
# Epoch 175/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4458 - accuracy: 0.9091 - val_loss: 0.4053 - val_accuracy: 0.9167
# Epoch 176/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4629 - accuracy: 0.8409 - val_loss: 0.4057 - val_accuracy: 0.9167
# Epoch 177/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4030 - accuracy: 0.9091 - val_loss: 0.4049 - val_accuracy: 0.9167
# Epoch 178/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4060 - accuracy: 0.9091 - val_loss: 0.4036 - val_accuracy: 0.9167
# Epoch 179/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4125 - accuracy: 0.8864 - val_loss: 0.4018 - val_accuracy: 0.9167
# Epoch 180/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4886 - accuracy: 0.8864 - val_loss: 0.4002 - val_accuracy: 0.9167
# Epoch 181/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4289 - accuracy: 0.9545 - val_loss: 0.3985 - val_accuracy: 0.9167
# Epoch 182/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3959 - accuracy: 0.9545 - val_loss: 0.3963 - val_accuracy: 0.9167
# Epoch 183/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4182 - accuracy: 0.8864 - val_loss: 0.3938 - val_accuracy: 0.9167
# Epoch 184/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4217 - accuracy: 0.8864 - val_loss: 0.3908 - val_accuracy: 0.9167
# Epoch 185/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4306 - accuracy: 0.9091 - val_loss: 0.3898 - val_accuracy: 0.9167
# Epoch 186/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4275 - accuracy: 0.9091 - val_loss: 0.3881 - val_accuracy: 0.9167
# Epoch 187/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3998 - accuracy: 0.9545 - val_loss: 0.3859 - val_accuracy: 0.9167
# Epoch 188/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4086 - accuracy: 0.8864 - val_loss: 0.3833 - val_accuracy: 0.9167
# Epoch 189/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4193 - accuracy: 0.9318 - val_loss: 0.3813 - val_accuracy: 0.9167
# Epoch 190/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3967 - accuracy: 0.9091 - val_loss: 0.3782 - val_accuracy: 0.9167
# Epoch 191/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4345 - accuracy: 0.8636 - val_loss: 0.3759 - val_accuracy: 0.9167
# Epoch 192/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4401 - accuracy: 0.9091 - val_loss: 0.3746 - val_accuracy: 0.9167
# Epoch 193/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4024 - accuracy: 0.8636 - val_loss: 0.3729 - val_accuracy: 0.9167
# Epoch 194/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3989 - accuracy: 0.9318 - val_loss: 0.3712 - val_accuracy: 0.9167
# Epoch 195/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3739 - accuracy: 0.9318 - val_loss: 0.3691 - val_accuracy: 0.9167
# Epoch 196/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3946 - accuracy: 0.8864 - val_loss: 0.3667 - val_accuracy: 0.9167
# Epoch 197/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3787 - accuracy: 0.9318 - val_loss: 0.3648 - val_accuracy: 0.9167
# Epoch 198/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3685 - accuracy: 0.9318 - val_loss: 0.3626 - val_accuracy: 0.9167
# Epoch 199/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3694 - accuracy: 0.8636 - val_loss: 0.3601 - val_accuracy: 0.9167
# Epoch 200/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3802 - accuracy: 0.9545 - val_loss: 0.3582 - val_accuracy: 0.9167
# Epoch 201/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3856 - accuracy: 0.9091 - val_loss: 0.3562 - val_accuracy: 0.9167
# Epoch 202/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3792 - accuracy: 0.8864 - val_loss: 0.3538 - val_accuracy: 0.9167
# Epoch 203/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3953 - accuracy: 0.9091 - val_loss: 0.3512 - val_accuracy: 0.9167
# Epoch 204/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3956 - accuracy: 0.9545 - val_loss: 0.3504 - val_accuracy: 0.9167
# Epoch 205/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3754 - accuracy: 0.9318 - val_loss: 0.3489 - val_accuracy: 0.9167
# Epoch 206/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3729 - accuracy: 0.9091 - val_loss: 0.3467 - val_accuracy: 0.9167
# Epoch 207/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4252 - accuracy: 0.8864 - val_loss: 0.3447 - val_accuracy: 0.9167
# Epoch 208/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3355 - accuracy: 0.9545 - val_loss: 0.3420 - val_accuracy: 0.9167
# Epoch 209/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3360 - accuracy: 0.9318 - val_loss: 0.3390 - val_accuracy: 0.9167
# Epoch 210/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3646 - accuracy: 0.8864 - val_loss: 0.3368 - val_accuracy: 0.9167
# Epoch 211/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3453 - accuracy: 0.9318 - val_loss: 0.3344 - val_accuracy: 0.9167
# Epoch 212/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4119 - accuracy: 0.8864 - val_loss: 0.3322 - val_accuracy: 0.9167
# Epoch 213/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3691 - accuracy: 0.9091 - val_loss: 0.3299 - val_accuracy: 0.9167
# Epoch 214/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3807 - accuracy: 0.9318 - val_loss: 0.3273 - val_accuracy: 0.9167
# Epoch 215/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3205 - accuracy: 0.9545 - val_loss: 0.3255 - val_accuracy: 0.9167
# Epoch 216/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3353 - accuracy: 0.9091 - val_loss: 0.3232 - val_accuracy: 0.9167
# Epoch 217/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3324 - accuracy: 0.9091 - val_loss: 0.3210 - val_accuracy: 0.9167
# Epoch 218/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3437 - accuracy: 0.9091 - val_loss: 0.3189 - val_accuracy: 0.9167
# Epoch 219/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3421 - accuracy: 0.9545 - val_loss: 0.3168 - val_accuracy: 0.9167
# Epoch 220/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4018 - accuracy: 0.8864 - val_loss: 0.3148 - val_accuracy: 0.9167
# Epoch 221/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3416 - accuracy: 0.9091 - val_loss: 0.3131 - val_accuracy: 0.9167
# Epoch 222/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3226 - accuracy: 0.9318 - val_loss: 0.3125 - val_accuracy: 0.9167
# Epoch 223/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3511 - accuracy: 0.9318 - val_loss: 0.3108 - val_accuracy: 0.9167
# Epoch 224/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3252 - accuracy: 0.8864 - val_loss: 0.3092 - val_accuracy: 0.9167
# Epoch 225/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2735 - accuracy: 1.0000 - val_loss: 0.3070 - val_accuracy: 0.9167
# Epoch 226/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2798 - accuracy: 0.9773 - val_loss: 0.3043 - val_accuracy: 0.9167
# Epoch 227/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3608 - accuracy: 0.8636 - val_loss: 0.3023 - val_accuracy: 0.9167
# Epoch 228/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2845 - accuracy: 0.9773 - val_loss: 0.2999 - val_accuracy: 0.9167
# Epoch 229/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2977 - accuracy: 0.9318 - val_loss: 0.2975 - val_accuracy: 0.9167
# Epoch 230/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2947 - accuracy: 0.9545 - val_loss: 0.2953 - val_accuracy: 0.9167
# Epoch 231/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3500 - accuracy: 0.9545 - val_loss: 0.2936 - val_accuracy: 0.9167
# Epoch 232/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3105 - accuracy: 0.9318 - val_loss: 0.2916 - val_accuracy: 0.9167
# Epoch 233/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2736 - accuracy: 0.9318 - val_loss: 0.2890 - val_accuracy: 0.9167
# Epoch 234/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3453 - accuracy: 0.9091 - val_loss: 0.2870 - val_accuracy: 0.9167
# Epoch 235/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2703 - accuracy: 0.9773 - val_loss: 0.2853 - val_accuracy: 0.9167
# Epoch 236/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3480 - accuracy: 0.8864 - val_loss: 0.2835 - val_accuracy: 0.9167
# Epoch 237/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3185 - accuracy: 0.8864 - val_loss: 0.2824 - val_accuracy: 0.9167
# Epoch 238/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3006 - accuracy: 0.9545 - val_loss: 0.2806 - val_accuracy: 0.9167
# Epoch 239/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3021 - accuracy: 0.9545 - val_loss: 0.2782 - val_accuracy: 0.9167
# Epoch 240/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3219 - accuracy: 0.9091 - val_loss: 0.2758 - val_accuracy: 0.9167
# Epoch 241/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3258 - accuracy: 0.8636 - val_loss: 0.2734 - val_accuracy: 0.9167
# Epoch 242/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3187 - accuracy: 0.8636 - val_loss: 0.2712 - val_accuracy: 0.9167
# Epoch 243/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2941 - accuracy: 0.9318 - val_loss: 0.2695 - val_accuracy: 0.9167
# Epoch 244/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2921 - accuracy: 0.8864 - val_loss: 0.2677 - val_accuracy: 0.9167
# Epoch 245/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2893 - accuracy: 0.9091 - val_loss: 0.2656 - val_accuracy: 0.9167
# Epoch 246/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3022 - accuracy: 0.9318 - val_loss: 0.2626 - val_accuracy: 0.9167
# Epoch 247/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2517 - accuracy: 0.9773 - val_loss: 0.2595 - val_accuracy: 0.9167
# Epoch 248/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3199 - accuracy: 0.9318 - val_loss: 0.2568 - val_accuracy: 0.9167
# Epoch 249/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2847 - accuracy: 0.9545 - val_loss: 0.2539 - val_accuracy: 0.9167
# Epoch 250/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2536 - accuracy: 0.9773 - val_loss: 0.2513 - val_accuracy: 0.9167
# Epoch 251/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2809 - accuracy: 0.9773 - val_loss: 0.2488 - val_accuracy: 0.9167
# Epoch 252/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3035 - accuracy: 0.9091 - val_loss: 0.2465 - val_accuracy: 0.9167
# Epoch 253/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2835 - accuracy: 0.8864 - val_loss: 0.2453 - val_accuracy: 0.9167
# Epoch 254/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2761 - accuracy: 0.9318 - val_loss: 0.2438 - val_accuracy: 0.9167
# Epoch 255/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2566 - accuracy: 0.9545 - val_loss: 0.2420 - val_accuracy: 0.9167
# Epoch 256/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2148 - accuracy: 0.9545 - val_loss: 0.2401 - val_accuracy: 0.9167
# Epoch 257/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2848 - accuracy: 0.9318 - val_loss: 0.2382 - val_accuracy: 0.9167
# Epoch 258/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2331 - accuracy: 0.9545 - val_loss: 0.2365 - val_accuracy: 0.9167
# Epoch 259/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2230 - accuracy: 0.9773 - val_loss: 0.2346 - val_accuracy: 0.9167
# Epoch 260/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2556 - accuracy: 0.9545 - val_loss: 0.2341 - val_accuracy: 0.9167
# Epoch 261/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2152 - accuracy: 0.9773 - val_loss: 0.2327 - val_accuracy: 0.9167
# Epoch 262/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1730 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9167
# Epoch 263/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2079 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9167
# Epoch 264/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2151 - accuracy: 0.9318 - val_loss: 0.2270 - val_accuracy: 0.9167
# Epoch 265/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2661 - accuracy: 0.9318 - val_loss: 0.2259 - val_accuracy: 0.9167
# Epoch 266/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2589 - accuracy: 0.9318 - val_loss: 0.2248 - val_accuracy: 0.9167
# Epoch 267/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2311 - accuracy: 0.9545 - val_loss: 0.2230 - val_accuracy: 0.9167
# Epoch 268/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2247 - accuracy: 0.9773 - val_loss: 0.2201 - val_accuracy: 0.9167
# Epoch 269/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2596 - accuracy: 0.9318 - val_loss: 0.2179 - val_accuracy: 0.9167
# Epoch 270/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2457 - accuracy: 0.9318 - val_loss: 0.2156 - val_accuracy: 0.9167
# Epoch 271/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2207 - accuracy: 0.9545 - val_loss: 0.2142 - val_accuracy: 0.9167
# Epoch 272/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2599 - accuracy: 0.9545 - val_loss: 0.2139 - val_accuracy: 0.9167
# Epoch 273/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2428 - accuracy: 0.9091 - val_loss: 0.2135 - val_accuracy: 0.9167
# Epoch 274/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2830 - accuracy: 0.8636 - val_loss: 0.2131 - val_accuracy: 0.9167
# Epoch 275/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1889 - accuracy: 0.9318 - val_loss: 0.2119 - val_accuracy: 0.9167
# Epoch 276/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1895 - accuracy: 0.9545 - val_loss: 0.2116 - val_accuracy: 0.9167
# Epoch 277/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1969 - accuracy: 0.9318 - val_loss: 0.2109 - val_accuracy: 0.9167
# Epoch 278/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2520 - accuracy: 0.9091 - val_loss: 0.2103 - val_accuracy: 0.9167
# Epoch 279/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2378 - accuracy: 0.9091 - val_loss: 0.2095 - val_accuracy: 0.9167
# Epoch 280/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1710 - accuracy: 0.9545 - val_loss: 0.2091 - val_accuracy: 0.9167
# Epoch 281/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2599 - accuracy: 0.9318 - val_loss: 0.2103 - val_accuracy: 0.9167
# Epoch 282/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1918 - accuracy: 0.9091 - val_loss: 0.2093 - val_accuracy: 0.9167
# Epoch 283/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3027 - accuracy: 0.9091 - val_loss: 0.2081 - val_accuracy: 0.9167
# Epoch 284/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1789 - accuracy: 0.9545 - val_loss: 0.2073 - val_accuracy: 0.9167
# Epoch 285/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1861 - accuracy: 0.9773 - val_loss: 0.2078 - val_accuracy: 0.9167
# Epoch 286/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2370 - accuracy: 0.9091 - val_loss: 0.2074 - val_accuracy: 0.9167
# Epoch 287/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1859 - accuracy: 0.9773 - val_loss: 0.2073 - val_accuracy: 0.9167
# Epoch 288/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2284 - accuracy: 0.9318 - val_loss: 0.2088 - val_accuracy: 0.9167
# Epoch 289/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1579 - accuracy: 0.9545 - val_loss: 0.2091 - val_accuracy: 0.9167
# Epoch 290/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1844 - accuracy: 0.9545 - val_loss: 0.2105 - val_accuracy: 0.9167
# Epoch 291/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1441 - accuracy: 0.9773 - val_loss: 0.2108 - val_accuracy: 0.9167
# Epoch 292/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1594 - accuracy: 0.9545 - val_loss: 0.2104 - val_accuracy: 0.9167
# Epoch 293/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2443 - accuracy: 0.8636 - val_loss: 0.2103 - val_accuracy: 0.9167
# Epoch 294/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1935 - accuracy: 0.9545 - val_loss: 0.2071 - val_accuracy: 0.9167
# Epoch 295/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1666 - accuracy: 0.9545 - val_loss: 0.2055 - val_accuracy: 0.9167
# Epoch 296/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1882 - accuracy: 0.9318 - val_loss: 0.2041 - val_accuracy: 0.9167
# Epoch 297/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2082 - accuracy: 0.9545 - val_loss: 0.2031 - val_accuracy: 0.9167
# Epoch 298/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1624 - accuracy: 0.9773 - val_loss: 0.2028 - val_accuracy: 0.9167
# Epoch 299/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1965 - accuracy: 0.9545 - val_loss: 0.2010 - val_accuracy: 0.9167
# Epoch 300/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2271 - accuracy: 0.9091 - val_loss: 0.2013 - val_accuracy: 0.9167
# 1/1 [==============================] - 0s 154ms/step - loss: 0.2013 - accuracy: 0.9167
# [0.2013148069381714, 0.9166666865348816]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 78ms/step

# %% [markdown]
# # DNN(Probe)

# %%
import pandas as pd
import numpy as np
import sklearn
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping, ModelCheckpoint

# 소수점 9자리까지 표시
pd.options.display.float_format = '{:.9f}'.format

# df_probe.csv 파일을 읽어옵니다.
df_probe = pd.read_csv("/content/drive/MyDrive/attack_name_data/df_probe.csv")

# 'label' 열을 제외한 데이터를 probe_loX로 지정합니다.
probe_loX = df_probe.drop(['label'], axis=1)

# 'label' 열을 probeY로 지정합니다.
probeY = df_probe['label']

# MinMaxScaler를 사용하여 데이터를 스케일링합니다.
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(probe_loX)
probeX = pd.DataFrame(np_scaled, columns=probe_loX.columns)

# RandomUnderSampler를 사용하여 언더샘플링을 수행합니다.
rus = RandomUnderSampler()
dfrus_X, dfrus_Y = rus.fit_resample(probeX, probeY)
dfrus_X = pd.DataFrame(dfrus_X, columns=probeX.columns)

# 훈련 및 테스트 데이터로 분할합니다.
X_train, X_test, y_train, y_test = train_test_split(dfrus_X, dfrus_Y, test_size=0.2, random_state=2022)

# 데이터 차원 확인
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# 배열로 변환
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# DNN 모델 생성
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=22))
model.add(Dropout(0.3))  # 조정
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))  # 조정
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.3))  # 조정
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.3))  # 조정
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002), metrics=['accuracy'])

# 모델 구조 확인
model.summary()

# # EarlyStopping 콜백 설정
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# # ModelCheckpoint 콜백 설정
# model_checkpoint = ModelCheckpoint('/content/drive/MyDrive/DNN_Model/DNN_probe_best.h5', save_best_only=True)

# 모델 훈련
mod = model.fit(X_train, y_train, epochs=400, batch_size=64, validation_data=(X_test, y_test))


# 테스트셋 평가
scores = model.evaluate(X_test, y_test)
print(scores)

# 모델 저장
model.save('/content/drive/MyDrive/DNN_Model/DNN_probe.h5')

# 손실 그래프
plt.plot(mod.history['loss'], label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 정확도 그래프
plt.plot(mod.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 데이터에 대한 예측 확률
y_pred_prob = model.predict(X_test)

# 확률을 클래스로 변환 (임계값은 예시로 0.5)
threshold = 0.5
y_pred = np.where(y_pred_prob > threshold, 1, 0)

# 혼동 행렬을 시각화
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# (4523, 22) (4523,)
# (1131, 22) (1131,)
# Model: "sequential_123"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_734 (Dense)           (None, 64)                1472
#
#  dropout_460 (Dropout)       (None, 64)                0
#
#  dense_735 (Dense)           (None, 32)                2080
#
#  dropout_461 (Dropout)       (None, 32)                0
#
#  dense_736 (Dense)           (None, 16)                528
#
#  dropout_462 (Dropout)       (None, 16)                0
#
#  dense_737 (Dense)           (None, 8)                 136
#
#  dropout_463 (Dropout)       (None, 8)                 0
#
#  dense_738 (Dense)           (None, 4)                 36
#
#  dense_739 (Dense)           (None, 1)                 5
#
# =================================================================
# Total params: 4257 (16.63 KB)
# Trainable params: 4257 (16.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/400
# 71/71 [==============================] - 2s 5ms/step - loss: 0.6833 - accuracy: 0.5390 - val_loss: 0.6696 - val_accuracy: 0.8762
# Epoch 2/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.6532 - accuracy: 0.6679 - val_loss: 0.5935 - val_accuracy: 0.8895
# Epoch 3/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.5877 - accuracy: 0.7513 - val_loss: 0.5066 - val_accuracy: 0.9063
# Epoch 4/400
# 71/71 [==============================] - 0s 4ms/step - loss: 0.5221 - accuracy: 0.8165 - val_loss: 0.4169 - val_accuracy: 0.9284
# Epoch 5/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4509 - accuracy: 0.8368 - val_loss: 0.3225 - val_accuracy: 0.9372
# Epoch 6/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8481 - val_loss: 0.2505 - val_accuracy: 0.9399
# Epoch 7/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.3452 - accuracy: 0.8634 - val_loss: 0.2078 - val_accuracy: 0.9425
# Epoch 8/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.3133 - accuracy: 0.8952 - val_loss: 0.1797 - val_accuracy: 0.9416
# Epoch 9/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2992 - accuracy: 0.9100 - val_loss: 0.1622 - val_accuracy: 0.9452
# Epoch 10/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2719 - accuracy: 0.9211 - val_loss: 0.1483 - val_accuracy: 0.9549
# Epoch 11/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2580 - accuracy: 0.9235 - val_loss: 0.1370 - val_accuracy: 0.9558
# Epoch 12/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2541 - accuracy: 0.9235 - val_loss: 0.1277 - val_accuracy: 0.9567
# Epoch 13/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2406 - accuracy: 0.9341 - val_loss: 0.1196 - val_accuracy: 0.9567
# Epoch 14/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2270 - accuracy: 0.9328 - val_loss: 0.1119 - val_accuracy: 0.9611
# Epoch 15/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2079 - accuracy: 0.9419 - val_loss: 0.1046 - val_accuracy: 0.9611
# Epoch 16/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2070 - accuracy: 0.9372 - val_loss: 0.1003 - val_accuracy: 0.9637
# Epoch 17/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1940 - accuracy: 0.9449 - val_loss: 0.0952 - val_accuracy: 0.9655
# Epoch 18/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1901 - accuracy: 0.9445 - val_loss: 0.0924 - val_accuracy: 0.9664
# Epoch 19/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.9447 - val_loss: 0.0903 - val_accuracy: 0.9691
# Epoch 20/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1736 - accuracy: 0.9416 - val_loss: 0.0872 - val_accuracy: 0.9673
# Epoch 21/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1692 - accuracy: 0.9518 - val_loss: 0.0852 - val_accuracy: 0.9673
# Epoch 22/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1690 - accuracy: 0.9518 - val_loss: 0.0840 - val_accuracy: 0.9691
# Epoch 23/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1554 - accuracy: 0.9529 - val_loss: 0.0813 - val_accuracy: 0.9699
# Epoch 24/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1522 - accuracy: 0.9520 - val_loss: 0.0783 - val_accuracy: 0.9699
# Epoch 25/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.9549 - val_loss: 0.0768 - val_accuracy: 0.9708
# Epoch 26/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1471 - accuracy: 0.9549 - val_loss: 0.0758 - val_accuracy: 0.9726
# Epoch 27/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.9569 - val_loss: 0.0746 - val_accuracy: 0.9726
# Epoch 28/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1421 - accuracy: 0.9582 - val_loss: 0.0738 - val_accuracy: 0.9726
# Epoch 29/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1368 - accuracy: 0.9589 - val_loss: 0.0727 - val_accuracy: 0.9770
# Epoch 30/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1340 - accuracy: 0.9567 - val_loss: 0.0722 - val_accuracy: 0.9805
# Epoch 31/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1277 - accuracy: 0.9582 - val_loss: 0.0688 - val_accuracy: 0.9761
# Epoch 32/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1324 - accuracy: 0.9582 - val_loss: 0.0679 - val_accuracy: 0.9814
# Epoch 33/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.9624 - val_loss: 0.0669 - val_accuracy: 0.9797
# Epoch 34/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9602 - val_loss: 0.0652 - val_accuracy: 0.9797
# Epoch 35/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1196 - accuracy: 0.9602 - val_loss: 0.0647 - val_accuracy: 0.9814
# Epoch 36/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 0.9651 - val_loss: 0.0631 - val_accuracy: 0.9814
# Epoch 37/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9611 - val_loss: 0.0613 - val_accuracy: 0.9823
# Epoch 38/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.9684 - val_loss: 0.0614 - val_accuracy: 0.9841
# Epoch 39/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1172 - accuracy: 0.9637 - val_loss: 0.0593 - val_accuracy: 0.9841
# Epoch 40/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1124 - accuracy: 0.9666 - val_loss: 0.0581 - val_accuracy: 0.9859
# Epoch 41/400
# 71/71 [==============================] - 0s 4ms/step - loss: 0.1140 - accuracy: 0.9655 - val_loss: 0.0578 - val_accuracy: 0.9850
# Epoch 42/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1112 - accuracy: 0.9668 - val_loss: 0.0574 - val_accuracy: 0.9841
# Epoch 43/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1008 - accuracy: 0.9675 - val_loss: 0.0563 - val_accuracy: 0.9841
# Epoch 44/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1094 - accuracy: 0.9677 - val_loss: 0.0548 - val_accuracy: 0.9876
# Epoch 45/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9697 - val_loss: 0.0556 - val_accuracy: 0.9867
# Epoch 46/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9648 - val_loss: 0.0561 - val_accuracy: 0.9867
# Epoch 47/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1053 - accuracy: 0.9715 - val_loss: 0.0555 - val_accuracy: 0.9885
# Epoch 48/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.9675 - val_loss: 0.0552 - val_accuracy: 0.9885
# Epoch 49/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0987 - accuracy: 0.9686 - val_loss: 0.0536 - val_accuracy: 0.9894
# Epoch 50/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9719 - val_loss: 0.0535 - val_accuracy: 0.9894
# Epoch 51/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.9688 - val_loss: 0.0536 - val_accuracy: 0.9894
# Epoch 52/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0954 - accuracy: 0.9693 - val_loss: 0.0527 - val_accuracy: 0.9894
# Epoch 53/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0924 - accuracy: 0.9746 - val_loss: 0.0532 - val_accuracy: 0.9912
# Epoch 54/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0937 - accuracy: 0.9713 - val_loss: 0.0512 - val_accuracy: 0.9894
# Epoch 55/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0881 - accuracy: 0.9744 - val_loss: 0.0513 - val_accuracy: 0.9894
# Epoch 56/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0937 - accuracy: 0.9708 - val_loss: 0.0485 - val_accuracy: 0.9903
# Epoch 57/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.9755 - val_loss: 0.0498 - val_accuracy: 0.9903
# Epoch 58/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0890 - accuracy: 0.9770 - val_loss: 0.0485 - val_accuracy: 0.9894
# Epoch 59/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0877 - accuracy: 0.9746 - val_loss: 0.0500 - val_accuracy: 0.9903
# Epoch 60/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.9768 - val_loss: 0.0485 - val_accuracy: 0.9903
# Epoch 61/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 0.9757 - val_loss: 0.0480 - val_accuracy: 0.9903
# Epoch 62/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9719 - val_loss: 0.0481 - val_accuracy: 0.9912
# Epoch 63/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9763 - val_loss: 0.0474 - val_accuracy: 0.9912
# Epoch 64/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9761 - val_loss: 0.0471 - val_accuracy: 0.9912
# Epoch 65/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0852 - accuracy: 0.9768 - val_loss: 0.0453 - val_accuracy: 0.9912
# Epoch 66/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9724 - val_loss: 0.0475 - val_accuracy: 0.9912
# Epoch 67/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9761 - val_loss: 0.0460 - val_accuracy: 0.9912
# Epoch 68/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9770 - val_loss: 0.0453 - val_accuracy: 0.9912
# Epoch 69/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.9816 - val_loss: 0.0455 - val_accuracy: 0.9912
# Epoch 70/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0792 - accuracy: 0.9790 - val_loss: 0.0452 - val_accuracy: 0.9912
# Epoch 71/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9783 - val_loss: 0.0458 - val_accuracy: 0.9912
# Epoch 72/400
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0782 - accuracy: 0.9761 - val_loss: 0.0443 - val_accuracy: 0.9912
# Epoch 73/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0763 - accuracy: 0.9781 - val_loss: 0.0462 - val_accuracy: 0.9903
# Epoch 74/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0805 - accuracy: 0.9779 - val_loss: 0.0458 - val_accuracy: 0.9912
# Epoch 75/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9788 - val_loss: 0.0447 - val_accuracy: 0.9912
# Epoch 76/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0764 - accuracy: 0.9779 - val_loss: 0.0446 - val_accuracy: 0.9912
# Epoch 77/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9779 - val_loss: 0.0444 - val_accuracy: 0.9912
# Epoch 78/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9805 - val_loss: 0.0441 - val_accuracy: 0.9912
# Epoch 79/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0708 - accuracy: 0.9790 - val_loss: 0.0437 - val_accuracy: 0.9912
# Epoch 80/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9801 - val_loss: 0.0449 - val_accuracy: 0.9912
# Epoch 81/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9816 - val_loss: 0.0432 - val_accuracy: 0.9912
# Epoch 82/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9803 - val_loss: 0.0436 - val_accuracy: 0.9912
# Epoch 83/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0746 - accuracy: 0.9786 - val_loss: 0.0449 - val_accuracy: 0.9912
# Epoch 84/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9830 - val_loss: 0.0446 - val_accuracy: 0.9903
# Epoch 85/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9810 - val_loss: 0.0452 - val_accuracy: 0.9894
# Epoch 86/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0727 - accuracy: 0.9801 - val_loss: 0.0462 - val_accuracy: 0.9894
# Epoch 87/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0713 - accuracy: 0.9812 - val_loss: 0.0432 - val_accuracy: 0.9912
# Epoch 88/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9808 - val_loss: 0.0453 - val_accuracy: 0.9894
# Epoch 89/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9810 - val_loss: 0.0428 - val_accuracy: 0.9912
# Epoch 90/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9839 - val_loss: 0.0445 - val_accuracy: 0.9894
# Epoch 91/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9810 - val_loss: 0.0432 - val_accuracy: 0.9903
# Epoch 92/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9843 - val_loss: 0.0429 - val_accuracy: 0.9912
# Epoch 93/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 0.9808 - val_loss: 0.0443 - val_accuracy: 0.9903
# Epoch 94/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9805 - val_loss: 0.0448 - val_accuracy: 0.9903
# Epoch 95/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 0.9805 - val_loss: 0.0439 - val_accuracy: 0.9894
# Epoch 96/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9823 - val_loss: 0.0442 - val_accuracy: 0.9894
# Epoch 97/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.9801 - val_loss: 0.0438 - val_accuracy: 0.9894
# Epoch 98/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9810 - val_loss: 0.0431 - val_accuracy: 0.9903
# Epoch 99/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0616 - accuracy: 0.9828 - val_loss: 0.0453 - val_accuracy: 0.9885
# Epoch 100/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9836 - val_loss: 0.0447 - val_accuracy: 0.9894
# Epoch 101/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 0.9819 - val_loss: 0.0420 - val_accuracy: 0.9912
# Epoch 102/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0635 - accuracy: 0.9836 - val_loss: 0.0423 - val_accuracy: 0.9894
# Epoch 103/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0602 - accuracy: 0.9801 - val_loss: 0.0444 - val_accuracy: 0.9885
# Epoch 104/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 0.9839 - val_loss: 0.0445 - val_accuracy: 0.9894
# Epoch 105/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0594 - accuracy: 0.9841 - val_loss: 0.0429 - val_accuracy: 0.9894
# Epoch 106/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 0.9830 - val_loss: 0.0425 - val_accuracy: 0.9894
# Epoch 107/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 0.9850 - val_loss: 0.0429 - val_accuracy: 0.9894
# Epoch 108/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9834 - val_loss: 0.0452 - val_accuracy: 0.9876
# Epoch 109/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0606 - accuracy: 0.9816 - val_loss: 0.0431 - val_accuracy: 0.9876
# Epoch 110/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9845 - val_loss: 0.0440 - val_accuracy: 0.9876
# Epoch 111/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0625 - accuracy: 0.9839 - val_loss: 0.0428 - val_accuracy: 0.9876
# Epoch 112/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 0.9845 - val_loss: 0.0419 - val_accuracy: 0.9894
# Epoch 113/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 0.9828 - val_loss: 0.0407 - val_accuracy: 0.9903
# Epoch 114/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9856 - val_loss: 0.0420 - val_accuracy: 0.9885
# Epoch 115/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 0.9843 - val_loss: 0.0411 - val_accuracy: 0.9894
# Epoch 116/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.9850 - val_loss: 0.0407 - val_accuracy: 0.9903
# Epoch 117/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0581 - accuracy: 0.9841 - val_loss: 0.0413 - val_accuracy: 0.9894
# Epoch 118/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9843 - val_loss: 0.0420 - val_accuracy: 0.9894
# Epoch 119/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 0.9856 - val_loss: 0.0410 - val_accuracy: 0.9894
# Epoch 120/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0556 - accuracy: 0.9850 - val_loss: 0.0433 - val_accuracy: 0.9876
# Epoch 121/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 0.9854 - val_loss: 0.0430 - val_accuracy: 0.9876
# Epoch 122/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0575 - accuracy: 0.9859 - val_loss: 0.0398 - val_accuracy: 0.9894
# Epoch 123/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0542 - accuracy: 0.9859 - val_loss: 0.0403 - val_accuracy: 0.9885
# Epoch 124/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0534 - accuracy: 0.9854 - val_loss: 0.0418 - val_accuracy: 0.9894
# Epoch 125/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0505 - accuracy: 0.9854 - val_loss: 0.0427 - val_accuracy: 0.9876
# Epoch 126/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0595 - accuracy: 0.9832 - val_loss: 0.0410 - val_accuracy: 0.9894
# Epoch 127/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0574 - accuracy: 0.9834 - val_loss: 0.0413 - val_accuracy: 0.9885
# Epoch 128/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9843 - val_loss: 0.0437 - val_accuracy: 0.9885
# Epoch 129/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9850 - val_loss: 0.0408 - val_accuracy: 0.9903
# Epoch 130/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9861 - val_loss: 0.0407 - val_accuracy: 0.9885
# Epoch 131/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0539 - accuracy: 0.9847 - val_loss: 0.0423 - val_accuracy: 0.9876
# Epoch 132/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 0.9867 - val_loss: 0.0400 - val_accuracy: 0.9894
# Epoch 133/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0520 - accuracy: 0.9870 - val_loss: 0.0404 - val_accuracy: 0.9894
# Epoch 134/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0557 - accuracy: 0.9850 - val_loss: 0.0414 - val_accuracy: 0.9876
# Epoch 135/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.9867 - val_loss: 0.0406 - val_accuracy: 0.9894
# Epoch 136/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0497 - accuracy: 0.9863 - val_loss: 0.0415 - val_accuracy: 0.9885
# Epoch 137/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0515 - accuracy: 0.9863 - val_loss: 0.0438 - val_accuracy: 0.9885
# Epoch 138/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0538 - accuracy: 0.9850 - val_loss: 0.0426 - val_accuracy: 0.9885
# Epoch 139/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 0.9872 - val_loss: 0.0412 - val_accuracy: 0.9885
# Epoch 140/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0495 - accuracy: 0.9859 - val_loss: 0.0408 - val_accuracy: 0.9894
# Epoch 141/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0522 - accuracy: 0.9854 - val_loss: 0.0399 - val_accuracy: 0.9903
# Epoch 142/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0521 - accuracy: 0.9859 - val_loss: 0.0420 - val_accuracy: 0.9876
# Epoch 143/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0514 - accuracy: 0.9863 - val_loss: 0.0411 - val_accuracy: 0.9885
# Epoch 144/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0497 - accuracy: 0.9878 - val_loss: 0.0432 - val_accuracy: 0.9885
# Epoch 145/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0501 - accuracy: 0.9845 - val_loss: 0.0426 - val_accuracy: 0.9885
# Epoch 146/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 0.9845 - val_loss: 0.0412 - val_accuracy: 0.9885
# Epoch 147/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9856 - val_loss: 0.0409 - val_accuracy: 0.9903
# Epoch 148/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0505 - accuracy: 0.9885 - val_loss: 0.0423 - val_accuracy: 0.9885
# Epoch 149/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0475 - accuracy: 0.9883 - val_loss: 0.0401 - val_accuracy: 0.9894
# Epoch 150/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 0.9859 - val_loss: 0.0409 - val_accuracy: 0.9885
# Epoch 151/400
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9872 - val_loss: 0.0401 - val_accuracy: 0.9903
# Epoch 152/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9865 - val_loss: 0.0397 - val_accuracy: 0.9903
# Epoch 153/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0462 - accuracy: 0.9885 - val_loss: 0.0411 - val_accuracy: 0.9903
# Epoch 154/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9881 - val_loss: 0.0411 - val_accuracy: 0.9894
# Epoch 155/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 0.9867 - val_loss: 0.0416 - val_accuracy: 0.9885
# Epoch 156/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 0.9887 - val_loss: 0.0417 - val_accuracy: 0.9885
# Epoch 157/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9878 - val_loss: 0.0410 - val_accuracy: 0.9894
# Epoch 158/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0492 - accuracy: 0.9870 - val_loss: 0.0410 - val_accuracy: 0.9903
# Epoch 159/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0434 - accuracy: 0.9885 - val_loss: 0.0409 - val_accuracy: 0.9903
# Epoch 160/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0514 - accuracy: 0.9872 - val_loss: 0.0407 - val_accuracy: 0.9912
# Epoch 161/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 0.9898 - val_loss: 0.0419 - val_accuracy: 0.9912
# Epoch 162/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.9876 - val_loss: 0.0393 - val_accuracy: 0.9920
# Epoch 163/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9859 - val_loss: 0.0401 - val_accuracy: 0.9903
# Epoch 164/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0410 - accuracy: 0.9867 - val_loss: 0.0391 - val_accuracy: 0.9920
# Epoch 165/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 0.9887 - val_loss: 0.0396 - val_accuracy: 0.9920
# Epoch 166/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.9876 - val_loss: 0.0414 - val_accuracy: 0.9903
# Epoch 167/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 0.9872 - val_loss: 0.0427 - val_accuracy: 0.9903
# Epoch 168/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0416 - accuracy: 0.9867 - val_loss: 0.0423 - val_accuracy: 0.9903
# Epoch 169/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0434 - accuracy: 0.9878 - val_loss: 0.0429 - val_accuracy: 0.9894
# Epoch 170/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 0.9847 - val_loss: 0.0419 - val_accuracy: 0.9912
# Epoch 171/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0471 - accuracy: 0.9874 - val_loss: 0.0415 - val_accuracy: 0.9903
# Epoch 172/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9881 - val_loss: 0.0426 - val_accuracy: 0.9885
# Epoch 173/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 0.9894 - val_loss: 0.0418 - val_accuracy: 0.9894
# Epoch 174/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9885 - val_loss: 0.0423 - val_accuracy: 0.9903
# Epoch 175/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 0.9872 - val_loss: 0.0432 - val_accuracy: 0.9885
# Epoch 176/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9876 - val_loss: 0.0392 - val_accuracy: 0.9920
# Epoch 177/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9874 - val_loss: 0.0426 - val_accuracy: 0.9894
# Epoch 178/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.9881 - val_loss: 0.0415 - val_accuracy: 0.9903
# Epoch 179/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 0.9894 - val_loss: 0.0414 - val_accuracy: 0.9903
# Epoch 180/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 0.9892 - val_loss: 0.0430 - val_accuracy: 0.9903
# Epoch 181/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9894 - val_loss: 0.0424 - val_accuracy: 0.9903
# Epoch 182/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9887 - val_loss: 0.0400 - val_accuracy: 0.9912
# Epoch 183/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0397 - accuracy: 0.9887 - val_loss: 0.0416 - val_accuracy: 0.9903
# Epoch 184/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 0.9885 - val_loss: 0.0426 - val_accuracy: 0.9903
# Epoch 185/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9874 - val_loss: 0.0413 - val_accuracy: 0.9903
# Epoch 186/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0383 - accuracy: 0.9898 - val_loss: 0.0424 - val_accuracy: 0.9912
# Epoch 187/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9874 - val_loss: 0.0398 - val_accuracy: 0.9912
# Epoch 188/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0441 - accuracy: 0.9865 - val_loss: 0.0422 - val_accuracy: 0.9903
# Epoch 189/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9885 - val_loss: 0.0433 - val_accuracy: 0.9903
# Epoch 190/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 0.9892 - val_loss: 0.0413 - val_accuracy: 0.9912
# Epoch 191/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0441 - accuracy: 0.9874 - val_loss: 0.0418 - val_accuracy: 0.9903
# Epoch 192/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9889 - val_loss: 0.0410 - val_accuracy: 0.9912
# Epoch 193/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9881 - val_loss: 0.0403 - val_accuracy: 0.9912
# Epoch 194/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 0.9912 - val_loss: 0.0425 - val_accuracy: 0.9903
# Epoch 195/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0397 - accuracy: 0.9876 - val_loss: 0.0419 - val_accuracy: 0.9903
# Epoch 196/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9887 - val_loss: 0.0419 - val_accuracy: 0.9903
# Epoch 197/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9876 - val_loss: 0.0433 - val_accuracy: 0.9885
# Epoch 198/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9881 - val_loss: 0.0422 - val_accuracy: 0.9912
# Epoch 199/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9901 - val_loss: 0.0436 - val_accuracy: 0.9894
# Epoch 200/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9865 - val_loss: 0.0418 - val_accuracy: 0.9912
# Epoch 201/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0372 - accuracy: 0.9889 - val_loss: 0.0426 - val_accuracy: 0.9912
# Epoch 202/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9901 - val_loss: 0.0438 - val_accuracy: 0.9894
# Epoch 203/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0361 - accuracy: 0.9889 - val_loss: 0.0428 - val_accuracy: 0.9903
# Epoch 204/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9889 - val_loss: 0.0423 - val_accuracy: 0.9912
# Epoch 205/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 0.9896 - val_loss: 0.0447 - val_accuracy: 0.9903
# Epoch 206/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0372 - accuracy: 0.9889 - val_loss: 0.0458 - val_accuracy: 0.9903
# Epoch 207/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 0.9887 - val_loss: 0.0441 - val_accuracy: 0.9903
# Epoch 208/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.0455 - val_accuracy: 0.9903
# Epoch 209/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9881 - val_loss: 0.0456 - val_accuracy: 0.9903
# Epoch 210/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 0.9896 - val_loss: 0.0444 - val_accuracy: 0.9903
# Epoch 211/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9883 - val_loss: 0.0437 - val_accuracy: 0.9903
# Epoch 212/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 0.9872 - val_loss: 0.0445 - val_accuracy: 0.9903
# Epoch 213/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 0.9887 - val_loss: 0.0441 - val_accuracy: 0.9903
# Epoch 214/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9876 - val_loss: 0.0442 - val_accuracy: 0.9912
# Epoch 215/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 0.9889 - val_loss: 0.0453 - val_accuracy: 0.9912
# Epoch 216/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9905 - val_loss: 0.0451 - val_accuracy: 0.9912
# Epoch 217/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9896 - val_loss: 0.0460 - val_accuracy: 0.9903
# Epoch 218/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9878 - val_loss: 0.0435 - val_accuracy: 0.9903
# Epoch 219/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 0.9894 - val_loss: 0.0480 - val_accuracy: 0.9903
# Epoch 220/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9885 - val_loss: 0.0455 - val_accuracy: 0.9912
# Epoch 221/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9889 - val_loss: 0.0460 - val_accuracy: 0.9912
# Epoch 222/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.9867 - val_loss: 0.0450 - val_accuracy: 0.9903
# Epoch 223/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9887 - val_loss: 0.0447 - val_accuracy: 0.9912
# Epoch 224/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 0.9901 - val_loss: 0.0470 - val_accuracy: 0.9903
# Epoch 225/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.0460 - val_accuracy: 0.9903
# Epoch 226/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 0.0459 - val_accuracy: 0.9903
# Epoch 227/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9892 - val_loss: 0.0468 - val_accuracy: 0.9903
# Epoch 228/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9885 - val_loss: 0.0482 - val_accuracy: 0.9903
# Epoch 229/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0360 - accuracy: 0.9901 - val_loss: 0.0475 - val_accuracy: 0.9903
# Epoch 230/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9907 - val_loss: 0.0461 - val_accuracy: 0.9912
# Epoch 231/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9889 - val_loss: 0.0459 - val_accuracy: 0.9912
# Epoch 232/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9896 - val_loss: 0.0464 - val_accuracy: 0.9912
# Epoch 233/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9905 - val_loss: 0.0454 - val_accuracy: 0.9912
# Epoch 234/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9903 - val_loss: 0.0465 - val_accuracy: 0.9912
# Epoch 235/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 0.9918 - val_loss: 0.0474 - val_accuracy: 0.9903
# Epoch 236/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9907 - val_loss: 0.0469 - val_accuracy: 0.9903
# Epoch 237/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9889 - val_loss: 0.0472 - val_accuracy: 0.9903
# Epoch 238/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9898 - val_loss: 0.0464 - val_accuracy: 0.9903
# Epoch 239/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 0.0475 - val_accuracy: 0.9903
# Epoch 240/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9898 - val_loss: 0.0470 - val_accuracy: 0.9903
# Epoch 241/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0360 - accuracy: 0.9883 - val_loss: 0.0459 - val_accuracy: 0.9903
# Epoch 242/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 0.9870 - val_loss: 0.0485 - val_accuracy: 0.9903
# Epoch 243/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9905 - val_loss: 0.0472 - val_accuracy: 0.9903
# Epoch 244/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9887 - val_loss: 0.0477 - val_accuracy: 0.9903
# Epoch 245/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9889 - val_loss: 0.0505 - val_accuracy: 0.9903
# Epoch 246/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.0485 - val_accuracy: 0.9903
# Epoch 247/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 0.9898 - val_loss: 0.0484 - val_accuracy: 0.9912
# Epoch 248/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9907 - val_loss: 0.0493 - val_accuracy: 0.9903
# Epoch 249/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9876 - val_loss: 0.0499 - val_accuracy: 0.9912
# Epoch 250/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9889 - val_loss: 0.0504 - val_accuracy: 0.9903
# Epoch 251/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9920 - val_loss: 0.0499 - val_accuracy: 0.9903
# Epoch 252/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 0.9918 - val_loss: 0.0499 - val_accuracy: 0.9912
# Epoch 253/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.0485 - val_accuracy: 0.9912
# Epoch 254/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0358 - accuracy: 0.9894 - val_loss: 0.0505 - val_accuracy: 0.9903
# Epoch 255/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 0.9885 - val_loss: 0.0501 - val_accuracy: 0.9903
# Epoch 256/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 0.9909 - val_loss: 0.0507 - val_accuracy: 0.9903
# Epoch 257/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9894 - val_loss: 0.0496 - val_accuracy: 0.9903
# Epoch 258/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 0.0515 - val_accuracy: 0.9903
# Epoch 259/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.9901 - val_loss: 0.0529 - val_accuracy: 0.9903
# Epoch 260/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 0.0511 - val_accuracy: 0.9903
# Epoch 261/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9907 - val_loss: 0.0511 - val_accuracy: 0.9903
# Epoch 262/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9912 - val_loss: 0.0502 - val_accuracy: 0.9912
# Epoch 263/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9885 - val_loss: 0.0502 - val_accuracy: 0.9903
# Epoch 264/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.9907 - val_loss: 0.0506 - val_accuracy: 0.9903
# Epoch 265/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 0.0506 - val_accuracy: 0.9903
# Epoch 266/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9914 - val_loss: 0.0488 - val_accuracy: 0.9920
# Epoch 267/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 0.9892 - val_loss: 0.0500 - val_accuracy: 0.9903
# Epoch 268/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9898 - val_loss: 0.0516 - val_accuracy: 0.9903
# Epoch 269/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9892 - val_loss: 0.0511 - val_accuracy: 0.9903
# Epoch 270/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9894 - val_loss: 0.0521 - val_accuracy: 0.9903
# Epoch 271/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.0509 - val_accuracy: 0.9903
# Epoch 272/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9905 - val_loss: 0.0510 - val_accuracy: 0.9903
# Epoch 273/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9887 - val_loss: 0.0512 - val_accuracy: 0.9903
# Epoch 274/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.0511 - val_accuracy: 0.9912
# Epoch 275/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9916 - val_loss: 0.0519 - val_accuracy: 0.9903
# Epoch 276/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9896 - val_loss: 0.0523 - val_accuracy: 0.9903
# Epoch 277/400
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9898 - val_loss: 0.0506 - val_accuracy: 0.9920
# Epoch 278/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 0.9907 - val_loss: 0.0531 - val_accuracy: 0.9903
# Epoch 279/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9901 - val_loss: 0.0534 - val_accuracy: 0.9903
# Epoch 280/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9912 - val_loss: 0.0537 - val_accuracy: 0.9903
# Epoch 281/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.9909 - val_loss: 0.0529 - val_accuracy: 0.9903
# Epoch 282/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 0.9914 - val_loss: 0.0529 - val_accuracy: 0.9903
# Epoch 283/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9916 - val_loss: 0.0527 - val_accuracy: 0.9903
# Epoch 284/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0280 - accuracy: 0.9909 - val_loss: 0.0530 - val_accuracy: 0.9903
# Epoch 285/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.0518 - val_accuracy: 0.9912
# Epoch 286/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9901 - val_loss: 0.0535 - val_accuracy: 0.9903
# Epoch 287/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.9889 - val_loss: 0.0533 - val_accuracy: 0.9912
# Epoch 288/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 0.9894 - val_loss: 0.0545 - val_accuracy: 0.9903
# Epoch 289/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9923 - val_loss: 0.0548 - val_accuracy: 0.9903
# Epoch 290/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0306 - accuracy: 0.9901 - val_loss: 0.0555 - val_accuracy: 0.9903
# Epoch 291/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.0529 - val_accuracy: 0.9912
# Epoch 292/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 0.9905 - val_loss: 0.0561 - val_accuracy: 0.9903
# Epoch 293/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 0.9907 - val_loss: 0.0573 - val_accuracy: 0.9894
# Epoch 294/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 0.9907 - val_loss: 0.0553 - val_accuracy: 0.9912
# Epoch 295/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.0548 - val_accuracy: 0.9912
# Epoch 296/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9918 - val_loss: 0.0563 - val_accuracy: 0.9903
# Epoch 297/400
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.0569 - val_accuracy: 0.9903
# Epoch 298/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 0.0552 - val_accuracy: 0.9912
# Epoch 299/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.9920 - val_loss: 0.0569 - val_accuracy: 0.9903
# Epoch 300/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9916 - val_loss: 0.0576 - val_accuracy: 0.9903
# Epoch 301/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 0.9914 - val_loss: 0.0566 - val_accuracy: 0.9903
# Epoch 302/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9903 - val_loss: 0.0560 - val_accuracy: 0.9920
# Epoch 303/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9901 - val_loss: 0.0580 - val_accuracy: 0.9912
# Epoch 304/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9892 - val_loss: 0.0576 - val_accuracy: 0.9903
# Epoch 305/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9912 - val_loss: 0.0587 - val_accuracy: 0.9903
# Epoch 306/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 0.9896 - val_loss: 0.0574 - val_accuracy: 0.9903
# Epoch 307/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9907 - val_loss: 0.0569 - val_accuracy: 0.9903
# Epoch 308/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 0.9883 - val_loss: 0.0569 - val_accuracy: 0.9903
# Epoch 309/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9907 - val_loss: 0.0579 - val_accuracy: 0.9903
# Epoch 310/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9898 - val_loss: 0.0593 - val_accuracy: 0.9903
# Epoch 311/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9905 - val_loss: 0.0584 - val_accuracy: 0.9903
# Epoch 312/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9912 - val_loss: 0.0601 - val_accuracy: 0.9903
# Epoch 313/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0588 - val_accuracy: 0.9903
# Epoch 314/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 0.9887 - val_loss: 0.0601 - val_accuracy: 0.9903
# Epoch 315/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9909 - val_loss: 0.0581 - val_accuracy: 0.9912
# Epoch 316/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9914 - val_loss: 0.0599 - val_accuracy: 0.9903
# Epoch 317/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9898 - val_loss: 0.0599 - val_accuracy: 0.9903
# Epoch 318/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9901 - val_loss: 0.0574 - val_accuracy: 0.9903
# Epoch 319/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 0.0594 - val_accuracy: 0.9894
# Epoch 320/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 0.9918 - val_loss: 0.0592 - val_accuracy: 0.9894
# Epoch 321/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.9929 - val_loss: 0.0581 - val_accuracy: 0.9903
# Epoch 322/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9896 - val_loss: 0.0565 - val_accuracy: 0.9920
# Epoch 323/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 0.0573 - val_accuracy: 0.9920
# Epoch 324/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9909 - val_loss: 0.0595 - val_accuracy: 0.9912
# Epoch 325/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.9912 - val_loss: 0.0614 - val_accuracy: 0.9903
# Epoch 326/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.9929 - val_loss: 0.0596 - val_accuracy: 0.9920
# Epoch 327/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9914 - val_loss: 0.0602 - val_accuracy: 0.9912
# Epoch 328/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9898 - val_loss: 0.0616 - val_accuracy: 0.9903
# Epoch 329/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9903 - val_loss: 0.0607 - val_accuracy: 0.9912
# Epoch 330/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 0.9881 - val_loss: 0.0593 - val_accuracy: 0.9920
# Epoch 331/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 0.9923 - val_loss: 0.0609 - val_accuracy: 0.9903
# Epoch 332/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.9912 - val_loss: 0.0607 - val_accuracy: 0.9912
# Epoch 333/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9912 - val_loss: 0.0620 - val_accuracy: 0.9903
# Epoch 334/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.0634 - val_accuracy: 0.9903
# Epoch 335/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 0.9881 - val_loss: 0.0625 - val_accuracy: 0.9903
# Epoch 336/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.0616 - val_accuracy: 0.9912
# Epoch 337/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.0638 - val_accuracy: 0.9912
# Epoch 338/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9918 - val_loss: 0.0657 - val_accuracy: 0.9903
# Epoch 339/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 0.9927 - val_loss: 0.0646 - val_accuracy: 0.9903
# Epoch 340/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9920 - val_loss: 0.0639 - val_accuracy: 0.9912
# Epoch 341/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9923 - val_loss: 0.0647 - val_accuracy: 0.9903
# Epoch 342/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.9896 - val_loss: 0.0650 - val_accuracy: 0.9903
# Epoch 343/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9923 - val_loss: 0.0654 - val_accuracy: 0.9903
# Epoch 344/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9914 - val_loss: 0.0660 - val_accuracy: 0.9903
# Epoch 345/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9925 - val_loss: 0.0664 - val_accuracy: 0.9903
# Epoch 346/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9920 - val_loss: 0.0677 - val_accuracy: 0.9903
# Epoch 347/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.0647 - val_accuracy: 0.9920
# Epoch 348/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9912 - val_loss: 0.0656 - val_accuracy: 0.9903
# Epoch 349/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 0.9923 - val_loss: 0.0660 - val_accuracy: 0.9912
# Epoch 350/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9916 - val_loss: 0.0660 - val_accuracy: 0.9920
# Epoch 351/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9889 - val_loss: 0.0665 - val_accuracy: 0.9912
# Epoch 352/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9927 - val_loss: 0.0682 - val_accuracy: 0.9903
# Epoch 353/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9912 - val_loss: 0.0664 - val_accuracy: 0.9903
# Epoch 354/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9927 - val_loss: 0.0652 - val_accuracy: 0.9920
# Epoch 355/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9923 - val_loss: 0.0675 - val_accuracy: 0.9903
# Epoch 356/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.0649 - val_accuracy: 0.9920
# Epoch 357/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 0.9903 - val_loss: 0.0633 - val_accuracy: 0.9920
# Epoch 358/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 0.9909 - val_loss: 0.0671 - val_accuracy: 0.9903
# Epoch 359/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.0680 - val_accuracy: 0.9903
# Epoch 360/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 0.9912 - val_loss: 0.0659 - val_accuracy: 0.9912
# Epoch 361/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9920 - val_loss: 0.0668 - val_accuracy: 0.9903
# Epoch 362/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 0.9916 - val_loss: 0.0673 - val_accuracy: 0.9920
# Epoch 363/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.0681 - val_accuracy: 0.9903
# Epoch 364/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9934 - val_loss: 0.0696 - val_accuracy: 0.9903
# Epoch 365/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9923 - val_loss: 0.0679 - val_accuracy: 0.9920
# Epoch 366/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 0.9912 - val_loss: 0.0692 - val_accuracy: 0.9912
# Epoch 367/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.0707 - val_accuracy: 0.9903
# Epoch 368/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 0.0700 - val_accuracy: 0.9903
# Epoch 369/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.0692 - val_accuracy: 0.9920
# Epoch 370/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.0701 - val_accuracy: 0.9903
# Epoch 371/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9923 - val_loss: 0.0709 - val_accuracy: 0.9903
# Epoch 372/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9927 - val_loss: 0.0726 - val_accuracy: 0.9903
# Epoch 373/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9918 - val_loss: 0.0711 - val_accuracy: 0.9903
# Epoch 374/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9918 - val_loss: 0.0733 - val_accuracy: 0.9903
# Epoch 375/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.9931 - val_loss: 0.0705 - val_accuracy: 0.9912
# Epoch 376/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9925 - val_loss: 0.0710 - val_accuracy: 0.9903
# Epoch 377/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9909 - val_loss: 0.0713 - val_accuracy: 0.9903
# Epoch 378/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 0.9905 - val_loss: 0.0721 - val_accuracy: 0.9903
# Epoch 379/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9925 - val_loss: 0.0715 - val_accuracy: 0.9920
# Epoch 380/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 0.9914 - val_loss: 0.0745 - val_accuracy: 0.9903
# Epoch 381/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9918 - val_loss: 0.0733 - val_accuracy: 0.9912
# Epoch 382/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.0734 - val_accuracy: 0.9920
# Epoch 383/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 0.9892 - val_loss: 0.0743 - val_accuracy: 0.9912
# Epoch 384/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9916 - val_loss: 0.0743 - val_accuracy: 0.9912
# Epoch 385/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9905 - val_loss: 0.0745 - val_accuracy: 0.9912
# Epoch 386/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.0745 - val_accuracy: 0.9912
# Epoch 387/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9903 - val_loss: 0.0768 - val_accuracy: 0.9894
# Epoch 388/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 0.9905 - val_loss: 0.0747 - val_accuracy: 0.9912
# Epoch 389/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9918 - val_loss: 0.0739 - val_accuracy: 0.9920
# Epoch 390/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 0.9905 - val_loss: 0.0739 - val_accuracy: 0.9920
# Epoch 391/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 0.9912 - val_loss: 0.0743 - val_accuracy: 0.9920
# Epoch 392/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.9914 - val_loss: 0.0773 - val_accuracy: 0.9903
# Epoch 393/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9914 - val_loss: 0.0761 - val_accuracy: 0.9912
# Epoch 394/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.0776 - val_accuracy: 0.9903
# Epoch 395/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9940 - val_loss: 0.0760 - val_accuracy: 0.9912
# Epoch 396/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9912 - val_loss: 0.0766 - val_accuracy: 0.9903
# Epoch 397/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9954 - val_loss: 0.0770 - val_accuracy: 0.9920
# Epoch 398/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9931 - val_loss: 0.0793 - val_accuracy: 0.9903
# Epoch 399/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9905 - val_loss: 0.0769 - val_accuracy: 0.9920
# Epoch 400/400
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 0.9916 - val_loss: 0.0799 - val_accuracy: 0.9903
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9903
# [0.07987407594919205, 0.9902740716934204]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 36/36 [==============================] - 0s 1ms/step

# %% [markdown]
# # DNN(R2L)

# %%
import pandas as pd
import numpy as np
import sklearn
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# 소수점 9자리까지 표시
pd.options.display.float_format = '{:.9f}'.format

# df_r2l.csv 파일을 읽어옵니다.
df_r2l = pd.read_csv("/content/drive/MyDrive/attack_name_data/df_r2l.csv")

# 'label' 열을 제외한 데이터를 r2l_loX로 지정합니다.
r2l_loX = df_r2l.drop(['label'], axis=1)

# 'label' 열을 r2lY로 지정합니다.
r2lY = df_r2l['label']

# MinMaxScaler를 사용하여 데이터를 스케일링합니다.
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(r2l_loX)
r2lX = pd.DataFrame(np_scaled, columns=r2l_loX.columns)

# 언더샘플링을 NearMiss로 변경
rus = NearMiss()
dfrus_X, dfrus_Y = rus.fit_resample(r2lX, r2lY)
dfrus_X = pd.DataFrame(dfrus_X, columns=r2lX.columns)

# 훈련 및 테스트 데이터로 분할합니다.
X_train, X_test, y_train, y_test = train_test_split(dfrus_X, dfrus_Y, test_size=0.2, random_state=2022)

# DNN 모델 생성
model = Sequential()
model.add(Dense(16, activation='relu', input_dim=22))
model.add(Dropout(0.1))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# # EarlyStopping 콜백 설정
# early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# # ModelCheckpoint 콜백 설정
# model_checkpoint = ModelCheckpoint('/content/drive/MyDrive/DNN_Model/DNN_r2l_best.h5', save_best_only=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=800, batch_size=64, validation_data=(X_test, y_test))

# 테스트셋 평가
scores = model.evaluate(X_test, y_test)
print(scores)

# 모델 저장
model.save('/content/drive/MyDrive/DNN_Model/DNN_r2l.h5')

# 손실 및 정확도 그래프
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 데이터에 대한 예측 확률
y_pred_prob = model.predict(X_test)

# 확률을 클래스로 변환 (임계값은 예시로 0.5)
threshold = 0.5
y_pred = np.where(y_pred_prob > threshold, 1, 0)

# 혼동 행렬을 시각화
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Epoch 1/800
# 19/19 [==============================] - 1s 13ms/step - loss: 0.7040 - accuracy: 0.4996 - val_loss: 0.6984 - val_accuracy: 0.4815
# Epoch 2/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6970 - accuracy: 0.5147 - val_loss: 0.6924 - val_accuracy: 0.5455
# Epoch 3/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.5324 - val_loss: 0.6889 - val_accuracy: 0.5421
# Epoch 4/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 0.5493 - val_loss: 0.6855 - val_accuracy: 0.5791
# Epoch 5/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6874 - accuracy: 0.5476 - val_loss: 0.6805 - val_accuracy: 0.6162
# Epoch 6/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6856 - accuracy: 0.5543 - val_loss: 0.6767 - val_accuracy: 0.6128
# Epoch 7/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.5847 - val_loss: 0.6729 - val_accuracy: 0.6229
# Epoch 8/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6751 - accuracy: 0.5889 - val_loss: 0.6680 - val_accuracy: 0.6128
# Epoch 9/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6706 - accuracy: 0.5678 - val_loss: 0.6609 - val_accuracy: 0.6128
# Epoch 10/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6629 - accuracy: 0.6167 - val_loss: 0.6506 - val_accuracy: 0.7172
# Epoch 11/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6519 - accuracy: 0.6824 - val_loss: 0.6345 - val_accuracy: 0.7643
# Epoch 12/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6396 - accuracy: 0.6858 - val_loss: 0.6217 - val_accuracy: 0.7710
# Epoch 13/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6306 - accuracy: 0.6891 - val_loss: 0.6082 - val_accuracy: 0.7609
# Epoch 14/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6151 - accuracy: 0.7051 - val_loss: 0.5941 - val_accuracy: 0.8182
# Epoch 15/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6100 - accuracy: 0.6984 - val_loss: 0.5798 - val_accuracy: 0.8182
# Epoch 16/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5883 - accuracy: 0.7186 - val_loss: 0.5659 - val_accuracy: 0.7811
# Epoch 17/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5861 - accuracy: 0.7127 - val_loss: 0.5539 - val_accuracy: 0.8283
# Epoch 18/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5722 - accuracy: 0.7254 - val_loss: 0.5414 - val_accuracy: 0.7879
# Epoch 19/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5583 - accuracy: 0.7254 - val_loss: 0.5275 - val_accuracy: 0.8249
# Epoch 20/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5448 - accuracy: 0.7372 - val_loss: 0.5172 - val_accuracy: 0.8013
# Epoch 21/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5387 - accuracy: 0.7287 - val_loss: 0.5055 - val_accuracy: 0.7811
# Epoch 22/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5164 - accuracy: 0.7532 - val_loss: 0.4929 - val_accuracy: 0.8114
# Epoch 23/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5231 - accuracy: 0.7279 - val_loss: 0.4808 - val_accuracy: 0.7778
# Epoch 24/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5012 - accuracy: 0.7624 - val_loss: 0.4683 - val_accuracy: 0.8384
# Epoch 25/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5024 - accuracy: 0.7489 - val_loss: 0.4590 - val_accuracy: 0.8047
# Epoch 26/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4955 - accuracy: 0.7473 - val_loss: 0.4551 - val_accuracy: 0.8249
# Epoch 27/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4713 - accuracy: 0.7810 - val_loss: 0.4461 - val_accuracy: 0.8586
# Epoch 28/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4751 - accuracy: 0.7759 - val_loss: 0.4402 - val_accuracy: 0.8316
# Epoch 29/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4726 - accuracy: 0.7709 - val_loss: 0.4382 - val_accuracy: 0.8418
# Epoch 30/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4805 - accuracy: 0.7734 - val_loss: 0.4342 - val_accuracy: 0.8384
# Epoch 31/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4601 - accuracy: 0.7860 - val_loss: 0.4280 - val_accuracy: 0.8384
# Epoch 32/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4480 - accuracy: 0.7961 - val_loss: 0.4259 - val_accuracy: 0.8350
# Epoch 33/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4705 - accuracy: 0.7767 - val_loss: 0.4222 - val_accuracy: 0.8350
# Epoch 34/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4582 - accuracy: 0.7894 - val_loss: 0.4203 - val_accuracy: 0.8384
# Epoch 35/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4463 - accuracy: 0.7852 - val_loss: 0.4196 - val_accuracy: 0.8384
# Epoch 36/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4389 - accuracy: 0.8079 - val_loss: 0.4169 - val_accuracy: 0.8350
# Epoch 37/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4463 - accuracy: 0.7894 - val_loss: 0.4156 - val_accuracy: 0.8283
# Epoch 38/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4363 - accuracy: 0.8104 - val_loss: 0.4111 - val_accuracy: 0.8249
# Epoch 39/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4271 - accuracy: 0.8104 - val_loss: 0.4079 - val_accuracy: 0.8283
# Epoch 40/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4273 - accuracy: 0.7953 - val_loss: 0.4037 - val_accuracy: 0.8249
# Epoch 41/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4375 - accuracy: 0.8138 - val_loss: 0.4029 - val_accuracy: 0.8418
# Epoch 42/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4238 - accuracy: 0.8012 - val_loss: 0.4025 - val_accuracy: 0.8316
# Epoch 43/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.8222 - val_loss: 0.3975 - val_accuracy: 0.8316
# Epoch 44/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4119 - accuracy: 0.8214 - val_loss: 0.3937 - val_accuracy: 0.8384
# Epoch 45/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4089 - accuracy: 0.8172 - val_loss: 0.3964 - val_accuracy: 0.8451
# Epoch 46/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.8256 - val_loss: 0.3974 - val_accuracy: 0.8249
# Epoch 47/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4133 - accuracy: 0.8096 - val_loss: 0.3920 - val_accuracy: 0.8316
# Epoch 48/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4006 - accuracy: 0.8189 - val_loss: 0.3922 - val_accuracy: 0.8350
# Epoch 49/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4140 - accuracy: 0.8062 - val_loss: 0.3885 - val_accuracy: 0.8418
# Epoch 50/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3975 - accuracy: 0.8281 - val_loss: 0.3867 - val_accuracy: 0.8350
# Epoch 51/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4001 - accuracy: 0.8189 - val_loss: 0.3955 - val_accuracy: 0.8283
# Epoch 52/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3938 - accuracy: 0.8290 - val_loss: 0.3844 - val_accuracy: 0.8350
# Epoch 53/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3960 - accuracy: 0.8281 - val_loss: 0.3861 - val_accuracy: 0.8350
# Epoch 54/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3876 - accuracy: 0.8214 - val_loss: 0.3821 - val_accuracy: 0.8384
# Epoch 55/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3983 - accuracy: 0.8155 - val_loss: 0.3903 - val_accuracy: 0.8215
# Epoch 56/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3957 - accuracy: 0.8206 - val_loss: 0.3829 - val_accuracy: 0.8384
# Epoch 57/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3978 - accuracy: 0.8222 - val_loss: 0.3812 - val_accuracy: 0.8451
# Epoch 58/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3854 - accuracy: 0.8214 - val_loss: 0.3811 - val_accuracy: 0.8418
# Epoch 59/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3868 - accuracy: 0.8273 - val_loss: 0.3805 - val_accuracy: 0.8822
# Epoch 60/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3919 - accuracy: 0.8265 - val_loss: 0.3840 - val_accuracy: 0.8451
# Epoch 61/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3827 - accuracy: 0.8256 - val_loss: 0.3815 - val_accuracy: 0.8316
# Epoch 62/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3831 - accuracy: 0.8307 - val_loss: 0.3777 - val_accuracy: 0.8384
# Epoch 63/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3831 - accuracy: 0.8239 - val_loss: 0.3801 - val_accuracy: 0.8350
# Epoch 64/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3706 - accuracy: 0.8399 - val_loss: 0.3771 - val_accuracy: 0.8451
# Epoch 65/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3788 - accuracy: 0.8315 - val_loss: 0.3768 - val_accuracy: 0.8384
# Epoch 66/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3842 - accuracy: 0.8374 - val_loss: 0.3782 - val_accuracy: 0.8418
# Epoch 67/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3774 - accuracy: 0.8382 - val_loss: 0.3779 - val_accuracy: 0.8653
# Epoch 68/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3698 - accuracy: 0.8382 - val_loss: 0.3765 - val_accuracy: 0.8721
# Epoch 69/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3732 - accuracy: 0.8399 - val_loss: 0.3767 - val_accuracy: 0.8418
# Epoch 70/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3710 - accuracy: 0.8332 - val_loss: 0.3748 - val_accuracy: 0.8754
# Epoch 71/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8399 - val_loss: 0.3754 - val_accuracy: 0.8451
# Epoch 72/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3584 - accuracy: 0.8543 - val_loss: 0.3725 - val_accuracy: 0.8923
# Epoch 73/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3597 - accuracy: 0.8517 - val_loss: 0.3742 - val_accuracy: 0.8418
# Epoch 74/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8332 - val_loss: 0.3728 - val_accuracy: 0.8451
# Epoch 75/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3555 - accuracy: 0.8509 - val_loss: 0.3711 - val_accuracy: 0.8451
# Epoch 76/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8324 - val_loss: 0.3733 - val_accuracy: 0.8451
# Epoch 77/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3606 - accuracy: 0.8500 - val_loss: 0.3717 - val_accuracy: 0.8451
# Epoch 78/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3727 - accuracy: 0.8433 - val_loss: 0.3754 - val_accuracy: 0.8418
# Epoch 79/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3679 - accuracy: 0.8467 - val_loss: 0.3755 - val_accuracy: 0.8384
# Epoch 80/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3750 - accuracy: 0.8357 - val_loss: 0.3747 - val_accuracy: 0.8451
# Epoch 81/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3596 - accuracy: 0.8467 - val_loss: 0.3722 - val_accuracy: 0.8485
# Epoch 82/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8408 - val_loss: 0.3729 - val_accuracy: 0.8754
# Epoch 83/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3538 - accuracy: 0.8467 - val_loss: 0.3728 - val_accuracy: 0.8586
# Epoch 84/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3459 - accuracy: 0.8534 - val_loss: 0.3706 - val_accuracy: 0.8485
# Epoch 85/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3509 - accuracy: 0.8526 - val_loss: 0.3743 - val_accuracy: 0.8418
# Epoch 86/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3477 - accuracy: 0.8551 - val_loss: 0.3731 - val_accuracy: 0.8552
# Epoch 87/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3522 - accuracy: 0.8534 - val_loss: 0.3749 - val_accuracy: 0.8316
# Epoch 88/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3400 - accuracy: 0.8618 - val_loss: 0.3735 - val_accuracy: 0.8788
# Epoch 89/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3384 - accuracy: 0.8593 - val_loss: 0.3733 - val_accuracy: 0.8316
# Epoch 90/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3420 - accuracy: 0.8467 - val_loss: 0.3694 - val_accuracy: 0.8653
# Epoch 91/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3452 - accuracy: 0.8568 - val_loss: 0.3722 - val_accuracy: 0.8519
# Epoch 92/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3481 - accuracy: 0.8467 - val_loss: 0.3695 - val_accuracy: 0.8653
# Epoch 93/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3430 - accuracy: 0.8627 - val_loss: 0.3679 - val_accuracy: 0.8754
# Epoch 94/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3519 - accuracy: 0.8559 - val_loss: 0.3669 - val_accuracy: 0.8552
# Epoch 95/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3432 - accuracy: 0.8475 - val_loss: 0.3696 - val_accuracy: 0.8451
# Epoch 96/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3466 - accuracy: 0.8551 - val_loss: 0.3690 - val_accuracy: 0.8754
# Epoch 97/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3336 - accuracy: 0.8627 - val_loss: 0.3716 - val_accuracy: 0.8519
# Epoch 98/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3354 - accuracy: 0.8728 - val_loss: 0.3739 - val_accuracy: 0.8418
# Epoch 99/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3369 - accuracy: 0.8618 - val_loss: 0.3688 - val_accuracy: 0.8586
# Epoch 100/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3479 - accuracy: 0.8576 - val_loss: 0.3752 - val_accuracy: 0.8754
# Epoch 101/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3364 - accuracy: 0.8635 - val_loss: 0.3706 - val_accuracy: 0.8889
# Epoch 102/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3392 - accuracy: 0.8517 - val_loss: 0.3750 - val_accuracy: 0.8754
# Epoch 103/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3330 - accuracy: 0.8593 - val_loss: 0.3717 - val_accuracy: 0.8788
# Epoch 104/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3282 - accuracy: 0.8686 - val_loss: 0.3700 - val_accuracy: 0.8653
# Epoch 105/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3350 - accuracy: 0.8644 - val_loss: 0.3706 - val_accuracy: 0.8889
# Epoch 106/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3353 - accuracy: 0.8635 - val_loss: 0.3687 - val_accuracy: 0.8418
# Epoch 107/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3271 - accuracy: 0.8610 - val_loss: 0.3700 - val_accuracy: 0.8721
# Epoch 108/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3320 - accuracy: 0.8585 - val_loss: 0.3722 - val_accuracy: 0.8822
# Epoch 109/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3285 - accuracy: 0.8736 - val_loss: 0.3698 - val_accuracy: 0.8754
# Epoch 110/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.8736 - val_loss: 0.3729 - val_accuracy: 0.8956
# Epoch 111/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3106 - accuracy: 0.8753 - val_loss: 0.3687 - val_accuracy: 0.8754
# Epoch 112/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3246 - accuracy: 0.8778 - val_loss: 0.3676 - val_accuracy: 0.8822
# Epoch 113/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3309 - accuracy: 0.8610 - val_loss: 0.3713 - val_accuracy: 0.8687
# Epoch 114/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3222 - accuracy: 0.8677 - val_loss: 0.3746 - val_accuracy: 0.8923
# Epoch 115/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3181 - accuracy: 0.8837 - val_loss: 0.3673 - val_accuracy: 0.8653
# Epoch 116/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3202 - accuracy: 0.8677 - val_loss: 0.3725 - val_accuracy: 0.8822
# Epoch 117/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3188 - accuracy: 0.8677 - val_loss: 0.3725 - val_accuracy: 0.8721
# Epoch 118/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3223 - accuracy: 0.8762 - val_loss: 0.3691 - val_accuracy: 0.8788
# Epoch 119/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3225 - accuracy: 0.8610 - val_loss: 0.3769 - val_accuracy: 0.8889
# Epoch 120/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3221 - accuracy: 0.8686 - val_loss: 0.3733 - val_accuracy: 0.8687
# Epoch 121/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3149 - accuracy: 0.8854 - val_loss: 0.3708 - val_accuracy: 0.8620
# Epoch 122/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3173 - accuracy: 0.8762 - val_loss: 0.3694 - val_accuracy: 0.8990
# Epoch 123/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3060 - accuracy: 0.8795 - val_loss: 0.3731 - val_accuracy: 0.8586
# Epoch 124/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3276 - accuracy: 0.8660 - val_loss: 0.3714 - val_accuracy: 0.8889
# Epoch 125/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3251 - accuracy: 0.8745 - val_loss: 0.3715 - val_accuracy: 0.8754
# Epoch 126/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3092 - accuracy: 0.8770 - val_loss: 0.3810 - val_accuracy: 0.8687
# Epoch 127/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3078 - accuracy: 0.8736 - val_loss: 0.3789 - val_accuracy: 0.8384
# Epoch 128/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3104 - accuracy: 0.8728 - val_loss: 0.3818 - val_accuracy: 0.8687
# Epoch 129/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3316 - accuracy: 0.8736 - val_loss: 0.3726 - val_accuracy: 0.8687
# Epoch 130/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3197 - accuracy: 0.8745 - val_loss: 0.3696 - val_accuracy: 0.8822
# Epoch 131/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3062 - accuracy: 0.8703 - val_loss: 0.3802 - val_accuracy: 0.8721
# Epoch 132/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3124 - accuracy: 0.8736 - val_loss: 0.3702 - val_accuracy: 0.8923
# Epoch 133/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3037 - accuracy: 0.8753 - val_loss: 0.3807 - val_accuracy: 0.8350
# Epoch 134/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3161 - accuracy: 0.8804 - val_loss: 0.3760 - val_accuracy: 0.8855
# Epoch 135/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3118 - accuracy: 0.8753 - val_loss: 0.3690 - val_accuracy: 0.8923
# Epoch 136/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3071 - accuracy: 0.8787 - val_loss: 0.3741 - val_accuracy: 0.8586
# Epoch 137/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3130 - accuracy: 0.8821 - val_loss: 0.3737 - val_accuracy: 0.8855
# Epoch 138/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3057 - accuracy: 0.8778 - val_loss: 0.3802 - val_accuracy: 0.8822
# Epoch 139/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3113 - accuracy: 0.8795 - val_loss: 0.3706 - val_accuracy: 0.8822
# Epoch 140/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3053 - accuracy: 0.8787 - val_loss: 0.3700 - val_accuracy: 0.8754
# Epoch 141/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3098 - accuracy: 0.8719 - val_loss: 0.3723 - val_accuracy: 0.8822
# Epoch 142/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.8762 - val_loss: 0.3717 - val_accuracy: 0.8754
# Epoch 143/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2968 - accuracy: 0.8812 - val_loss: 0.3762 - val_accuracy: 0.8754
# Epoch 144/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3097 - accuracy: 0.8686 - val_loss: 0.3761 - val_accuracy: 0.8687
# Epoch 145/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3028 - accuracy: 0.8745 - val_loss: 0.3738 - val_accuracy: 0.8687
# Epoch 146/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3072 - accuracy: 0.8778 - val_loss: 0.3743 - val_accuracy: 0.8788
# Epoch 147/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3004 - accuracy: 0.8686 - val_loss: 0.3852 - val_accuracy: 0.8822
# Epoch 148/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3126 - accuracy: 0.8812 - val_loss: 0.3680 - val_accuracy: 0.8855
# Epoch 149/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3066 - accuracy: 0.8812 - val_loss: 0.3732 - val_accuracy: 0.8855
# Epoch 150/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2948 - accuracy: 0.8913 - val_loss: 0.3719 - val_accuracy: 0.8822
# Epoch 151/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2968 - accuracy: 0.8964 - val_loss: 0.3685 - val_accuracy: 0.8990
# Epoch 152/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2943 - accuracy: 0.8846 - val_loss: 0.3696 - val_accuracy: 0.8990
# Epoch 153/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2839 - accuracy: 0.8863 - val_loss: 0.3786 - val_accuracy: 0.8923
# Epoch 154/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2907 - accuracy: 0.8854 - val_loss: 0.3720 - val_accuracy: 0.8822
# Epoch 155/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2910 - accuracy: 0.8829 - val_loss: 0.3775 - val_accuracy: 0.8316
# Epoch 156/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2902 - accuracy: 0.8863 - val_loss: 0.3825 - val_accuracy: 0.8855
# Epoch 157/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2989 - accuracy: 0.8829 - val_loss: 0.3742 - val_accuracy: 0.8822
# Epoch 158/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3172 - accuracy: 0.8753 - val_loss: 0.3718 - val_accuracy: 0.8923
# Epoch 159/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3060 - accuracy: 0.8787 - val_loss: 0.3759 - val_accuracy: 0.8889
# Epoch 160/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2891 - accuracy: 0.8863 - val_loss: 0.3745 - val_accuracy: 0.8889
# Epoch 161/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2860 - accuracy: 0.8922 - val_loss: 0.3729 - val_accuracy: 0.8687
# Epoch 162/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2899 - accuracy: 0.8888 - val_loss: 0.3768 - val_accuracy: 0.8855
# Epoch 163/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3046 - accuracy: 0.8736 - val_loss: 0.3748 - val_accuracy: 0.8822
# Epoch 164/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2940 - accuracy: 0.8829 - val_loss: 0.3824 - val_accuracy: 0.8923
# Epoch 165/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2903 - accuracy: 0.8863 - val_loss: 0.3883 - val_accuracy: 0.8384
# Epoch 166/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3026 - accuracy: 0.8703 - val_loss: 0.3793 - val_accuracy: 0.8923
# Epoch 167/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2861 - accuracy: 0.8888 - val_loss: 0.3755 - val_accuracy: 0.8889
# Epoch 168/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.8896 - val_loss: 0.3789 - val_accuracy: 0.8653
# Epoch 169/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2889 - accuracy: 0.8922 - val_loss: 0.3745 - val_accuracy: 0.8788
# Epoch 170/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2889 - accuracy: 0.8871 - val_loss: 0.3758 - val_accuracy: 0.8990
# Epoch 171/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2866 - accuracy: 0.8905 - val_loss: 0.3824 - val_accuracy: 0.8889
# Epoch 172/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2870 - accuracy: 0.8812 - val_loss: 0.3759 - val_accuracy: 0.8788
# Epoch 173/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2822 - accuracy: 0.8871 - val_loss: 0.3801 - val_accuracy: 0.8889
# Epoch 174/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2885 - accuracy: 0.8896 - val_loss: 0.3760 - val_accuracy: 0.8822
# Epoch 175/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2950 - accuracy: 0.8745 - val_loss: 0.3832 - val_accuracy: 0.8350
# Epoch 176/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2805 - accuracy: 0.8922 - val_loss: 0.3790 - val_accuracy: 0.8889
# Epoch 177/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2847 - accuracy: 0.8863 - val_loss: 0.3749 - val_accuracy: 0.8822
# Epoch 178/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2888 - accuracy: 0.8955 - val_loss: 0.3724 - val_accuracy: 0.8990
# Epoch 179/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2861 - accuracy: 0.8947 - val_loss: 0.3766 - val_accuracy: 0.8620
# Epoch 180/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2751 - accuracy: 0.8947 - val_loss: 0.3802 - val_accuracy: 0.8889
# Epoch 181/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2863 - accuracy: 0.8955 - val_loss: 0.3747 - val_accuracy: 0.8889
# Epoch 182/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2874 - accuracy: 0.8837 - val_loss: 0.3776 - val_accuracy: 0.8855
# Epoch 183/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2839 - accuracy: 0.8930 - val_loss: 0.3879 - val_accuracy: 0.8485
# Epoch 184/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2881 - accuracy: 0.8854 - val_loss: 0.3769 - val_accuracy: 0.8855
# Epoch 185/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2733 - accuracy: 0.8981 - val_loss: 0.3799 - val_accuracy: 0.8956
# Epoch 186/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2945 - accuracy: 0.8745 - val_loss: 0.3757 - val_accuracy: 0.8788
# Epoch 187/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2754 - accuracy: 0.8939 - val_loss: 0.3761 - val_accuracy: 0.8956
# Epoch 188/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2903 - accuracy: 0.8905 - val_loss: 0.3826 - val_accuracy: 0.8889
# Epoch 189/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2844 - accuracy: 0.8947 - val_loss: 0.3772 - val_accuracy: 0.8923
# Epoch 190/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2817 - accuracy: 0.8871 - val_loss: 0.3796 - val_accuracy: 0.8788
# Epoch 191/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2823 - accuracy: 0.8880 - val_loss: 0.3811 - val_accuracy: 0.8855
# Epoch 192/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2995 - accuracy: 0.8863 - val_loss: 0.3766 - val_accuracy: 0.8855
# Epoch 193/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2758 - accuracy: 0.8947 - val_loss: 0.3862 - val_accuracy: 0.8788
# Epoch 194/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2868 - accuracy: 0.8821 - val_loss: 0.3855 - val_accuracy: 0.8923
# Epoch 195/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 0.8972 - val_loss: 0.3772 - val_accuracy: 0.8889
# Epoch 196/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2696 - accuracy: 0.9031 - val_loss: 0.3795 - val_accuracy: 0.8754
# Epoch 197/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2796 - accuracy: 0.8930 - val_loss: 0.3820 - val_accuracy: 0.8923
# Epoch 198/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2683 - accuracy: 0.9023 - val_loss: 0.3774 - val_accuracy: 0.8889
# Epoch 199/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2808 - accuracy: 0.8896 - val_loss: 0.3865 - val_accuracy: 0.8923
# Epoch 200/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2675 - accuracy: 0.8939 - val_loss: 0.3835 - val_accuracy: 0.8822
# Epoch 201/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2700 - accuracy: 0.8871 - val_loss: 0.3854 - val_accuracy: 0.8923
# Epoch 202/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2768 - accuracy: 0.8888 - val_loss: 0.3824 - val_accuracy: 0.8889
# Epoch 203/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2739 - accuracy: 0.8871 - val_loss: 0.3865 - val_accuracy: 0.8855
# Epoch 204/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.8964 - val_loss: 0.3852 - val_accuracy: 0.8754
# Epoch 205/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2699 - accuracy: 0.8955 - val_loss: 0.3854 - val_accuracy: 0.8956
# Epoch 206/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2624 - accuracy: 0.8922 - val_loss: 0.3860 - val_accuracy: 0.8923
# Epoch 207/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2716 - accuracy: 0.8955 - val_loss: 0.3896 - val_accuracy: 0.8956
# Epoch 208/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2801 - accuracy: 0.8905 - val_loss: 0.3842 - val_accuracy: 0.8889
# Epoch 209/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2738 - accuracy: 0.8896 - val_loss: 0.3890 - val_accuracy: 0.8956
# Epoch 210/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2763 - accuracy: 0.8955 - val_loss: 0.3848 - val_accuracy: 0.8653
# Epoch 211/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2775 - accuracy: 0.8905 - val_loss: 0.3816 - val_accuracy: 0.8889
# Epoch 212/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2752 - accuracy: 0.8888 - val_loss: 0.4027 - val_accuracy: 0.8788
# Epoch 213/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2861 - accuracy: 0.8905 - val_loss: 0.3811 - val_accuracy: 0.8822
# Epoch 214/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2692 - accuracy: 0.8922 - val_loss: 0.3850 - val_accuracy: 0.8855
# Epoch 215/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2690 - accuracy: 0.8981 - val_loss: 0.3943 - val_accuracy: 0.8788
# Epoch 216/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2600 - accuracy: 0.9006 - val_loss: 0.3938 - val_accuracy: 0.8721
# Epoch 217/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2806 - accuracy: 0.8913 - val_loss: 0.4046 - val_accuracy: 0.8754
# Epoch 218/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2744 - accuracy: 0.8871 - val_loss: 0.3910 - val_accuracy: 0.8956
# Epoch 219/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2643 - accuracy: 0.8989 - val_loss: 0.3858 - val_accuracy: 0.8889
# Epoch 220/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2728 - accuracy: 0.8880 - val_loss: 0.3860 - val_accuracy: 0.8889
# Epoch 221/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2729 - accuracy: 0.8972 - val_loss: 0.3860 - val_accuracy: 0.8889
# Epoch 222/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2602 - accuracy: 0.9006 - val_loss: 0.3896 - val_accuracy: 0.8788
# Epoch 223/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2683 - accuracy: 0.8939 - val_loss: 0.3846 - val_accuracy: 0.8889
# Epoch 224/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2626 - accuracy: 0.8981 - val_loss: 0.3908 - val_accuracy: 0.8923
# Epoch 225/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2695 - accuracy: 0.8955 - val_loss: 0.3959 - val_accuracy: 0.8855
# Epoch 226/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2619 - accuracy: 0.8981 - val_loss: 0.3881 - val_accuracy: 0.8855
# Epoch 227/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2651 - accuracy: 0.8989 - val_loss: 0.3850 - val_accuracy: 0.8990
# Epoch 228/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2737 - accuracy: 0.8854 - val_loss: 0.3938 - val_accuracy: 0.8721
# Epoch 229/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2640 - accuracy: 0.9023 - val_loss: 0.3857 - val_accuracy: 0.8923
# Epoch 230/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2700 - accuracy: 0.8896 - val_loss: 0.3875 - val_accuracy: 0.8923
# Epoch 231/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2686 - accuracy: 0.8922 - val_loss: 0.3863 - val_accuracy: 0.8956
# Epoch 232/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2678 - accuracy: 0.8930 - val_loss: 0.3869 - val_accuracy: 0.8956
# Epoch 233/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2581 - accuracy: 0.9023 - val_loss: 0.3907 - val_accuracy: 0.8822
# Epoch 234/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2723 - accuracy: 0.8964 - val_loss: 0.3907 - val_accuracy: 0.8822
# Epoch 235/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2761 - accuracy: 0.8922 - val_loss: 0.3897 - val_accuracy: 0.8956
# Epoch 236/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2671 - accuracy: 0.8997 - val_loss: 0.3899 - val_accuracy: 0.8956
# Epoch 237/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2629 - accuracy: 0.9014 - val_loss: 0.3900 - val_accuracy: 0.8923
# Epoch 238/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2725 - accuracy: 0.8905 - val_loss: 0.4070 - val_accuracy: 0.8788
# Epoch 239/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2746 - accuracy: 0.8821 - val_loss: 0.3895 - val_accuracy: 0.8855
# Epoch 240/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2651 - accuracy: 0.8972 - val_loss: 0.3904 - val_accuracy: 0.8889
# Epoch 241/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2554 - accuracy: 0.9023 - val_loss: 0.3875 - val_accuracy: 0.8990
# Epoch 242/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2613 - accuracy: 0.8997 - val_loss: 0.3901 - val_accuracy: 0.8889
# Epoch 243/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2685 - accuracy: 0.8939 - val_loss: 0.3978 - val_accuracy: 0.8889
# Epoch 244/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2625 - accuracy: 0.8939 - val_loss: 0.3936 - val_accuracy: 0.8889
# Epoch 245/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2751 - accuracy: 0.8922 - val_loss: 0.4062 - val_accuracy: 0.8788
# Epoch 246/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2625 - accuracy: 0.9048 - val_loss: 0.3931 - val_accuracy: 0.8855
# Epoch 247/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2555 - accuracy: 0.9023 - val_loss: 0.3991 - val_accuracy: 0.8923
# Epoch 248/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2598 - accuracy: 0.8955 - val_loss: 0.3992 - val_accuracy: 0.8923
# Epoch 249/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2547 - accuracy: 0.8939 - val_loss: 0.3903 - val_accuracy: 0.8923
# Epoch 250/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2688 - accuracy: 0.9023 - val_loss: 0.3942 - val_accuracy: 0.8923
# Epoch 251/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2600 - accuracy: 0.8955 - val_loss: 0.3922 - val_accuracy: 0.8990
# Epoch 252/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2668 - accuracy: 0.8947 - val_loss: 0.3971 - val_accuracy: 0.8990
# Epoch 253/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2619 - accuracy: 0.9023 - val_loss: 0.3874 - val_accuracy: 0.8788
# Epoch 254/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2644 - accuracy: 0.8955 - val_loss: 0.3932 - val_accuracy: 0.8889
# Epoch 255/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2574 - accuracy: 0.9040 - val_loss: 0.3948 - val_accuracy: 0.8956
# Epoch 256/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2594 - accuracy: 0.8972 - val_loss: 0.3948 - val_accuracy: 0.8956
# Epoch 257/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2593 - accuracy: 0.9006 - val_loss: 0.3946 - val_accuracy: 0.8822
# Epoch 258/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2693 - accuracy: 0.8913 - val_loss: 0.4103 - val_accuracy: 0.8822
# Epoch 259/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2724 - accuracy: 0.8930 - val_loss: 0.3966 - val_accuracy: 0.8923
# Epoch 260/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2549 - accuracy: 0.8981 - val_loss: 0.4037 - val_accuracy: 0.8923
# Epoch 261/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2611 - accuracy: 0.8964 - val_loss: 0.3988 - val_accuracy: 0.8923
# Epoch 262/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2626 - accuracy: 0.9023 - val_loss: 0.4027 - val_accuracy: 0.8990
# Epoch 263/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2489 - accuracy: 0.9014 - val_loss: 0.3998 - val_accuracy: 0.8721
# Epoch 264/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2489 - accuracy: 0.9040 - val_loss: 0.4002 - val_accuracy: 0.8923
# Epoch 265/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2644 - accuracy: 0.8905 - val_loss: 0.4027 - val_accuracy: 0.8956
# Epoch 266/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2646 - accuracy: 0.8939 - val_loss: 0.4005 - val_accuracy: 0.8956
# Epoch 267/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2572 - accuracy: 0.9056 - val_loss: 0.3967 - val_accuracy: 0.8923
# Epoch 268/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2555 - accuracy: 0.9006 - val_loss: 0.3950 - val_accuracy: 0.8923
# Epoch 269/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2566 - accuracy: 0.9031 - val_loss: 0.4020 - val_accuracy: 0.8923
# Epoch 270/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2589 - accuracy: 0.8989 - val_loss: 0.4027 - val_accuracy: 0.8923
# Epoch 271/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2599 - accuracy: 0.8981 - val_loss: 0.3983 - val_accuracy: 0.8889
# Epoch 272/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2646 - accuracy: 0.9023 - val_loss: 0.4118 - val_accuracy: 0.8889
# Epoch 273/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2773 - accuracy: 0.8955 - val_loss: 0.4133 - val_accuracy: 0.8956
# Epoch 274/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2578 - accuracy: 0.8947 - val_loss: 0.4033 - val_accuracy: 0.8889
# Epoch 275/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2684 - accuracy: 0.8939 - val_loss: 0.4144 - val_accuracy: 0.8956
# Epoch 276/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2638 - accuracy: 0.8930 - val_loss: 0.4021 - val_accuracy: 0.8923
# Epoch 277/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2670 - accuracy: 0.9006 - val_loss: 0.4134 - val_accuracy: 0.8519
# Epoch 278/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2519 - accuracy: 0.9014 - val_loss: 0.4082 - val_accuracy: 0.8956
# Epoch 279/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2481 - accuracy: 0.9040 - val_loss: 0.4111 - val_accuracy: 0.8586
# Epoch 280/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2683 - accuracy: 0.8922 - val_loss: 0.3990 - val_accuracy: 0.8923
# Epoch 281/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2624 - accuracy: 0.9031 - val_loss: 0.4032 - val_accuracy: 0.8889
# Epoch 282/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2662 - accuracy: 0.8939 - val_loss: 0.4042 - val_accuracy: 0.8889
# Epoch 283/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2653 - accuracy: 0.8964 - val_loss: 0.4067 - val_accuracy: 0.8956
# Epoch 284/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2547 - accuracy: 0.9090 - val_loss: 0.4085 - val_accuracy: 0.8822
# Epoch 285/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2497 - accuracy: 0.9073 - val_loss: 0.4053 - val_accuracy: 0.8855
# Epoch 286/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2521 - accuracy: 0.9048 - val_loss: 0.4078 - val_accuracy: 0.8956
# Epoch 287/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2587 - accuracy: 0.8947 - val_loss: 0.4022 - val_accuracy: 0.8923
# Epoch 288/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.8972 - val_loss: 0.4093 - val_accuracy: 0.8956
# Epoch 289/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2534 - accuracy: 0.8955 - val_loss: 0.4000 - val_accuracy: 0.8889
# Epoch 290/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2522 - accuracy: 0.9048 - val_loss: 0.4034 - val_accuracy: 0.8956
# Epoch 291/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2604 - accuracy: 0.8972 - val_loss: 0.4096 - val_accuracy: 0.8822
# Epoch 292/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2631 - accuracy: 0.8913 - val_loss: 0.4155 - val_accuracy: 0.8923
# Epoch 293/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2584 - accuracy: 0.9048 - val_loss: 0.4014 - val_accuracy: 0.8956
# Epoch 294/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.9040 - val_loss: 0.4022 - val_accuracy: 0.8956
# Epoch 295/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2612 - accuracy: 0.8854 - val_loss: 0.4028 - val_accuracy: 0.8990
# Epoch 296/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2519 - accuracy: 0.8989 - val_loss: 0.4053 - val_accuracy: 0.8990
# Epoch 297/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2527 - accuracy: 0.9031 - val_loss: 0.4077 - val_accuracy: 0.8990
# Epoch 298/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2616 - accuracy: 0.8930 - val_loss: 0.4034 - val_accuracy: 0.8990
# Epoch 299/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2542 - accuracy: 0.8955 - val_loss: 0.4003 - val_accuracy: 0.8956
# Epoch 300/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2516 - accuracy: 0.9006 - val_loss: 0.4054 - val_accuracy: 0.8923
# Epoch 301/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2413 - accuracy: 0.9099 - val_loss: 0.4097 - val_accuracy: 0.8754
# Epoch 302/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.9031 - val_loss: 0.4189 - val_accuracy: 0.8889
# Epoch 303/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2637 - accuracy: 0.8905 - val_loss: 0.4075 - val_accuracy: 0.8923
# Epoch 304/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2511 - accuracy: 0.8981 - val_loss: 0.4093 - val_accuracy: 0.8956
# Epoch 305/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2469 - accuracy: 0.9040 - val_loss: 0.4084 - val_accuracy: 0.8923
# Epoch 306/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2570 - accuracy: 0.8939 - val_loss: 0.4243 - val_accuracy: 0.8788
# Epoch 307/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2561 - accuracy: 0.9031 - val_loss: 0.4093 - val_accuracy: 0.8923
# Epoch 308/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2521 - accuracy: 0.8972 - val_loss: 0.4126 - val_accuracy: 0.8956
# Epoch 309/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2534 - accuracy: 0.8989 - val_loss: 0.4149 - val_accuracy: 0.8653
# Epoch 310/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2426 - accuracy: 0.9048 - val_loss: 0.4236 - val_accuracy: 0.8855
# Epoch 311/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2609 - accuracy: 0.8939 - val_loss: 0.4109 - val_accuracy: 0.8923
# Epoch 312/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2581 - accuracy: 0.8989 - val_loss: 0.4114 - val_accuracy: 0.8956
# Epoch 313/800
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2528 - accuracy: 0.9048 - val_loss: 0.4077 - val_accuracy: 0.8956
# Epoch 314/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2544 - accuracy: 0.8930 - val_loss: 0.4139 - val_accuracy: 0.8889
# Epoch 315/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2495 - accuracy: 0.9014 - val_loss: 0.4100 - val_accuracy: 0.8923
# Epoch 316/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2520 - accuracy: 0.9048 - val_loss: 0.4153 - val_accuracy: 0.8956
# Epoch 317/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2559 - accuracy: 0.8989 - val_loss: 0.4042 - val_accuracy: 0.8956
# Epoch 318/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2446 - accuracy: 0.9006 - val_loss: 0.4125 - val_accuracy: 0.8923
# Epoch 319/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2572 - accuracy: 0.8930 - val_loss: 0.4146 - val_accuracy: 0.8855
# Epoch 320/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2661 - accuracy: 0.8905 - val_loss: 0.4171 - val_accuracy: 0.8923
# Epoch 321/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2595 - accuracy: 0.8997 - val_loss: 0.4201 - val_accuracy: 0.8956
# Epoch 322/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2521 - accuracy: 0.9014 - val_loss: 0.4171 - val_accuracy: 0.8923
# Epoch 323/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2584 - accuracy: 0.8880 - val_loss: 0.4215 - val_accuracy: 0.8923
# Epoch 324/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2648 - accuracy: 0.8981 - val_loss: 0.4112 - val_accuracy: 0.8889
# Epoch 325/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2438 - accuracy: 0.9048 - val_loss: 0.4175 - val_accuracy: 0.8889
# Epoch 326/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2555 - accuracy: 0.8972 - val_loss: 0.4175 - val_accuracy: 0.8956
# Epoch 327/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2555 - accuracy: 0.9048 - val_loss: 0.4143 - val_accuracy: 0.8923
# Epoch 328/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2568 - accuracy: 0.8930 - val_loss: 0.4242 - val_accuracy: 0.8822
# Epoch 329/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2527 - accuracy: 0.9014 - val_loss: 0.4150 - val_accuracy: 0.8889
# Epoch 330/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2476 - accuracy: 0.9006 - val_loss: 0.4156 - val_accuracy: 0.8956
# Epoch 331/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2469 - accuracy: 0.8972 - val_loss: 0.4267 - val_accuracy: 0.8956
# Epoch 332/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2417 - accuracy: 0.9090 - val_loss: 0.4161 - val_accuracy: 0.8990
# Epoch 333/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2512 - accuracy: 0.9031 - val_loss: 0.4166 - val_accuracy: 0.8956
# Epoch 334/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2398 - accuracy: 0.9082 - val_loss: 0.4198 - val_accuracy: 0.8923
# Epoch 335/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2539 - accuracy: 0.8989 - val_loss: 0.4266 - val_accuracy: 0.8923
# Epoch 336/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2516 - accuracy: 0.8955 - val_loss: 0.4158 - val_accuracy: 0.8990
# Epoch 337/800
# ...
# Epoch 693/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2185 - accuracy: 0.9099 - val_loss: 0.5821 - val_accuracy: 0.9091
# Epoch 694/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2031 - accuracy: 0.9183 - val_loss: 0.6002 - val_accuracy: 0.9057
# Epoch 695/800
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9183 - val_loss: 0.5924 - val_accuracy: 0.9057
# Epoch 696/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2147 - accuracy: 0.9099 - val_loss: 0.5923 - val_accuracy: 0.8990
# Epoch 697/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2217 - accuracy: 0.9031 - val_loss: 0.6051 - val_accuracy: 0.8855
# Epoch 698/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2147 - accuracy: 0.9107 - val_loss: 0.5896 - val_accuracy: 0.9024
# Epoch 699/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2175 - accuracy: 0.9065 - val_loss: 0.5802 - val_accuracy: 0.9125
# Epoch 700/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2160 - accuracy: 0.9065 - val_loss: 0.5923 - val_accuracy: 0.9057
# Epoch 701/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2199 - accuracy: 0.9132 - val_loss: 0.5911 - val_accuracy: 0.8990
# Epoch 702/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2161 - accuracy: 0.9158 - val_loss: 0.5887 - val_accuracy: 0.9057
# Epoch 703/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2194 - accuracy: 0.9056 - val_loss: 0.6009 - val_accuracy: 0.8990
# Epoch 704/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2223 - accuracy: 0.9056 - val_loss: 0.5785 - val_accuracy: 0.9091
# Epoch 705/800
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2106 - accuracy: 0.9141 - val_loss: 0.5866 - val_accuracy: 0.9125
# Epoch 706/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2166 - accuracy: 0.9056 - val_loss: 0.5899 - val_accuracy: 0.9125
# Epoch 707/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2114 - accuracy: 0.9149 - val_loss: 0.5958 - val_accuracy: 0.8990
# Epoch 708/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2188 - accuracy: 0.9099 - val_loss: 0.5985 - val_accuracy: 0.8990
# Epoch 709/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2206 - accuracy: 0.9149 - val_loss: 0.5936 - val_accuracy: 0.9057
# Epoch 710/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2283 - accuracy: 0.9124 - val_loss: 0.5870 - val_accuracy: 0.9091
# Epoch 711/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2132 - accuracy: 0.9149 - val_loss: 0.5997 - val_accuracy: 0.9024
# Epoch 712/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2228 - accuracy: 0.9107 - val_loss: 0.5877 - val_accuracy: 0.9057
# Epoch 713/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2128 - accuracy: 0.9132 - val_loss: 0.5937 - val_accuracy: 0.9057
# Epoch 714/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2221 - accuracy: 0.9158 - val_loss: 0.5921 - val_accuracy: 0.9057
# Epoch 715/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2207 - accuracy: 0.9056 - val_loss: 0.5924 - val_accuracy: 0.9125
# Epoch 716/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2122 - accuracy: 0.9124 - val_loss: 0.5923 - val_accuracy: 0.9091
# Epoch 717/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2080 - accuracy: 0.9191 - val_loss: 0.5905 - val_accuracy: 0.9125
# Epoch 718/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2269 - accuracy: 0.9107 - val_loss: 0.5881 - val_accuracy: 0.9125
# Epoch 719/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2111 - accuracy: 0.9082 - val_loss: 0.5959 - val_accuracy: 0.9024
# Epoch 720/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2257 - accuracy: 0.9115 - val_loss: 0.5852 - val_accuracy: 0.9091
# Epoch 721/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1962 - accuracy: 0.9250 - val_loss: 0.5947 - val_accuracy: 0.9091
# Epoch 722/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2032 - accuracy: 0.9174 - val_loss: 0.6030 - val_accuracy: 0.9024
# Epoch 723/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2145 - accuracy: 0.9040 - val_loss: 0.5972 - val_accuracy: 0.9091
# Epoch 724/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2098 - accuracy: 0.9200 - val_loss: 0.5981 - val_accuracy: 0.9091
# Epoch 725/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2059 - accuracy: 0.9141 - val_loss: 0.5948 - val_accuracy: 0.9091
# Epoch 726/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2132 - accuracy: 0.9124 - val_loss: 0.6157 - val_accuracy: 0.8855
# Epoch 727/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2114 - accuracy: 0.9099 - val_loss: 0.5903 - val_accuracy: 0.9057
# Epoch 728/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2151 - accuracy: 0.9082 - val_loss: 0.5943 - val_accuracy: 0.9057
# Epoch 729/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2219 - accuracy: 0.9174 - val_loss: 0.5926 - val_accuracy: 0.9125
# Epoch 730/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.9200 - val_loss: 0.5943 - val_accuracy: 0.9057
# Epoch 731/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2208 - accuracy: 0.9031 - val_loss: 0.5826 - val_accuracy: 0.9158
# Epoch 732/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2088 - accuracy: 0.9141 - val_loss: 0.5969 - val_accuracy: 0.9057
# Epoch 733/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2197 - accuracy: 0.9065 - val_loss: 0.6041 - val_accuracy: 0.8990
# Epoch 734/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2171 - accuracy: 0.9132 - val_loss: 0.5896 - val_accuracy: 0.9158
# Epoch 735/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2064 - accuracy: 0.9090 - val_loss: 0.6066 - val_accuracy: 0.9024
# Epoch 736/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2135 - accuracy: 0.9149 - val_loss: 0.6019 - val_accuracy: 0.9057
# Epoch 737/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2158 - accuracy: 0.9090 - val_loss: 0.6092 - val_accuracy: 0.9091
# Epoch 738/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2199 - accuracy: 0.9065 - val_loss: 0.6087 - val_accuracy: 0.9057
# Epoch 739/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2104 - accuracy: 0.9115 - val_loss: 0.6059 - val_accuracy: 0.9091
# Epoch 740/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2222 - accuracy: 0.9115 - val_loss: 0.6017 - val_accuracy: 0.9091
# Epoch 741/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2058 - accuracy: 0.9191 - val_loss: 0.6048 - val_accuracy: 0.9091
# Epoch 742/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2162 - accuracy: 0.9174 - val_loss: 0.6113 - val_accuracy: 0.9057
# Epoch 743/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2132 - accuracy: 0.9132 - val_loss: 0.6192 - val_accuracy: 0.9024
# Epoch 744/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2151 - accuracy: 0.9115 - val_loss: 0.6006 - val_accuracy: 0.9125
# Epoch 745/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.6112 - val_accuracy: 0.9091
# Epoch 746/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2088 - accuracy: 0.9124 - val_loss: 0.6021 - val_accuracy: 0.9125
# Epoch 747/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2220 - accuracy: 0.8989 - val_loss: 0.6166 - val_accuracy: 0.9091
# Epoch 748/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2157 - accuracy: 0.9141 - val_loss: 0.6155 - val_accuracy: 0.9091
# Epoch 749/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2244 - accuracy: 0.9031 - val_loss: 0.6255 - val_accuracy: 0.9024
# Epoch 750/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2090 - accuracy: 0.9107 - val_loss: 0.6182 - val_accuracy: 0.9057
# Epoch 751/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2039 - accuracy: 0.9200 - val_loss: 0.6103 - val_accuracy: 0.9125
# Epoch 752/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2097 - accuracy: 0.9090 - val_loss: 0.6096 - val_accuracy: 0.9158
# Epoch 753/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2121 - accuracy: 0.9132 - val_loss: 0.6196 - val_accuracy: 0.9091
# Epoch 754/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2127 - accuracy: 0.9124 - val_loss: 0.6225 - val_accuracy: 0.9057
# Epoch 755/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2193 - accuracy: 0.9115 - val_loss: 0.6284 - val_accuracy: 0.8990
# Epoch 756/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2174 - accuracy: 0.9107 - val_loss: 0.6158 - val_accuracy: 0.9057
# Epoch 757/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2176 - accuracy: 0.9107 - val_loss: 0.6217 - val_accuracy: 0.8956
# Epoch 758/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2113 - accuracy: 0.9149 - val_loss: 0.6167 - val_accuracy: 0.9057
# Epoch 759/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2294 - accuracy: 0.9090 - val_loss: 0.6014 - val_accuracy: 0.9091
# Epoch 760/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2076 - accuracy: 0.9132 - val_loss: 0.6151 - val_accuracy: 0.9125
# Epoch 761/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2107 - accuracy: 0.9090 - val_loss: 0.6294 - val_accuracy: 0.8990
# Epoch 762/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2166 - accuracy: 0.9082 - val_loss: 0.6072 - val_accuracy: 0.9125
# Epoch 763/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2113 - accuracy: 0.9090 - val_loss: 0.6161 - val_accuracy: 0.9024
# Epoch 764/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2096 - accuracy: 0.9149 - val_loss: 0.6367 - val_accuracy: 0.8889
# Epoch 765/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2089 - accuracy: 0.9090 - val_loss: 0.6231 - val_accuracy: 0.9057
# Epoch 766/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1974 - accuracy: 0.9217 - val_loss: 0.6346 - val_accuracy: 0.9024
# Epoch 767/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2117 - accuracy: 0.9107 - val_loss: 0.6189 - val_accuracy: 0.9125
# Epoch 768/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2048 - accuracy: 0.9158 - val_loss: 0.6387 - val_accuracy: 0.8990
# Epoch 769/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1954 - accuracy: 0.9200 - val_loss: 0.6286 - val_accuracy: 0.9057
# Epoch 770/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2180 - accuracy: 0.9099 - val_loss: 0.6399 - val_accuracy: 0.8990
# Epoch 771/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2077 - accuracy: 0.9115 - val_loss: 0.6357 - val_accuracy: 0.9057
# Epoch 772/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1997 - accuracy: 0.9225 - val_loss: 0.6315 - val_accuracy: 0.9125
# Epoch 773/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2127 - accuracy: 0.9174 - val_loss: 0.6387 - val_accuracy: 0.9057
# Epoch 774/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2058 - accuracy: 0.9132 - val_loss: 0.6384 - val_accuracy: 0.9024
# Epoch 775/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2007 - accuracy: 0.9149 - val_loss: 0.6396 - val_accuracy: 0.9091
# Epoch 776/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2039 - accuracy: 0.9149 - val_loss: 0.6394 - val_accuracy: 0.9091
# Epoch 777/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2179 - accuracy: 0.9115 - val_loss: 0.6507 - val_accuracy: 0.9057
# Epoch 778/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2145 - accuracy: 0.9166 - val_loss: 0.6324 - val_accuracy: 0.9057
# Epoch 779/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2146 - accuracy: 0.9158 - val_loss: 0.6404 - val_accuracy: 0.9024
# Epoch 780/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2245 - accuracy: 0.9115 - val_loss: 0.6475 - val_accuracy: 0.9057
# Epoch 781/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2161 - accuracy: 0.9048 - val_loss: 0.6317 - val_accuracy: 0.9091
# Epoch 782/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2056 - accuracy: 0.9115 - val_loss: 0.6281 - val_accuracy: 0.9091
# Epoch 783/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2293 - accuracy: 0.9082 - val_loss: 0.6448 - val_accuracy: 0.9024
# Epoch 784/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2079 - accuracy: 0.9174 - val_loss: 0.6370 - val_accuracy: 0.9091
# Epoch 785/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2232 - accuracy: 0.9090 - val_loss: 0.6306 - val_accuracy: 0.9125
# Epoch 786/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2081 - accuracy: 0.9183 - val_loss: 0.6354 - val_accuracy: 0.9057
# Epoch 787/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2092 - accuracy: 0.9158 - val_loss: 0.6328 - val_accuracy: 0.9024
# Epoch 788/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2130 - accuracy: 0.9048 - val_loss: 0.6354 - val_accuracy: 0.9091
# Epoch 789/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2175 - accuracy: 0.9090 - val_loss: 0.6309 - val_accuracy: 0.9125
# Epoch 790/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2128 - accuracy: 0.9174 - val_loss: 0.6441 - val_accuracy: 0.8990
# Epoch 791/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2076 - accuracy: 0.9141 - val_loss: 0.6364 - val_accuracy: 0.9125
# Epoch 792/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2117 - accuracy: 0.9115 - val_loss: 0.6457 - val_accuracy: 0.8990
# Epoch 793/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2180 - accuracy: 0.9107 - val_loss: 0.6336 - val_accuracy: 0.9091
# Epoch 794/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2128 - accuracy: 0.9183 - val_loss: 0.6438 - val_accuracy: 0.9091
# Epoch 795/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2135 - accuracy: 0.9132 - val_loss: 0.6412 - val_accuracy: 0.9091
# Epoch 796/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2118 - accuracy: 0.9149 - val_loss: 0.6495 - val_accuracy: 0.8990
# Epoch 797/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2166 - accuracy: 0.9082 - val_loss: 0.6302 - val_accuracy: 0.9158
# Epoch 798/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2155 - accuracy: 0.9006 - val_loss: 0.6405 - val_accuracy: 0.9024
# Epoch 799/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2199 - accuracy: 0.9115 - val_loss: 0.6422 - val_accuracy: 0.9057
# Epoch 800/800
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2138 - accuracy: 0.9200 - val_loss: 0.6361 - val_accuracy: 0.9091
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6361 - accuracy: 0.9091
# [0.6360706686973572, 0.9090909361839294]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 10/10 [==============================] - 0s 2ms/step

# %% [markdown]
# # 특징 읽어오기

# %%
import pandas as pd
# 데이터 가져오기
df_dos = pd.read_csv('/content/drive/MyDrive/attack_name_data/df_dos.csv')
df_probe = pd.read_csv('/content/drive/MyDrive/attack_name_data/df_probe.csv')
df_r2l = pd.read_csv('/content/drive/MyDrive/attack_name_data/df_r2l.csv')
df_u2r = pd.read_csv('/content/drive/MyDrive/attack_name_data/df_u2r.csv')

# 각각 컬럼 읽어와서 저장
dos_cloumn = df_dos.columns
probe_cloumn = df_probe.columns
r2l_cloumn = df_r2l.columns
u2r_cloumn = df_u2r.columns

# 각각 컬럼 수 저장
dos_cloumn_len = len(dos_cloumn)
probe_cloumn_len = len(probe_cloumn)
r2l_cloumn_len = len(r2l_cloumn)
u2r_cloumn_len = len(u2r_cloumn)


print('Dos 컬럼')
print(dos_cloumn)
print(dos_cloumn_len)

print('Probe 컬럼')
print(probe_cloumn)
print(probe_cloumn_len)

print('R2L 컬럼')
print(r2l_cloumn)
print(r2l_cloumn_len)

print('U2R 컬럼')
print(u2r_cloumn)
print(u2r_cloumn_len)
# Out:
# Dos 컬럼
# Index(['src_bytes', 'flag', 'protocol_type', 'dst_host_same_src_port_rate',
#        'count', 'wrong_fragment', 'dst_host_rerror_rate', 'dst_bytes',
#        'dst_host_same_srv_rate', 'service', 'dst_host_serror_rate',
#        'num_compromised', 'dst_host_count', 'dst_host_diff_srv_rate',
#        'serror_rate', 'dst_host_srv_serror_rate', 'srv_serror_rate',
#        'rerror_rate', 'srv_count', 'diff_srv_rate', 'logged_in',
#        'dst_host_srv_rerror_rate', 'label'],
#       dtype='object')
# 23
# Probe 컬럼
# Index(['src_bytes', 'protocol_type', 'service', 'dst_host_same_srv_rate',
#        'dst_bytes', 'dst_host_same_src_port_rate', 'dst_host_rerror_rate',
#        'dst_host_diff_srv_rate', 'dst_host_count', 'count', 'diff_srv_rate',
#        'srv_count', 'dst_host_serror_rate', 'dst_host_srv_count',
#        'same_srv_rate', 'flag', 'rerror_rate', 'duration', 'logged_in',
#        'wrong_fragment', 'dst_host_srv_rerror_rate', 'num_outbound_cmds',
#        'label'],
#       dtype='object')
# 23
# R2L 컬럼
# Index(['service', 'src_bytes', 'dst_bytes', 'duration',
#        'dst_host_same_src_port_rate', 'hot', 'dst_host_same_srv_rate',
#        'srv_count', 'dst_host_srv_count', 'count', 'num_failed_logins',
#        'dst_host_count', 'logged_in', 'dst_host_srv_diff_host_rate',
#        'dst_host_rerror_rate', 'flag', 'is_guest_login',
#        'dst_host_srv_rerror_rate', 'is_host_login', 'dst_host_srv_serror_rate',
#        'root_shell', 'land', 'label'],
#       dtype='object')
# 23
# U2R 컬럼
# Index(['src_bytes', 'duration', 'num_file_creations', 'root_shell', 'service',
#        'dst_host_srv_count', 'hot', 'srv_count', 'dst_bytes',
#        'num_compromised', 'dst_host_count', 'dst_host_srv_diff_host_rate',
#        'dst_host_diff_srv_rate', 'num_shells', 'num_root', 'count',
#        'dst_host_serror_rate', 'dst_host_same_srv_rate', 'logged_in',
#        'dst_host_srv_serror_rate', 'protocol_type', 'land', 'label'],
#       dtype='object')
# 23

# %% [markdown]
# #모델 테스트

# %%
import pandas as pd
import numpy as np
from keras.models import load_model
from sklearn.preprocessing import LabelEncoder

# 데이터셋의 열 이름을 정의합니다.
column_names = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes',
    'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins',
    'logged_in', 'num_compromised', 'root_shell', 'su_attempted',
    'num_root', 'num_file_creations', 'num_shells', 'num_access_files',
    'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate',
    'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
    'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
    'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
    'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate',
    'label'
]

# 테스트 데이터
df1 = pd.read_csv("/content/drive/MyDrive/attack_name_data/KDDTrain+.csv", names=column_names)
df2 = pd.read_csv("/content/drive/MyDrive/attack_name_data/KDDTest+.csv", names=column_names)

# 데이터 합치기
df = pd.concat([df1, df2], ignore_index=True)
# 마지막 컬럼 삭제
df = df.drop(df.columns[-1], axis=1)

# LabelEncoder를 사용하여 범주형 열을 인코딩합니다.
le = LabelEncoder()
le.fit(df['protocol_type'])
protocol = le.transform(df['protocol_type'])
le.fit(df['service'])
service = le.transform(df['service'])
le.fit(df['flag'])
flag = le.transform(df['flag'])
df['protocol_type'] = protocol
df['service'] = service
df['flag'] = flag

# Dos모델에 넣을 데이터
dos_columns = ['src_bytes', 'flag', 'protocol_type', 'dst_host_same_src_port_rate',
               'count', 'wrong_fragment', 'dst_host_rerror_rate', 'dst_bytes',
               'dst_host_same_srv_rate', 'service', 'dst_host_serror_rate',
               'num_compromised', 'dst_host_count', 'dst_host_diff_srv_rate',
               'serror_rate', 'dst_host_srv_serror_rate', 'srv_serror_rate',
               'rerror_rate', 'srv_count', 'diff_srv_rate', 'logged_in',
               'dst_host_srv_rerror_rate']
# 선택한 컬럼들로 새로운 데이터프레임 생성
dos_df = df[dos_columns]

# Probe모델에 넣을 데이터
probe_cloumn = ['src_bytes', 'protocol_type', 'service', 'dst_host_same_srv_rate',
                'dst_bytes', 'dst_host_same_src_port_rate', 'dst_host_rerror_rate',
                'dst_host_diff_srv_rate', 'dst_host_count', 'count', 'diff_srv_rate',
                'srv_count', 'dst_host_serror_rate', 'dst_host_srv_count',
                'same_srv_rate', 'flag', 'rerror_rate', 'duration', 'logged_in',
                'wrong_fragment', 'dst_host_srv_rerror_rate', 'num_outbound_cmds']

# 선택한 컬럼들로 새로운 데이터프레임 생성
probe_df = df[probe_cloumn]

# R2L모델에 넣을 데이터
r2l_cloumn = ['service', 'src_bytes', 'dst_bytes', 'duration',
               'dst_host_same_src_port_rate', 'hot', 'dst_host_same_srv_rate',
               'srv_count', 'dst_host_srv_count', 'count', 'num_failed_logins',
               'dst_host_count', 'logged_in', 'dst_host_srv_diff_host_rate',
               'dst_host_rerror_rate', 'flag', 'is_guest_login',
               'dst_host_srv_rerror_rate', 'is_host_login', 'dst_host_srv_serror_rate',
               'root_shell', 'land']
# 선택한 컬럼들로 새로운 데이터프레임 생성
r2l_df = df[r2l_cloumn]

# U2R모델에 넣을 데이터
u2r_cloumn = ['src_bytes', 'duration', 'num_file_creations', 'root_shell', 'service',
               'dst_host_srv_count', 'hot', 'srv_count', 'dst_bytes',
               'num_compromised', 'dst_host_count', 'dst_host_srv_diff_host_rate',
               'dst_host_diff_srv_rate', 'num_shells', 'num_root', 'count',
               'dst_host_serror_rate', 'dst_host_same_srv_rate', 'logged_in',
               'dst_host_srv_serror_rate', 'protocol_type', 'land']
# 선택한 컬럼들로 새로운 데이터프레임 생성
u2r_df = df[u2r_cloumn]

# DNN모델 불러오기
Dos_model = load_model('/content/drive/MyDrive/DNN_Model/DNN_dos.h5')
Probe_model = load_model('/content/drive/MyDrive/DNN_Model/DNN_probe.h5')
R2l_model = load_model('/content/drive/MyDrive/DNN_Model/DNN_r2l.h5')
U2r_model = load_model('/content/drive/MyDrive/DNN_Model/DNN_u2r.h5')

# 각 모델에 대한 예측 결과
result1 = Dos_model.predict(dos_df.to_numpy())
result2 = Probe_model.predict(probe_df.to_numpy())
result3 = R2l_model.predict(r2l_df.to_numpy())
result4 = U2r_model.predict(u2r_df.to_numpy())

# 예측 결과를 기반으로 탐지된 개수 계산
def count_detected(predictions, threshold=0.9):
    return np.sum(predictions > threshold)

# 각 모델에 대한 탐지된 공격 개수 계산
detected_count1 = count_detected(result1)
detected_count2 = count_detected(result2)
detected_count3 = count_detected(result3)
detected_count4 = count_detected(result4)

# 탐지된 공격 개수 출력
print(f"Dos 모델에서 탐지된 공격 개수: {detected_count1}")
print(f"Probe 모델에서 탐지된 공격 개수: {detected_count2}")
print(f"R2l 모델에서 탐지된 공격 개수: {detected_count3}")
print(f"U2r 모델에서 탐지된 공격 개수: {detected_count4}")
# Out:
# 4642/4642 [==============================] - 6s 1ms/step
# 4642/4642 [==============================] - 6s 1ms/step
# 4642/4642 [==============================] - 5s 1ms/step
# 4642/4642 [==============================] - 6s 1ms/step
# Dos 모델에서 탐지된 공격 개수: 53959
# Probe 모델에서 탐지된 공격 개수: 15564
# R2l 모델에서 탐지된 공격 개수: 86156
# U2r 모델에서 탐지된 공격 개수: 62875

# %%
# 필요한 라이브러리를 임포트합니다.
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import sklearn
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE

# 데이터셋의 열 이름을 정의합니다.
column_names = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes',
    'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins',
    'logged_in', 'num_compromised', 'root_shell', 'su_attempted',
    'num_root', 'num_file_creations', 'num_shells', 'num_access_files',
    'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate',
    'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
    'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
    'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
    'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate',
    'label'
]

# 학습 및 테스트 데이터를 읽어옵니다.
df1 = pd.read_csv("/content/drive/MyDrive/attack_name_data/KDDTrain+.csv", names=column_names)
df2 = pd.read_csv("/content/drive/MyDrive/attack_name_data/KDDTest+.csv", names=column_names)

# 두 데이터프레임을 합쳐 새로운 데이터프레임을 만듭니다.
newdf = pd.concat([df1, df2])

# 공격 레이블을 숫자 값으로 대체합니다.
dfdos = newdf.replace(['apache2', 'back', 'land', 'mailbomb', 'neptune', 'pod', 'processtable', 'smurf', 'teardrop', 'udpstorm'], 2)
dfr2l = dfdos.replace(['ftp_write', 'guess_passwd', 'imap', 'multihop', 'named', 'phf', 'sendmail', 'snmpgetattack', 'snmpguess', 'warezmaster', 'worm', 'xlock' ,'xsnoop', 'httptunnel', 'warezclient', 'spy'], 4)
dfu2r = dfr2l.replace(['buffer_overflow', 'loadmodule', 'perl', 'rootkit', 'ps', 'sqlattack', 'xterm'], 1)
dfprobe = dfu2r.replace(['ipsweep', 'mscan', 'nmap', 'portsweep', 'saint', 'satan'], 3)
dfnormal = dfprobe.replace(['normal'], 0)
df_type = dfnormal

# 레이블이 0 또는 1인 행만 선택합니다 (normal 또는 dos).
condition = (df_type.label == 0) | (df_type.label == 1)
df_dos = df_type[condition]
df_dos = df_dos.reset_index(drop=True)

# 각 레이블의 개수를 표시합니다.
print(df_dos.value_counts('label'))
# Out:
# label
# 0    77054
# 1      119
# dtype: int64
