# %% [markdown]
# <a href="https://colab.research.google.com/github/lee191/LSTM/blob/main/DNN_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 특징추출

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 필요한 라이브러리를 임포트합니다.
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.cluster import KMeans
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import sklearn
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE

# 데이터셋의 열 이름을 정의합니다.
column_names = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes',
    'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins',
    'logged_in', 'num_compromised', 'root_shell', 'su_attempted',
    'num_root', 'num_file_creations', 'num_shells', 'num_access_files',
    'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate',
    'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
    'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
    'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
    'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate',
    'label'
]

# 학습 및 테스트 데이터를 읽어옵니다.
df1 = pd.read_csv("/content/drive/MyDrive/attack_name_data/KDDTrain+.csv", names=column_names)
df2 = pd.read_csv("/content/drive/MyDrive/attack_name_data/KDDTest+.csv", names=column_names)

# 두 데이터프레임을 합쳐 새로운 데이터프레임을 만듭니다.
newdf = pd.concat([df1, df2], ignore_index=True)

# 공격 레이블을 숫자 값으로 대체합니다.
dfdos = newdf.replace(['apache2', 'back', 'land', 'mailbomb', 'neptune', 'pod', 'processtable', 'smurf', 'teardrop', 'udpstorm'], 2)
dfr2l = dfdos.replace(['ftp_write', 'guess_passwd', 'imap', 'multihop', 'named', 'phf', 'sendmail', 'snmpgetattack', 'snmpguess', 'warezmaster', 'worm', 'xlock' ,'xsnoop', 'httptunnel', 'warezclient', 'spy'], 3)
dfu2r = dfr2l.replace(['buffer_overflow', 'loadmodule', 'perl', 'rootkit', 'ps', 'sqlattack', 'xterm'], 4)
dfprobe = dfu2r.replace(['ipsweep', 'mscan', 'nmap', 'portsweep', 'saint', 'satan'], 1)
dfnormal = dfprobe.replace(['normal'], 0)
df_type = dfnormal

# 레이블이 0 또는 1인 행만 선택합니다 (normal 또는 dos).
condition = (df_type.label == 0) | (df_type.label == 1)
df_dos = df_type[condition]
df_dos = df_dos.reset_index(drop=True)

# 각 레이블의 개수를 표시합니다.
print(df_dos.value_counts('label'))

# object 타입의 열에 대해 고유 값 및 개수를 표시합니다.
for columns in df1.columns:
    if df_dos[columns].dtypes == 'object':
        print(columns, '\n종류:', df_dos[columns].unique(), '\n개수:', df_dos[columns].nunique(), '\n')

# 'protocol_type', 'service', 'flag' 열을 추출합니다.
df_dos_obj = df_dos[['protocol_type', 'service', 'flag']]

# 'label' 열을 제외한 새로운 데이터프레임을 생성합니다.
newdos = df_dos.drop(columns=['label'])
newlabel = df_dos['label']

# LabelEncoder를 사용하여 범주형 열을 인코딩합니다.
le = LabelEncoder()
le.fit(newdos['protocol_type'])
protocol = le.transform(newdos['protocol_type'])
le.fit(newdos['service'])
service = le.transform(newdos['service'])
le.fit(newdos['flag'])
flag = le.transform(newdos['flag'])
newdos['protocol_type'] = protocol
newdos['service'] = service
newdos['flag'] = flag

# 전처리된 데이터를 dosle 및 yle에 저장합니다.
dosle = newdos
yle = newlabel

# MinMaxScaler를 사용하여 특성을 스케일링합니다.
pd.options.display.float_format = '{:.9f}'.format
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(dosle)
xle = pd.DataFrame(np_scaled, columns=dosle.columns)

# 데이터를 훈련 및 테스트 세트로 나눕니다.
xle, xle_test, yle, yle_test = train_test_split(xle, yle, test_size=0.2, random_state=2022)

# 데이터셋의 모양을 표시합니다.
print(xle.shape, yle.shape)
print(xle_test.shape, yle_test.shape)

# 훈련 및 테스트용으로 데이터의 일부를 선택합니다.
x = xle.head(1000)
x_test = xle_test.head(200)
y = yle.head(1000)
y_test = yle_test.head(200)

# XGBoost 분류기를 훈련합니다.
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
xgb.fit(xle, yle)

# 테스트 세트에서 예측을 수행합니다.
yle_preds = xgb.predict(xle_test)
yle_test = yle_test.astype(int)
yle_preds = yle_preds.astype(int)

# 정확도를 표시합니다.
print('Accuracy: %.2f' % accuracy_score(yle_test, yle_preds))

# 혼동 행렬을 표시합니다.
cm = confusion_matrix(yle_test, yle_preds)
plt.figure(figsize=(16, 9))
sns.heatmap(
    cm,
    annot=True,
    fmt='g',
    xticklabels=['dos', 'normal'],
    yticklabels=['dos', 'normal']
)
plt.show()

# Permutation Importance 분석을 수행합니다.
perm = PermutationImportance(xgb, random_state=1).fit(xle_test, yle_test)

# 중요도가 높은 순서대로 22개의 특성 선택
selected_features = xle_test.columns[perm.feature_importances_.argsort()[::-1][:22]]
print(selected_features)

# 선택된 특성을 데이터프레임으로 추출
xle_test_selected = xle_test[selected_features]

# newlabel과 합치기
final_df = pd.concat([xle_test_selected, pd.DataFrame(yle_test, columns=['label'])], axis=1)

print(final_df)
# CSV 파일로 저장
final_df.to_csv("/content/drive/MyDrive/attack_name_data/df_probe.csv", index=False)

eli5.show_weights(perm, feature_names=xle_test.columns.tolist())
# Out:
# label
# 0    77054
# 1    14077
# dtype: int64
# protocol_type
# 종류: ['tcp' 'udp' 'icmp']
# 개수: 3
#
# service
# 종류: ['ftp_data' 'other' 'http' 'eco_i' 'telnet' 'private' 'domain_u' 'smtp'
#  'netbios_dgm' 'urp_i' 'finger' 'ftp' 'gopher' 'ecr_i' 'sql_net' 'time'
#  'ntp_u' 'remote_job' 'csnet_ns' 'ssh' 'auth' 'shell' 'pop_3' 'Z39_50'
#  'IRC' 'pm_dump' 'link' 'systat' 'exec' 'iso_tsap' 'red_i' 'domain'
#  'netbios_ns' 'echo' 'uucp_path' 'bgp' 'whois' 'nntp' 'kshell' 'X11'
#  'klogin' 'ldap' 'name' 'discard' 'imap4' 'rje' 'http_443' 'pop_2'
#  'netbios_ssn' 'mtp' 'netstat' 'daytime' 'sunrpc' 'urh_i' 'http_8001'
#  'efs' 'supdup' 'ctf' 'nnsp' 'hostnames' 'courier' 'uucp' 'aol' 'vmnet'
#  'tim_i' 'login' 'http_2784' 'printer' 'tftp_u' 'harvest']
# 개수: 70
#
# flag
# 종류: ['SF' 'REJ' 'RSTR' 'SH' 'RSTO' 'S0' 'S1' 'RSTOS0' 'S3' 'S2' 'OTH']
# 개수: 11
#
# label
# 종류: [0 1]
# 개수: 2
#
# (72904, 41) (72904,)
# (18227, 41) (18227,)
# Accuracy: 1.00
# Index(['src_bytes', 'protocol_type', 'service', 'dst_host_same_srv_rate',
#        'dst_bytes', 'dst_host_same_src_port_rate', 'dst_host_rerror_rate',
#        'dst_host_diff_srv_rate', 'dst_host_count', 'count', 'diff_srv_rate',
#        'srv_count', 'dst_host_serror_rate', 'dst_host_srv_count',
#        'same_srv_rate', 'flag', 'rerror_rate', 'duration', 'logged_in',
#        'wrong_fragment', 'dst_host_srv_rerror_rate', 'num_outbound_cmds'],
#       dtype='object')
#         src_bytes  protocol_type     service  dst_host_same_srv_rate  \
# 40692 0.000000542    0.500000000 0.289855072             0.360000000
# 30744 0.000000231    0.500000000 0.347826087             1.000000000
# 23296 0.000000134    0.500000000 0.347826087             1.000000000
# 7668  0.000000161    0.500000000 0.347826087             1.000000000
# 61792 0.000000252    0.500000000 0.347826087             1.000000000
# ...           ...            ...         ...                     ...
# 44242 0.000000022    0.000000000 0.202898551             1.000000000
# 57888 0.000000175    0.500000000 0.347826087             1.000000000
# 71839 0.000000032    1.000000000 0.173913043             0.990000000
# 7551  0.000000235    0.500000000 0.347826087             1.000000000
# 23159 0.000000033    1.000000000 0.173913043             0.770000000
#
#         dst_bytes  dst_host_same_src_port_rate  dst_host_rerror_rate  \
# 40692 0.000000000                  0.360000000           0.000000000
# 30744 0.000002331                  0.000000000           0.000000000
# 23296 0.000004197                  0.010000000           0.000000000
# 7668  0.000000604                  0.010000000           0.330000000
# 61792 0.000004771                  0.000000000           0.000000000
# ...           ...                          ...                   ...
# 44242 0.000000000                  1.000000000           0.000000000
# 57888 0.000000366                  0.000000000           0.000000000
# 71839 0.000000084                  0.000000000           0.000000000
# 7551  0.000043825                  0.050000000           0.000000000
# 23159 0.000000098                  0.010000000           0.000000000
#
#        dst_host_diff_srv_rate  dst_host_count       count  ...  \
# 40692             0.020000000     0.721568627 0.001956947  ...
# 30744             0.000000000     1.000000000 0.035225049  ...
# 23296             0.000000000     0.533333333 0.001956947  ...
# 7668              0.000000000     0.427450980 0.052837573  ...
# 61792             0.000000000     1.000000000 0.015655577  ...
# ...                       ...             ...         ...  ...
# 44242             0.000000000     0.286274510 0.000000000  ...
# 57888             0.000000000     1.000000000 0.015655577  ...
# 71839             0.010000000     0.882352941 0.001956947  ...
# 7551              0.000000000     0.082352941 0.041095890  ...
# 23159             0.020000000     0.654901961 0.322896282  ...
#
#        dst_host_srv_count  same_srv_rate        flag  rerror_rate    duration  \
# 40692         0.301960784    1.000000000 0.900000000  0.000000000 0.000000000
# 30744         1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# 23296         0.533333333    1.000000000 0.900000000  0.000000000 0.000000000
# 7668          1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# 61792         1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# ...                   ...            ...         ...          ...         ...
# 44242         0.286274510    0.000000000 0.900000000  0.000000000 0.000000000
# 57888         1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# 71839         0.870588235    1.000000000 0.900000000  0.000000000 0.000000000
# 7551          1.000000000    1.000000000 0.900000000  0.000000000 0.000000000
# 23159         0.501960784    0.990000000 0.900000000  0.000000000 0.000000000
#
#         logged_in  wrong_fragment  dst_host_srv_rerror_rate  \
# 40692 1.000000000     0.000000000               0.000000000
# 30744 1.000000000     0.000000000               0.000000000
# 23296 1.000000000     0.000000000               0.000000000
# 7668  1.000000000     0.000000000               0.550000000
# 61792 1.000000000     0.000000000               0.000000000
# ...           ...             ...                       ...
# 44242 0.000000000     0.000000000               0.000000000
# 57888 1.000000000     0.000000000               0.000000000
# 71839 0.000000000     0.000000000               0.000000000
# 7551  1.000000000     0.000000000               0.000000000
# 23159 0.000000000     0.000000000               0.000000000
#
#        num_outbound_cmds  label
# 40692        0.000000000      0
# 30744        0.000000000      0
# 23296        0.000000000      0
# 7668         0.000000000      0
# 61792        0.000000000      0
# ...                  ...    ...
# 44242        0.000000000      0
# 57888        0.000000000      0
# 71839        0.000000000      0
# 7551         0.000000000      0
# 23159        0.000000000      0
#
# [18227 rows x 23 columns]
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0800
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 src_bytes
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0123
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 protocol_type
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0083
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 service
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0047
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_same_srv_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_bytes
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_same_src_port_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_rerror_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_diff_srv_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_count
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 count
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 diff_srv_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.31%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 srv_count
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_serror_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dst_host_srv_count
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 same_srv_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 flag
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 rerror_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.00

# %% [markdown]
# # DNN(DOS)

# %%
import pandas as pd
import numpy as np
import sklearn
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.preprocessing import MinMaxScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 소수점 9자리까지 표시
pd.options.display.float_format = '{:.9f}'.format

# df_dos2.csv 파일을 읽어옵니다.
df_dos = pd.read_csv("/content/drive/MyDrive/attack_name_data/df_dos.csv")

# 'label' 열을 제외한 데이터를 dos_loX로 지정합니다.
dos_loX = df_dos.drop(['label'], axis=1)

# 'label' 열을 dosY로 지정합니다.
dosY = df_dos['label']

# MinMaxScaler를 사용하여 데이터를 스케일링합니다.
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(dos_loX)
dosX = pd.DataFrame(np_scaled, columns=dos_loX.columns)

# RandomUnderSampler를 사용하여 언더샘플링을 수행합니다.
rus = RandomUnderSampler()
dfrus_X, dfrus_Y = rus.fit_resample(dosX, dosY)
dfrus_X = pd.DataFrame(dfrus_X, columns=dosX.columns)

# 훈련 및 테스트 데이터로 분할합니다.
X_train, X_test, y_train, y_test = train_test_split(dfrus_X, dfrus_Y, test_size=0.2, random_state=2022)

# 데이터 차원 확인
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# Random Forest 모델 생성
rand_clf = RandomForestClassifier(criterion='entropy', bootstrap=True, random_state=42, max_depth=5)
rand_clf.fit(X_train, y_train)

# 훈련 및 테스트 정확도 출력
print('훈련세트 정확도: {:.3f}'.format(rand_clf.score(X_train, y_train)))
print('테스트세트 정확도: {:.3f}'.format(rand_clf.score(X_test, y_test)))

# DNN 모델 생성
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=22))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 구조 확인
model.summary()

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=64)

# 테스트셋 평가
scores = model.evaluate(X_test, y_test)
print(scores)

# 모델 저장
model.save('/content/drive/MyDrive/DNN_Model/DNN_dos.h5')

# 손실 및 정확도 그래프
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 데이터에 대한 예측 확률
y_pred_prob = model.predict(X_test)

# 확률을 클래스로 변환 (임계값은 예시로 0.5)
threshold = 0.5
y_pred = np.where(y_pred_prob > threshold, 1, 0)

# 혼동 행렬을 시각화
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# (17097, 22) (17097,)
# (4275, 22) (4275,)
# 훈련세트 정확도: 0.995
# 테스트세트 정확도: 0.995
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                1472
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dense_9 (Dense)             (None, 8)                 136
#
#  dense_10 (Dense)            (None, 4)                 36
#
#  dense_11 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 4257 (16.63 KB)
# Trainable params: 4257 (16.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 268/268 [==============================] - 2s 2ms/step - loss: 0.4953 - accuracy: 0.8679
# Epoch 2/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.3182 - accuracy: 0.9757
# Epoch 3/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.2607 - accuracy: 0.9802
# Epoch 4/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.2189 - accuracy: 0.9812
# Epoch 5/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1870 - accuracy: 0.9832
# Epoch 6/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1612 - accuracy: 0.9840
# Epoch 7/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1373 - accuracy: 0.9860
# Epoch 8/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1188 - accuracy: 0.9876
# Epoch 9/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.1024 - accuracy: 0.9887
# Epoch 10/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0909 - accuracy: 0.9898
# Epoch 11/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0812 - accuracy: 0.9906
# Epoch 12/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0733 - accuracy: 0.9904
# Epoch 13/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0655 - accuracy: 0.9911
# Epoch 14/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0597 - accuracy: 0.9916
# Epoch 15/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0562 - accuracy: 0.9914
# Epoch 16/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0510 - accuracy: 0.9920
# Epoch 17/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0456 - accuracy: 0.9925
# Epoch 18/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0413 - accuracy: 0.9936
# Epoch 19/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0404 - accuracy: 0.9931
# Epoch 20/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0378 - accuracy: 0.9932
# Epoch 21/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0314 - accuracy: 0.9946
# Epoch 22/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0336 - accuracy: 0.9936
# Epoch 23/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0290 - accuracy: 0.9942
# Epoch 24/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0267 - accuracy: 0.9944
# Epoch 25/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0232 - accuracy: 0.9958
# Epoch 26/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0267 - accuracy: 0.9947
# Epoch 27/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0220 - accuracy: 0.9960
# Epoch 28/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0179 - accuracy: 0.9968
# Epoch 29/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0183 - accuracy: 0.9958
# Epoch 30/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0165 - accuracy: 0.9967
# Epoch 31/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0137 - accuracy: 0.9979
# Epoch 32/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0153 - accuracy: 0.9970
# Epoch 33/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0172 - accuracy: 0.9965
# Epoch 34/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0142 - accuracy: 0.9970
# Epoch 35/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0128 - accuracy: 0.9973
# Epoch 36/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0122 - accuracy: 0.9978
# Epoch 37/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0151 - accuracy: 0.9967
# Epoch 38/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0112 - accuracy: 0.9980
# Epoch 39/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0122 - accuracy: 0.9973
# Epoch 40/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0136 - accuracy: 0.9968
# Epoch 41/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0106 - accuracy: 0.9977
# Epoch 42/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0097 - accuracy: 0.9984
# Epoch 43/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0106 - accuracy: 0.9978
# Epoch 44/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0112 - accuracy: 0.9976
# Epoch 45/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0123 - accuracy: 0.9970
# Epoch 46/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0101 - accuracy: 0.9982
# Epoch 47/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0100 - accuracy: 0.9980
# Epoch 48/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0115 - accuracy: 0.9973
# Epoch 49/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0091 - accuracy: 0.9982
# Epoch 50/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0099 - accuracy: 0.9980
# Epoch 51/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0097 - accuracy: 0.9982
# Epoch 52/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0094 - accuracy: 0.9978
# Epoch 53/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0151 - accuracy: 0.9968
# Epoch 54/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0093 - accuracy: 0.9982
# Epoch 55/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0088 - accuracy: 0.9981
# Epoch 56/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0099 - accuracy: 0.9978
# Epoch 57/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0081 - accuracy: 0.9983
# Epoch 58/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0093 - accuracy: 0.9982
# Epoch 59/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0105 - accuracy: 0.9975
# Epoch 60/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0082 - accuracy: 0.9984
# Epoch 61/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0086 - accuracy: 0.9982
# Epoch 62/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0085 - accuracy: 0.9981
# Epoch 63/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0080 - accuracy: 0.9984
# Epoch 64/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0074 - accuracy: 0.9987
# Epoch 65/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 0.9988
# Epoch 66/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0099 - accuracy: 0.9978
# Epoch 67/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0113 - accuracy: 0.9972
# Epoch 68/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0085 - accuracy: 0.9982
# Epoch 69/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0084 - accuracy: 0.9982
# Epoch 70/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0079 - accuracy: 0.9985
# Epoch 71/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0089 - accuracy: 0.9982
# Epoch 72/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0078 - accuracy: 0.9982
# Epoch 73/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0118 - accuracy: 0.9969
# Epoch 74/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0105 - accuracy: 0.9978
# Epoch 75/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 76/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0086 - accuracy: 0.9982
# Epoch 77/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0072 - accuracy: 0.9987
# Epoch 78/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0070 - accuracy: 0.9989
# Epoch 79/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0083 - accuracy: 0.9982
# Epoch 80/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0071 - accuracy: 0.9987
# Epoch 81/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0081 - accuracy: 0.9984
# Epoch 82/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0089 - accuracy: 0.9978
# Epoch 83/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0092 - accuracy: 0.9979
# Epoch 84/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0077 - accuracy: 0.9980
# Epoch 85/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0074 - accuracy: 0.9984
# Epoch 86/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0075 - accuracy: 0.9984
# Epoch 87/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0106 - accuracy: 0.9980
# Epoch 88/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 89/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 0.9988
# Epoch 90/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0076 - accuracy: 0.9984
# Epoch 91/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0069 - accuracy: 0.9985
# Epoch 92/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0073 - accuracy: 0.9985
# Epoch 93/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 94/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 0.9988
# Epoch 95/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0099 - accuracy: 0.9981
# Epoch 96/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0084 - accuracy: 0.9980
# Epoch 97/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0064 - accuracy: 0.9988
# Epoch 98/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0083 - accuracy: 0.9981
# Epoch 99/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0065 - accuracy: 0.9988
# Epoch 100/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 0.9985
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9984
# [0.00699360016733408, 0.9983626008033752]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 134/134 [==============================] - 0s 1ms/step

# %% [markdown]
# # DNN(U2R)

# %%
import pandas as pd
import numpy as np
import sklearn
import sys
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.preprocessing import MinMaxScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers import Dropout
from keras.optimizers import Adam
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 소수점 9자리까지 표시
pd.options.display.float_format = '{:.9f}'.format

# df_u2r.csv 파일을 읽어옵니다.
df_u2r = pd.read_csv("/content/drive/MyDrive/attack_name_data/df_u2r.csv")

# 'label' 열을 제외한 데이터를 u2r_loX로 지정합니다.
u2r_loX = df_u2r.drop(['label'], axis=1)

# 'label' 열을 u2rY로 지정합니다.
u2rY = df_u2r['label']

# MinMaxScaler를 사용하여 데이터를 스케일링합니다.
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(u2r_loX)
u2rX = pd.DataFrame(np_scaled, columns=u2r_loX.columns)

# RandomUnderSampler를 사용하여 언더샘플링을 수행합니다.
rus = RandomUnderSampler()
dfrus_X, dfrus_Y = rus.fit_resample(u2rX, u2rY)
dfrus_X = pd.DataFrame(dfrus_X, columns=u2rX.columns)

# 훈련 및 테스트 데이터로 분할합니다.
X_train, X_test, y_train, y_test = train_test_split(dfrus_X, dfrus_Y, test_size=0.2, random_state=2022)

# 데이터 차원 확인
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# 배열로 변환
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# DNN 모델 생성
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=22))
model.add(Dropout(0.1))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# 모델 구조 확인
model.summary()

# 모델 훈련
mod = model.fit(X_train, y_train, epochs=90, batch_size=8, validation_data=(X_test, y_test))

# 테스트셋 평가
scores = model.evaluate(X_test, y_test)
print(scores)

# 모델 저장
model.save('/content/drive/MyDrive/DNN_u2r.h5')

# 손실 그래프
plt.plot(mod.history['loss'], label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 정확도 그래프
plt.plot(mod.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 데이터에 대한 예측 확률
y_pred_prob = model.predict(X_test)

# 확률을 클래스로 변환 (임계값은 예시로 0.5)
threshold = 0.5
y_pred = np.where(y_pred_prob > threshold, 1, 0)

# 혼동 행렬을 시각화
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# (44, 22) (44,)
# (12, 22) (12,)
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_138 (Dense)           (None, 64)                1472
#
#  dropout_84 (Dropout)        (None, 64)                0
#
#  dense_139 (Dense)           (None, 32)                2080
#
#  dropout_85 (Dropout)        (None, 32)                0
#
#  dense_140 (Dense)           (None, 16)                528
#
#  dropout_86 (Dropout)        (None, 16)                0
#
#  dense_141 (Dense)           (None, 8)                 136
#
#  dropout_87 (Dropout)        (None, 8)                 0
#
#  dense_142 (Dense)           (None, 4)                 36
#
#  dense_143 (Dense)           (None, 1)                 5
#
# =================================================================
# Total params: 4257 (16.63 KB)
# Trainable params: 4257 (16.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/90
# 6/6 [==============================] - 1s 40ms/step - loss: 0.6972 - accuracy: 0.4545 - val_loss: 0.6947 - val_accuracy: 0.5000
# Epoch 2/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6876 - accuracy: 0.5682 - val_loss: 0.6890 - val_accuracy: 0.5000
# Epoch 3/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6777 - accuracy: 0.6136 - val_loss: 0.6806 - val_accuracy: 0.6667
# Epoch 4/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6854 - accuracy: 0.5682 - val_loss: 0.6714 - val_accuracy: 0.8333
# Epoch 5/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6723 - accuracy: 0.6818 - val_loss: 0.6624 - val_accuracy: 0.8333
# Epoch 6/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6448 - accuracy: 0.8864 - val_loss: 0.6515 - val_accuracy: 0.8333
# Epoch 7/90
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6451 - accuracy: 0.8409 - val_loss: 0.6327 - val_accuracy: 0.8333
# Epoch 8/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6055 - accuracy: 0.8864 - val_loss: 0.6091 - val_accuracy: 0.9167
# Epoch 9/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6167 - accuracy: 0.7955 - val_loss: 0.5821 - val_accuracy: 0.9167
# Epoch 10/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5629 - accuracy: 0.8409 - val_loss: 0.5454 - val_accuracy: 0.9167
# Epoch 11/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5690 - accuracy: 0.8182 - val_loss: 0.5091 - val_accuracy: 0.9167
# Epoch 12/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5162 - accuracy: 0.8636 - val_loss: 0.4619 - val_accuracy: 0.9167
# Epoch 13/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4869 - accuracy: 0.8864 - val_loss: 0.4266 - val_accuracy: 0.9167
# Epoch 14/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4728 - accuracy: 0.8864 - val_loss: 0.3995 - val_accuracy: 0.9167
# Epoch 15/90
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4092 - accuracy: 0.8409 - val_loss: 0.3565 - val_accuracy: 0.9167
# Epoch 16/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3974 - accuracy: 0.8182 - val_loss: 0.3347 - val_accuracy: 0.9167
# Epoch 17/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3254 - accuracy: 0.9091 - val_loss: 0.3036 - val_accuracy: 0.9167
# Epoch 18/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4085 - accuracy: 0.8182 - val_loss: 0.2935 - val_accuracy: 0.9167
# Epoch 19/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2982 - accuracy: 0.8636 - val_loss: 0.2879 - val_accuracy: 0.9167
# Epoch 20/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2747 - accuracy: 0.9091 - val_loss: 0.2900 - val_accuracy: 0.9167
# Epoch 21/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3130 - accuracy: 0.8864 - val_loss: 0.2836 - val_accuracy: 0.9167
# Epoch 22/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2906 - accuracy: 0.8864 - val_loss: 0.2647 - val_accuracy: 0.9167
# Epoch 23/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2193 - accuracy: 0.9091 - val_loss: 0.2495 - val_accuracy: 0.9167
# Epoch 24/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3539 - accuracy: 0.8636 - val_loss: 0.2313 - val_accuracy: 0.9167
# Epoch 25/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2661 - accuracy: 0.8636 - val_loss: 0.2368 - val_accuracy: 0.9167
# Epoch 26/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3378 - accuracy: 0.8409 - val_loss: 0.2440 - val_accuracy: 0.9167
# Epoch 27/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2562 - accuracy: 0.9091 - val_loss: 0.2491 - val_accuracy: 0.9167
# Epoch 28/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2018 - accuracy: 0.8864 - val_loss: 0.2620 - val_accuracy: 0.9167
# Epoch 29/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2939 - accuracy: 0.8636 - val_loss: 0.2458 - val_accuracy: 0.9167
# Epoch 30/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2781 - accuracy: 0.8864 - val_loss: 0.2249 - val_accuracy: 0.9167
# Epoch 31/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2571 - accuracy: 0.9318 - val_loss: 0.2201 - val_accuracy: 0.9167
# Epoch 32/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2898 - accuracy: 0.9091 - val_loss: 0.2766 - val_accuracy: 0.9167
# Epoch 33/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2883 - accuracy: 0.9091 - val_loss: 0.2822 - val_accuracy: 0.9167
# Epoch 34/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2373 - accuracy: 0.8864 - val_loss: 0.2627 - val_accuracy: 0.9167
# Epoch 35/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2562 - accuracy: 0.9091 - val_loss: 0.2361 - val_accuracy: 0.9167
# Epoch 36/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2014 - accuracy: 0.9091 - val_loss: 0.2182 - val_accuracy: 0.9167
# Epoch 37/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2006 - accuracy: 0.9545 - val_loss: 0.2134 - val_accuracy: 0.9167
# Epoch 38/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1787 - accuracy: 0.9318 - val_loss: 0.2249 - val_accuracy: 0.9167
# Epoch 39/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2357 - accuracy: 0.8864 - val_loss: 0.2267 - val_accuracy: 0.9167
# Epoch 40/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1903 - accuracy: 0.8864 - val_loss: 0.2141 - val_accuracy: 0.9167
# Epoch 41/90
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2066 - accuracy: 0.9091 - val_loss: 0.2123 - val_accuracy: 0.9167
# Epoch 42/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1696 - accuracy: 0.8636 - val_loss: 0.2107 - val_accuracy: 0.9167
# Epoch 43/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1379 - accuracy: 0.9545 - val_loss: 0.2295 - val_accuracy: 0.9167
# Epoch 44/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1708 - accuracy: 0.9318 - val_loss: 0.2336 - val_accuracy: 0.9167
# Epoch 45/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1673 - accuracy: 0.9091 - val_loss: 0.2381 - val_accuracy: 0.9167
# Epoch 46/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1673 - accuracy: 0.9545 - val_loss: 0.1959 - val_accuracy: 0.9167
# Epoch 47/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1317 - accuracy: 0.9773 - val_loss: 0.1920 - val_accuracy: 0.9167
# Epoch 48/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1299 - accuracy: 0.9773 - val_loss: 0.2014 - val_accuracy: 0.9167
# Epoch 49/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1513 - accuracy: 0.9545 - val_loss: 0.2145 - val_accuracy: 0.9167
# Epoch 50/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1490 - accuracy: 0.9318 - val_loss: 0.2615 - val_accuracy: 0.9167
# Epoch 51/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1018 - accuracy: 1.0000 - val_loss: 0.3080 - val_accuracy: 0.9167
# Epoch 52/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0839 - accuracy: 0.9773 - val_loss: 0.2986 - val_accuracy: 0.9167
# Epoch 53/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1201 - accuracy: 0.9545 - val_loss: 0.2371 - val_accuracy: 0.9167
# Epoch 54/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0844 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9167
# Epoch 55/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1231 - accuracy: 0.9773 - val_loss: 0.2160 - val_accuracy: 0.9167
# Epoch 56/90
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1766 - accuracy: 0.9318 - val_loss: 0.2249 - val_accuracy: 0.9167
# Epoch 57/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1306 - accuracy: 0.9318 - val_loss: 0.3042 - val_accuracy: 0.9167
# Epoch 58/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0956 - accuracy: 0.9545 - val_loss: 0.3337 - val_accuracy: 0.8333
# Epoch 59/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1455 - accuracy: 0.9545 - val_loss: 0.2869 - val_accuracy: 0.9167
# Epoch 60/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0775 - accuracy: 0.9773 - val_loss: 0.2287 - val_accuracy: 0.9167
# Epoch 61/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0892 - accuracy: 0.9773 - val_loss: 0.1851 - val_accuracy: 0.9167
# Epoch 62/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0781 - accuracy: 0.9773 - val_loss: 0.1875 - val_accuracy: 0.9167
# Epoch 63/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 0.1912 - val_accuracy: 0.9167
# Epoch 64/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1101 - accuracy: 0.9545 - val_loss: 0.2152 - val_accuracy: 0.9167
# Epoch 65/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0708 - accuracy: 0.9773 - val_loss: 0.2599 - val_accuracy: 0.9167
# Epoch 66/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.9167
# Epoch 67/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1011 - accuracy: 0.9545 - val_loss: 0.3283 - val_accuracy: 0.8333
# Epoch 68/90
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9167
# Epoch 69/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9167
# Epoch 70/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0707 - accuracy: 0.9773 - val_loss: 0.2094 - val_accuracy: 0.9167
# Epoch 71/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.2363 - val_accuracy: 0.9167
# Epoch 72/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0571 - accuracy: 1.0000 - val_loss: 0.2905 - val_accuracy: 0.9167
# Epoch 73/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0675 - accuracy: 0.9773 - val_loss: 0.3413 - val_accuracy: 0.8333
# Epoch 74/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0843 - accuracy: 0.9773 - val_loss: 0.2777 - val_accuracy: 0.9167
# Epoch 75/90
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0383 - accuracy: 0.9773 - val_loss: 0.2464 - val_accuracy: 0.9167
# Epoch 76/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0816 - accuracy: 0.9773 - val_loss: 0.2533 - val_accuracy: 0.9167
# Epoch 77/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.2538 - val_accuracy: 0.9167
# Epoch 78/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9167
# Epoch 79/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.9167
# Epoch 80/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9167
# Epoch 81/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0391 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9167
# Epoch 82/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9167
# Epoch 83/90
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0525 - accuracy: 0.9773 - val_loss: 0.2398 - val_accuracy: 0.9167
# Epoch 84/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.2791 - val_accuracy: 0.8333
# Epoch 85/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0447 - accuracy: 0.9773 - val_loss: 0.2273 - val_accuracy: 0.9167
# Epoch 86/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.9167
# Epoch 87/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.1700 - val_accuracy: 0.9167
# Epoch 88/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9167
# Epoch 89/90
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.2407 - val_accuracy: 0.9167
# Epoch 90/90
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9167
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2307 - accuracy: 0.9167
# [0.23073233664035797, 0.9166666865348816]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 79ms/step

# %% [markdown]
# # DNN(Probe)

# %%
import pandas as pd
import numpy as np
import sklearn
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 소수점 9자리까지 표시
pd.options.display.float_format = '{:.9f}'.format

# df_probe.csv 파일을 읽어옵니다.
df_probe = pd.read_csv("/content/drive/MyDrive/attack_name_data/df_probe.csv")

# 'label' 열을 제외한 데이터를 probe_loX로 지정합니다.
probe_loX = df_probe.drop(['label'], axis=1)

# 'label' 열을 probeY로 지정합니다.
probeY = df_probe['label']

# MinMaxScaler를 사용하여 데이터를 스케일링합니다.
scaler = sklearn.preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(probe_loX)
probeX = pd.DataFrame(np_scaled, columns=probe_loX.columns)

# RandomUnderSampler를 사용하여 언더샘플링을 수행합니다.
rus = RandomUnderSampler()
dfrus_X, dfrus_Y = rus.fit_resample(probeX, probeY)
dfrus_X = pd.DataFrame(dfrus_X, columns=probeX.columns)

# 훈련 및 테스트 데이터로 분할합니다.
X_train, X_test, y_train, y_test = train_test_split(dfrus_X, dfrus_Y, test_size=0.2, random_state=2022)

# 데이터 차원 확인
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# 배열로 변환
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# DNN 모델 생성
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=22))
model.add(Dropout(0.1))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# 모델 구조 확인
model.summary()

# 모델 훈련
mod = model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test))

# 테스트셋 평가
scores = model.evaluate(X_test, y_test)
print(scores)

# 모델 저장
model.save('/content/drive/MyDrive/DNN_Model/DNN_probe.h5')

# 손실 그래프
plt.plot(mod.history['loss'], label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 정확도 그래프
plt.plot(mod.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 데이터에 대한 예측 확률
y_pred_prob = model.predict(X_test)

# 확률을 클래스로 변환 (임계값은 예시로 0.5)
threshold = 0.5
y_pred = np.where(y_pred_prob > threshold, 1, 0)

# 혼동 행렬을 시각화
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# (4523, 22) (4523,)
# (1131, 22) (1131,)
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_150 (Dense)           (None, 64)                1472
#
#  dropout_92 (Dropout)        (None, 64)                0
#
#  dense_151 (Dense)           (None, 32)                2080
#
#  dropout_93 (Dropout)        (None, 32)                0
#
#  dense_152 (Dense)           (None, 16)                528
#
#  dropout_94 (Dropout)        (None, 16)                0
#
#  dense_153 (Dense)           (None, 8)                 136
#
#  dropout_95 (Dropout)        (None, 8)                 0
#
#  dense_154 (Dense)           (None, 4)                 36
#
#  dense_155 (Dense)           (None, 1)                 5
#
# =================================================================
# Total params: 4257 (16.63 KB)
# Trainable params: 4257 (16.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 71/71 [==============================] - 2s 5ms/step - loss: 0.6212 - accuracy: 0.6891 - val_loss: 0.4470 - val_accuracy: 0.9231
# Epoch 2/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.3092 - accuracy: 0.9162 - val_loss: 0.1478 - val_accuracy: 0.9496
# Epoch 3/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1822 - accuracy: 0.9352 - val_loss: 0.1175 - val_accuracy: 0.9646
# Epoch 4/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1527 - accuracy: 0.9456 - val_loss: 0.1037 - val_accuracy: 0.9708
# Epoch 5/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9491 - val_loss: 0.0945 - val_accuracy: 0.9682
# Epoch 6/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1121 - accuracy: 0.9562 - val_loss: 0.0802 - val_accuracy: 0.9708
# Epoch 7/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1044 - accuracy: 0.9602 - val_loss: 0.0697 - val_accuracy: 0.9779
# Epoch 8/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9666 - val_loss: 0.0644 - val_accuracy: 0.9779
# Epoch 9/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0934 - accuracy: 0.9668 - val_loss: 0.0598 - val_accuracy: 0.9814
# Epoch 10/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9744 - val_loss: 0.0536 - val_accuracy: 0.9850
# Epoch 11/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9750 - val_loss: 0.0543 - val_accuracy: 0.9867
# Epoch 12/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9772 - val_loss: 0.0486 - val_accuracy: 0.9876
# Epoch 13/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 0.9801 - val_loss: 0.0470 - val_accuracy: 0.9867
# Epoch 14/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9803 - val_loss: 0.0457 - val_accuracy: 0.9876
# Epoch 15/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0690 - accuracy: 0.9801 - val_loss: 0.0434 - val_accuracy: 0.9876
# Epoch 16/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 0.9819 - val_loss: 0.0427 - val_accuracy: 0.9876
# Epoch 17/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0571 - accuracy: 0.9828 - val_loss: 0.0386 - val_accuracy: 0.9894
# Epoch 18/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 0.9854 - val_loss: 0.0409 - val_accuracy: 0.9885
# Epoch 19/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9841 - val_loss: 0.0346 - val_accuracy: 0.9912
# Epoch 20/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0530 - accuracy: 0.9843 - val_loss: 0.0349 - val_accuracy: 0.9903
# Epoch 21/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 0.9854 - val_loss: 0.0366 - val_accuracy: 0.9885
# Epoch 22/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0480 - accuracy: 0.9865 - val_loss: 0.0336 - val_accuracy: 0.9903
# Epoch 23/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 0.9874 - val_loss: 0.0363 - val_accuracy: 0.9885
# Epoch 24/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 0.9861 - val_loss: 0.0356 - val_accuracy: 0.9885
# Epoch 25/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0498 - accuracy: 0.9856 - val_loss: 0.0308 - val_accuracy: 0.9912
# Epoch 26/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9867 - val_loss: 0.0287 - val_accuracy: 0.9903
# Epoch 27/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9896 - val_loss: 0.0319 - val_accuracy: 0.9903
# Epoch 28/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9881 - val_loss: 0.0331 - val_accuracy: 0.9903
# Epoch 29/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 0.9892 - val_loss: 0.0321 - val_accuracy: 0.9912
# Epoch 30/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 0.9892 - val_loss: 0.0321 - val_accuracy: 0.9894
# Epoch 31/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.9883 - val_loss: 0.0316 - val_accuracy: 0.9903
# Epoch 32/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 0.9887 - val_loss: 0.0401 - val_accuracy: 0.9859
# Epoch 33/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9889 - val_loss: 0.0316 - val_accuracy: 0.9912
# Epoch 34/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0378 - accuracy: 0.9894 - val_loss: 0.0331 - val_accuracy: 0.9903
# Epoch 35/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9898 - val_loss: 0.0268 - val_accuracy: 0.9947
# Epoch 36/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9898 - val_loss: 0.0263 - val_accuracy: 0.9947
# Epoch 37/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9889 - val_loss: 0.0257 - val_accuracy: 0.9929
# Epoch 38/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 0.9907 - val_loss: 0.0309 - val_accuracy: 0.9929
# Epoch 39/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9925 - val_loss: 0.0270 - val_accuracy: 0.9929
# Epoch 40/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9909 - val_loss: 0.0290 - val_accuracy: 0.9929
# Epoch 41/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.0320 - val_accuracy: 0.9929
# Epoch 42/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 0.9885 - val_loss: 0.0292 - val_accuracy: 0.9938
# Epoch 43/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9901 - val_loss: 0.0265 - val_accuracy: 0.9938
# Epoch 44/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9912 - val_loss: 0.0288 - val_accuracy: 0.9929
# Epoch 45/100
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 0.9925 - val_loss: 0.0286 - val_accuracy: 0.9938
# Epoch 46/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9916 - val_loss: 0.0323 - val_accuracy: 0.9920
# Epoch 47/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 0.9918 - val_loss: 0.0326 - val_accuracy: 0.9920
# Epoch 48/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9918 - val_loss: 0.0273 - val_accuracy: 0.9947
# Epoch 49/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 0.9918 - val_loss: 0.0295 - val_accuracy: 0.9920
# Epoch 50/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9918 - val_loss: 0.0425 - val_accuracy: 0.9903
# Epoch 51/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 0.9914 - val_loss: 0.0281 - val_accuracy: 0.9938
# Epoch 52/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9934 - val_loss: 0.0330 - val_accuracy: 0.9912
# Epoch 53/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9929 - val_loss: 0.0340 - val_accuracy: 0.9912
# Epoch 54/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9914 - val_loss: 0.0306 - val_accuracy: 0.9938
# Epoch 55/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9916 - val_loss: 0.0307 - val_accuracy: 0.9938
# Epoch 56/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.0321 - val_accuracy: 0.9938
# Epoch 57/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0260 - accuracy: 0.9925 - val_loss: 0.0281 - val_accuracy: 0.9956
# Epoch 58/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 0.0314 - val_accuracy: 0.9929
# Epoch 59/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.9934 - val_loss: 0.0356 - val_accuracy: 0.9912
# Epoch 60/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9920 - val_loss: 0.0378 - val_accuracy: 0.9912
# Epoch 61/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9914 - val_loss: 0.0313 - val_accuracy: 0.9938
# Epoch 62/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.0344 - val_accuracy: 0.9912
# Epoch 63/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 0.9923 - val_loss: 0.0465 - val_accuracy: 0.9903
# Epoch 64/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0260 - accuracy: 0.9909 - val_loss: 0.0346 - val_accuracy: 0.9920
# Epoch 65/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 0.9923 - val_loss: 0.0300 - val_accuracy: 0.9929
# Epoch 66/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9936 - val_loss: 0.0326 - val_accuracy: 0.9929
# Epoch 67/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.0347 - val_accuracy: 0.9920
# Epoch 68/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 0.0346 - val_accuracy: 0.9938
# Epoch 69/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.9927 - val_loss: 0.0380 - val_accuracy: 0.9929
# Epoch 70/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.0329 - val_accuracy: 0.9929
# Epoch 71/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9940 - val_loss: 0.0372 - val_accuracy: 0.9920
# Epoch 72/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 0.0336 - val_accuracy: 0.9947
# Epoch 73/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9945 - val_loss: 0.0384 - val_accuracy: 0.9920
# Epoch 74/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9936 - val_loss: 0.0400 - val_accuracy: 0.9929
# Epoch 75/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9936 - val_loss: 0.0434 - val_accuracy: 0.9912
# Epoch 76/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 0.0448 - val_accuracy: 0.9903
# Epoch 77/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9927 - val_loss: 0.0427 - val_accuracy: 0.9920
# Epoch 78/100
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9940 - val_loss: 0.0396 - val_accuracy: 0.9920
# Epoch 79/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9934 - val_loss: 0.0422 - val_accuracy: 0.9929
# Epoch 80/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.9925 - val_loss: 0.0394 - val_accuracy: 0.9938
# Epoch 81/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 0.0431 - val_accuracy: 0.9929
# Epoch 82/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.0412 - val_accuracy: 0.9929
# Epoch 83/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9936 - val_loss: 0.0485 - val_accuracy: 0.9894
# Epoch 84/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.0460 - val_accuracy: 0.9929
# Epoch 85/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9936 - val_loss: 0.0526 - val_accuracy: 0.9929
# Epoch 86/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 0.0509 - val_accuracy: 0.9903
# Epoch 87/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 0.9934 - val_loss: 0.0477 - val_accuracy: 0.9920
# Epoch 88/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9927 - val_loss: 0.0502 - val_accuracy: 0.9920
# Epoch 89/100
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9929 - val_loss: 0.0450 - val_accuracy: 0.9920
# Epoch 90/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.0435 - val_accuracy: 0.9929
# Epoch 91/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9949 - val_loss: 0.0424 - val_accuracy: 0.9929
# Epoch 92/100
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 0.0429 - val_accuracy: 0.9938
# Epoch 93/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9943 - val_loss: 0.0432 - val_accuracy: 0.9947
# Epoch 94/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9943 - val_loss: 0.0496 - val_accuracy: 0.9912
# Epoch 95/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0539 - val_accuracy: 0.9912
# Epoch 96/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.0488 - val_accuracy: 0.9938
# Epoch 97/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.0486 - val_accuracy: 0.9929
# Epoch 98/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 0.0522 - val_accuracy: 0.9920
# Epoch 99/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.0462 - val_accuracy: 0.9947
# Epoch 100/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 0.9958 - val_loss: 0.0503 - val_accuracy: 0.9938
# 36/36 [==============================] - 0s 1ms/step - loss: 0.0503 - accuracy: 0.9938
# [0.050313521176576614, 0.993810772895813]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 36/36 [==============================] - 0s 2ms/step
